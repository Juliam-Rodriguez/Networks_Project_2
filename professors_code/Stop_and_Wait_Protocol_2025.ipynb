# %%
import time
import socket
from queue import Queue 
from threading import Thread, Condition
from ipywidgets import widgets
from IPython.display import display
import random

# %%
class EXP_Output:
    def __init__(self):
        #self.out = widgets.Output(layout={'border': '1px solid black'})
        #display(self.out)
        #with self.out:
        #print("Experiment outputs")

        self.Queue_Print = Queue()
        self.thread = Thread(target=self.loop_Print)
        self.thread.start()

    def print(self, msg):
        text_out = time.strftime("%H:%M:%S", time.localtime()) + "> "
        self.Queue_Print.put(text_out+msg)

    def loop_Print(self):
        while True:
            msg = self.Queue_Print.get()
            #with self.out:
            print(msg)
            self.Queue_Print.task_done()

# %%
class ALE_TextInput:
    
    def __init__(self, exp_out):
        
        self.Queue_User = Queue()
        self.exp_out = exp_out

        # Create a text input widget
        self.Text = widgets.Text(
                        value='',
                        placeholder='Type something and press enter',
                        description='To send:',
                        disabled=False
                    )

        # create a button object
        self.Botton =  widgets.Button(
                            description='Submit',
                            disabled=False,
                            button_style='', 
                            tooltip='Click me to submit a string',
                        )

        # Define a function to handle the click action on the button
        def on_submit_button_clicked(b):

            global thread_running
            
            msg = self.Text.value
            #self.exp_out.print("ALE_0: received input: "+str(msg))
                
            if thread_running == True:
                if msg == "end":
                    thread_running = False
                
                for i in range(20):
                    self.Queue_User.put(msg+str(i))

            self.Text.value = ''  # Clear the input field after submission

        # Attach the event to the button
        self.Botton.on_click(on_submit_button_clicked)
        
        # Display the widgets
        display(self.Text, self.Botton)
        
    # to get a message from user queue. this function can block the thread
    def get(self):
        return self.Queue_User.get()

# %%
class ALE_TR:
    
    def __init__(self, name, upper_Tx, lower_TR, exp_out):
        
        self.Name     = name
        self.Upper_Tx = upper_Tx  # must provide get()
        self.Lower_TR = lower_TR  # must provide send(msg), and receive()
        self.exp_out  = exp_out
        
    def loop_Tx(self):

        global thread_running
        c = 0
        self.exp_out.print(self.Name + ": loop_Tx starting")
    
        while (thread_running == True):

            c = c + 1

            # get text from Upper_Tx, which must provide a get method
            # this thread is blocked here
            msg = self.Upper_Tx.get()
            
            text_out = self.Name + " Tx: message " + str(c) + ": " + str(msg)
            self.exp_out.print(text_out)

            # add the text to the queue
            self.Lower_TR.send(msg)
            
    def loop_Rx(self):
        
        global thread_running
        c = 0
        self.exp_out.print(self.Name + ": loop_Rx starting")
    
        while (thread_running == True):

            c = c + 1

            # get message from a lower layer
            # this thread is blocked here
            msg = self.Lower_TR.receive()
            
            text_out = self.Name + " Rx: message " + str(c) + ": " + str(msg)
            self.exp_out.print(text_out)

# %%
# state of DLE
STATE_READY_TO_SEND = 0 # ready to send a packet to the DLE entity in another node through lower layer
STATE_WAITING_ACK   = 1 # waiting for ACK from the DLE entity in another node

# events of DLE
EVENT_UPPER_TX  = 0 # upper layer wants to send a packet
EVENT_LOWER_DAT = 1 # lower layer forwards an incoming data packet
EVENT_LOWER_ACK = 2 # lower layer forwards an incoming data packet
EVENT_TIMEOUT   = 3 # timer timeout
        
class DLE_TR_FSM:
    
    def __init__(self, name, lower_TR, exp_out):
        
        self.Name      = name
        self.Lower_TR  = lower_TR   # must provide send(msg) and receive()
        self.Queue_Tx  = Queue()
        self.Queue_Rx  = Queue()
        self.exp_out   = exp_out
        
        # create a queue for Finite State Machine
        self.Queue_FSM = Queue()
        
        # create a flag = condition to start sending
        self.cv_TxOp = Condition()
        self.TxOp    = True

        # init state to STATE_WAITING_UPPER
        self.State = STATE_READY_TO_SEND
        
        self.Procedure = [[self.FSM_upper_Tx, self.FSM_abnormal],
                          [self.FSM_lower_Rx, self.FSM_lower_Rx],
                          [self.FSM_abnormal, self.FSM_lower_Rx_ack],
                          [self.FSM_abnormal, self.FSM_timeout]] 
        

        # new features for retransmission
        # timer
        self.cv_Timer      = Condition()
        self.timer_active  = False
        self.timer_counter = 0
        
        # transmission 
        self.tx_buffer  = ''
        self.tx_seq_num = '0'
        
        # reception
        self.tx_ack_num = '0'
        
        
    def loop_Tx(self):

        global thread_running
        c = 0
        self.exp_out.print(self.Name + ": loop_Tx starting")
    
        while (thread_running == True):

            # waiting for the ready to sent signal
            with self.cv_TxOp: 
                while (self.TxOp != True): 
                    self.cv_TxOp.wait()
            
                self.TxOp = False
                
                c = c + 1

                # get a message from queue
                msg = self.Queue_Tx.get()
                text_out = self.Name + " Tx: message " + str(c) + ": " + str(msg)
                self.exp_out.print(text_out)
            
                self.event_add(EVENT_UPPER_TX, msg) 

    def loop_Rx(self):
        
        global thread_running
        c = 0
        self.exp_out.print(self.Name + ": loop_Rx starting")
    
        while (thread_running == True):

            c = c + 1

            # get message from a lower layer
            # this thread is blocked here
            msg = self.Lower_TR.receive()
            
            text_out = self.Name + " Rx: message " + str(c) + ": " + str(msg)
            self.exp_out.print(text_out)
            
            # add an event for FSM, assuming that msg is a sequence of bytes
            msg_type = msg[0]
            if (msg_type == '0'):
                self.event_add(EVENT_LOWER_DAT, msg[1:])
            elif (msg_type == '1'):
                self.event_add(EVENT_LOWER_ACK, msg[1:])
            else:
                text_out = self.Name + " Rx: message type unknown " + msg_type
                self.exp_out.print(text_out)

    def receive(self):
        return self.Queue_Rx.get()
    
    def send(self, msg):
        self.Queue_Tx.put(msg)
        
    def event_add(self, ev_type, msg):
        
        # preparing an event
        if (isinstance(msg, str)):
            msg = msg.encode()
        
        # the event is a sequence of bytes
        event = ev_type.to_bytes(1, "big")+msg
        
        # add event to queue
        self.Queue_FSM.put(event)        
        

    def loop_FSM(self):
        
        global thread_running
        self.exp_out.print(self.Name + ": loop_FSM starting")
        
        while (thread_running == True):
            
            # get the next event
            event = self.Queue_FSM.get()
            
            ev_type = event[0]
            
            text_out = self.Name + " FSM: state: " + str(self.State)+" event type: " + str(ev_type)
            self.exp_out.print(text_out)
            
            # process the event
            msg = event[1:].decode('utf-8') # message becomes a string
            self.Procedure[ev_type][self.State](msg)
        
    def FSM_abnormal(self, msg):
        
        text_out = self.Name + " FSM: error! " + msg
        self.exp_out.print(text_out)
    
    def FSM_upper_Tx(self, msg):   
        
        text_out = self.Name + " FSM: to send: " + msg
        self.exp_out.print(text_out)

        # buffer the message (for retransmission)
        self.tx_buffer = msg
        
        # prepare to send a data message
        msg = '0' + self.tx_seq_num + msg     # inicating a new packet and its sequence number
        self.Lower_TR.send(msg)

        # waiting for ACK
        self.State = STATE_WAITING_ACK
        
        # start timer
        with self.cv_Timer:
            self.timer_active  = True
            self.timer_counter = 10
            self.cv_Timer.notify()    
    
    def FSM_lower_Rx(self, msg):

        # get the sequence number
        seq = msg[0]
        msg = msg[1:]
        
        # received a new data packet        
        text_out = self.Name + " FSM: received: " + msg
        self.exp_out.print(text_out)

        if (seq == self.tx_ack_num):
            
            # put the message in a receiving queue
            self.Queue_Rx.put(msg)
            
            self.tx_ack_num = chr(ord(self.tx_ack_num) + 1)
            if (self.tx_ack_num == chr(ord('9') + 1)):
                self.tx_ack_num = '0'
        
        else:
            text_out  = self.Name + " FSM: received received frame " + seq
            text_out += " but expected " + self.tx_ack_num
            self.exp_out.print(text_out)
            

        # to send an ACK
        self.Lower_TR.send('1'+seq)

                
    def FSM_lower_Rx_ack(self, msg):
        
        ack = msg[0] # get the ack number
        if (ack != self.tx_seq_num):
            
            # the received ack does not match the seq
            text_out = "ACK # " + ack + " does not match local seq # " + self.tx_seq_num
            self.exp_out.print(text_out)
            return

        # stop timer
        self.timer_active = False
        
        # inc the seq
        self.tx_seq_num = chr(ord(self.tx_seq_num) + 1)
        if (self.tx_seq_num == chr(ord('9') + 1)):
                self.tx_seq_num = '0'
        
        # ready to send the next upper layer packet
        with self.cv_TxOp:
            self.State = STATE_READY_TO_SEND
            self.TxOp  = True
            self.cv_TxOp.notify()
            
    def FSM_timeout(self, msg):
        
        text_out = self.Name + " FSM: to resend frame " + self.tx_seq_num + " " + self.tx_buffer
        self.exp_out.print(text_out)
        
        # prepare to send a data message
        msg = '0' + self.tx_seq_num + self.tx_buffer     # inicating a new packet and its sequence number
        self.Lower_TR.send(msg)
        
        # start timer
        with self.cv_Timer:
            self.timer_active  = True
            self.timer_counter = 10
            self.cv_Timer.notify()

    def loop_timer(self):
        
        global thread_running
        self.exp_out.print(self.Name + ": loop_Timer starting")
        
        while (thread_running == True):
            
            with self.cv_Timer: 
                while (self.timer_active == False): 
                    self.cv_Timer.wait() 
            
                time.sleep(0.5)

                if (self.timer_counter == 0):
                    # add an event for timeout
                    self.event_add(EVENT_TIMEOUT, 'x')
                    self.timer_active = False

                else:
                    self.timer_counter = self.timer_counter - 1

# %%
class PLE_TR:

    def __init__(self, name, Socket, AP_Tx, AP_Rx, exp_out):
        
        self.Name      = name
        self.Socket    = Socket
        self.AP_Tx     = AP_Tx
        self.AP_Rx     = AP_Rx
        self.Queue_Tx  = Queue()
        self.Queue_Rx  = Queue()
        self.exp_out   = exp_out
        
    def loop_Tx(self):
        
        global thread_running
        self.exp_out.print(self.Name + ": loop_Tx starting")
    
        while (thread_running == True):
        
            # get a message from queue
            msg = self.Queue_Tx.get()
            
            text_out = self.Name + " Tx: message: " + str(msg)
            self.exp_out.print(text_out)
            
            # sending the message using socket
            msg_bytes = str.encode(msg)
            if (random.random() < 0.1):
                self.exp_out.print("packet loss")

            elif (random.random() < 0.05):
                self.Socket.sendto(msg_bytes, self.AP_Tx)
                self.Socket.sendto(msg_bytes, self.AP_Tx)
                self.exp_out.print("Transmission Duplicated")
            else:
                # sending the message using socket
                self.Socket.sendto(msg_bytes, self.AP_Tx)

    def loop_Rx(self):
        
        global thread_running
        global bufferSize
        self.exp_out.print(self.Name + ": loop_Rx starting")
    
        # binding the socket with the IP and port
        self.Socket.bind(self.AP_Rx)
        
        while (thread_running == True):
        
            # get a message from socket, this thread is blocked here
            msg_addr = self.Socket.recvfrom(bufferSize)

            # Random delay ranging from 0 - 2 seconds.
            delay = random.uniform(0, 2)
            time.sleep(delay)
    
            msg  = msg_addr[0].decode('utf-8')
            addr = msg_addr[1]
            
            text_out = self.Name + " Rx: from " + str(addr) + ": " + str(msg)
            self.exp_out.print(text_out)
            
            self.Queue_Rx.put(msg)
            
    def send(self, msg):
        self.Queue_Tx.put(msg)
        
    def receive(self):
        return self.Queue_Rx.get()

# %%
thread_running = False
bufferSize = 1024

# (0) creating an output object
exp_out = EXP_Output()

# (1) create physical layer entities
AP_local_1  = ("127.0.0.1", 30000)
AP_remote_1 = ("127.0.0.1", 31111)
Socket_1    = socket.socket(family=socket.AF_INET, type=socket.SOCK_DGRAM)
PLE_1       = PLE_TR("PLE_Alice", Socket_1, AP_remote_1, AP_local_1, exp_out)

# (2) create date link layer entities
DLE_1 = DLE_TR_FSM("DLE_Alice", PLE_1, exp_out)

# (3) create application layer entities
ALE_0 = ALE_TextInput(exp_out)
ALE_1 = ALE_TR("ALE_Alice", ALE_0, DLE_1, exp_out)
# Out:
# Text(value='', description='To send:', placeholder='Type something and press enter')
# Button(description='Submit', style=ButtonStyle(), tooltip='Click me to submit a string')
# 19:02:13> ALE_Alice: loop_Tx starting
# 19:02:13> ALE_Alice: loop_Rx starting
# 19:02:13> DLE_Alice: loop_Tx starting
# 19:02:13> DLE_Alice: loop_Rx starting
# 19:02:13> PLE_Alice: loop_Tx starting
# 19:02:13> PLE_Alice: loop_Rx starting
# 19:02:13> ALE_Bob: loop_Tx starting
# 19:02:13> ALE_Bob: loop_Rx starting
# 19:02:13> DLE_Bob: loop_Tx starting
# 19:02:13> DLE_Bob: loop_Rx starting
# 19:02:13> PLE_Bob: loop_Tx starting
# 19:02:13> PLE_Bob: loop_Rx starting
# 19:02:13> DLE_Alice: loop_FSM starting
# 19:02:13> DLE_Bob: loop_FSM starting
# 19:02:13> DLE_Alice: loop_Timer starting
# 19:02:13> DLE_Bob: loop_Timer starting

# %%
# (4) create physical layer entities
AP_local_2  = ("127.0.0.1", 31111)
AP_remote_2 = ("127.0.0.1", 30000)
Socket_2    = socket.socket(family=socket.AF_INET, type=socket.SOCK_DGRAM)
PLE_2       = PLE_TR("PLE_Bob", Socket_2, AP_remote_2, AP_local_2, exp_out)

# (5) create date link layer entities
DLE_2 = DLE_TR_FSM("DLE_Bob", PLE_2, exp_out)

# (6) create application layer entities
ALE_3 = ALE_TextInput(exp_out)
ALE_2 = ALE_TR("ALE_Bob", ALE_3, DLE_2, exp_out)
# Out:
# Text(value='', description='To send:', placeholder='Type something and press enter')
# Button(description='Submit', style=ButtonStyle(), tooltip='Click me to submit a string')

# %%
# start the loops of all entities
# all loops must be blocked at a certain position

t1_1 = Thread(target = ALE_1.loop_Tx, args = ()) 
t2_1 = Thread(target = ALE_1.loop_Rx, args = ()) 
t3_1 = Thread(target = DLE_1.loop_Tx, args = ())
t4_1 = Thread(target = DLE_1.loop_Rx, args = ())
t5_1 = Thread(target = PLE_1.loop_Tx, args = ()) 
t6_1 = Thread(target = PLE_1.loop_Rx, args = ())
f1_1 = Thread(target = DLE_1.loop_FSM, args = ())
f2_1 = Thread(target = DLE_1.loop_timer, args = ())


t1_2 = Thread(target = ALE_2.loop_Tx, args = ()) 
t2_2 = Thread(target = ALE_2.loop_Rx, args = ()) 
t3_2 = Thread(target = DLE_2.loop_Tx, args = ())
t4_2 = Thread(target = DLE_2.loop_Rx, args = ())
t5_2 = Thread(target = PLE_2.loop_Tx, args = ()) 
t6_2 = Thread(target = PLE_2.loop_Rx, args = ()) 
f1_2 = Thread(target = DLE_2.loop_FSM, args = ())
f2_2 = Thread(target = DLE_2.loop_timer, args = ())

thread_running = True

t1_1.start()
t2_1.start()
t3_1.start()
t4_1.start()
t5_1.start()
t6_1.start()
t1_2.start()
t2_2.start()
t3_2.start()
t4_2.start()
t5_2.start()
t6_2.start()
f1_1.start()
f1_2.start()
f2_1.start()
f2_2.start()

# %%
class MLE_TR(PLE_TR):
    def __init__(self, name, Socket, AP_Tx, AP_Rx, exp_out, experiment_id = 1):
        super().__init__(name, Socket, AP_Tx, AP_Rx, exp_out)
        self.experiment_id = experiment_id
        self.received_packets = []
        self.received_counts = {}
        
        self.button = widgets.Button(description=f'Run {name}')
        self.button.on_click(self.send_messages_callback)
        display(self.button)

    def send_messages_callback(self, b):

        for msg_id in range(1, 101):
            timestamp = time.time_ns()
            packet = f"{self.experiment_id}|{msg_id}|{timestamp}" # Construct the package format
            self.send(packet)            
            
        self.exp_out.print(f"Button Pressed")

    def display_computations(self):

        total_expected = 100
        delays = [(received_time - sent_time) / 1e6 for (_, _, sent_time, received_time) in self.received_packets]
        avg_delay = sum(delays) / len(delays) if delays else 0
        
        # Unique messages received
        unique_received = len(self.received_counts)
        loss_rate = (total_expected - unique_received) / total_expected
        
        # Count extra duplicate receptions:
        duplicate_count = sum(1 for count in self.received_counts.values() if count > 1)
        duplicate_rate = duplicate_count / total_expected
        
        self.exp_out.print(f"--- Measurement Results for {self.Name} ---")
        self.exp_out.print(f"Average Delay: {avg_delay:.2f} ms")
        self.exp_out.print(f"Loss Rate: {loss_rate * 100:.2f}%")
        self.exp_out.print(f"Duplicate Rate: {duplicate_rate * 100:.2f}%")

    def loop_Rx(self):

        global thread_running
        global bufferSize
    
        self.Socket.bind(self.AP_Rx)
        
        while (thread_running == True):

            message_address = self.Socket.recvfrom(bufferSize)

            message = message_address[0]
            address = message_address[1]

            try:
                experiment_id, message_id, sent_time = message.decode().split('|')
                message_id = int(message_id)
                sent_time = int(sent_time)
                print(time.strftime("%H:%M:%S", time.localtime()), end=' ')
                print("%s Rx from %s: %s"%(self.Name, address, message))
                self.Queue_Rx.put(message)
            except Exception as e:
                self.exp_out.print(f"Error - {e} - parsing packet: {message}")
                continue
                
            # Verify and add to the list if the packet is duplicate or not in the packet list
            # This is done for Part 4 (Section 4 Part 4)
            key = message_id
            if key in self.received_counts:
                self.received_counts[key]+= 1
            else:
                self.received_counts[key] = 1
                self.received_packets.append((experiment_id, message_id, sent_time, time.time_ns()))
            
            self.display_computations()


exp_out = EXP_Output()

AP_local_MLE_Alice = ("localhost", 32000)
AP_Local_MLE_Bob = ("localhost", 32222)
AP_Remote_MLE_Bob = ("localhost", 32000)
AP_remote_MLE_Alice = ("localhost", 32222)

alice_MLE_socket = socket.socket(family=socket.AF_INET, type=socket.SOCK_DGRAM)
bob_MLE_socket = socket.socket(family=socket.AF_INET, type=socket.SOCK_DGRAM)

# Call class MLE_TR
alice_MLE = MLE_TR("MLE_Alice", alice_MLE_socket, AP_remote_MLE_Alice, AP_local_MLE_Alice, exp_out)
bob_MLE = MLE_TR("MLE_Bob", bob_MLE_socket, AP_Remote_MLE_Bob, AP_Local_MLE_Bob, exp_out)


alice_thread_tx = Thread(target=alice_MLE.loop_Tx)
alice_thread_rx = Thread(target=alice_MLE.loop_Rx)
bob_thread_tx = Thread(target=bob_MLE.loop_Tx)
bob_thread_rx = Thread(target=bob_MLE.loop_Rx)

# Start threads for MLE_Alice and MLE_Bob
thread_running = True

alice_thread_tx.start()
alice_thread_rx.start()
bob_thread_tx.start()
bob_thread_rx.start()
# Out:
# Button(description='Run MLE_Alice', style=ButtonStyle())
# Button(description='Run MLE_Bob', style=ButtonStyle())
# 19:02:13> MLE_Alice: loop_Tx starting
# 19:02:13> MLE_Bob: loop_Tx starting
# 19:02:15> Button Pressed
# 19:02:15> MLE_Alice Tx: message: 1|1|1743116535026644000
# 19:02:15> MLE_Alice Tx: message: 1|2|1743116535026657000
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|1|1743116535026644000'
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 0.73 ms
# 19:02:15> Loss Rate: 99.00%
# 19:02:15> Duplicate Rate: 0.00%
# 19:02:15> MLE_Alice Tx: message: 1|3|1743116535026659000
# 19:02:15> packet loss
# 19:02:15> MLE_Alice Tx: message: 1|4|1743116535026661000
# 19:02:15> MLE_Alice Tx: message: 1|5|1743116535026663000
# 19:02:15> MLE_Alice Tx: message: 1|6|1743116535026664000
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|2|1743116535026657000'
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 1.24 ms
# 19:02:15> Loss Rate: 98.00%
# 19:02:15> Duplicate Rate: 0.00%
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|4|1743116535026661000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|5|1743116535026663000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|6|1743116535026664000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|7|1743116535026665000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|7|1743116535026665000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|8|1743116535026667000'
# 19:02:15> MLE_Alice Tx: message: 1|7|1743116535026665000
# 19:02:15> Transmission Duplicated
# 19:02:15> MLE_Alice Tx: message: 1|8|1743116535026667000
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 1.49 ms
# 19:02:15> Loss Rate: 97.00%
# 19:02:15> Duplicate Rate: 0.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 1.62 ms
# 19:02:15> Loss Rate: 96.00%
# 19:02:15> Duplicate Rate: 0.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 1.71 ms
# 19:02:15> Loss Rate: 95.00%
# 19:02:15> Duplicate Rate: 0.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 1.78 ms
# 19:02:15> Loss Rate: 94.00%
# 19:02:15> Duplicate Rate: 0.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 1.78 ms
# 19:02:15> Loss Rate: 94.00%
# 19:02:15> Duplicate Rate: 1.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 1.86 ms
# 19:02:15> Loss Rate: 93.00%
# 19:02:15> Duplicate Rate: 1.00%
# 19:02:15> MLE_Alice Tx: message: 1|9|1743116535026668000
# 19:02:15> MLE_Alice Tx: message: 1|10|1743116535026670000
# 19:02:15> MLE_Alice Tx: message: 1|11|1743116535026672000
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|9|1743116535026668000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|10|1743116535026670000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|11|1743116535026672000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|12|1743116535026673000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|14|1743116535026676000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|15|1743116535026677000'
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 2.01 ms
# 19:02:15> Loss Rate: 92.00%
# 19:02:15> Duplicate Rate: 1.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 2.13 ms
# 19:02:15> Loss Rate: 91.00%
# 19:02:15> Duplicate Rate: 1.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 2.24 ms
# 19:02:15> Loss Rate: 90.00%
# 19:02:15> Duplicate Rate: 1.00%
# 19:02:15> MLE_Alice Tx: message: 1|12|1743116535026673000
# 19:02:15> MLE_Alice Tx: message: 1|13|1743116535026675000
# 19:02:15> packet loss
# 19:02:15> MLE_Alice Tx: message: 1|14|1743116535026676000
# 19:02:15> MLE_Alice Tx: message: 1|15|1743116535026677000
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 2.34 ms
# 19:02:15> Loss Rate: 89.00%
# 19:02:15> Duplicate Rate: 1.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 2.43 ms
# 19:02:15> Loss Rate: 88.00%
# 19:02:15> Duplicate Rate: 1.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 2.51 ms
# 19:02:15> Loss Rate: 87.00%
# 19:02:15> Duplicate Rate: 1.00%
# 19:02:15> MLE_Alice Tx: message: 1|16|1743116535026679000
# 19:02:15> packet loss
# 19:02:15> MLE_Alice Tx: message: 1|17|1743116535026680000
# 19:02:15> MLE_Alice Tx: message: 1|18|1743116535026681000
# 19:02:15> packet loss
# 19:02:15> MLE_Alice Tx: message: 1|19|1743116535026683000
# 19:02:15> MLE_Alice Tx: message: 1|20|1743116535026684000
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|17|1743116535026680000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|19|1743116535026683000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|20|1743116535026684000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|21|1743116535026685000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|22|1743116535026686000'
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 2.73 ms
# 19:02:15> Loss Rate: 86.00%
# 19:02:15> Duplicate Rate: 1.00%
# 19:02:15> MLE_Alice Tx: message: 1|21|1743116535026685000
# 19:02:15> MLE_Alice Tx: message: 1|22|1743116535026686000
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 2.93 ms
# 19:02:15> Loss Rate: 85.00%
# 19:02:15> Duplicate Rate: 1.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 3.12 ms
# 19:02:15> Loss Rate: 84.00%
# 19:02:15> Duplicate Rate: 1.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 3.29 ms
# 19:02:15> Loss Rate: 83.00%
# 19:02:15> Duplicate Rate: 1.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 3.44 ms
# 19:02:15> Loss Rate: 82.00%
# 19:02:15> Duplicate Rate: 1.00%
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|22|1743116535026686000'
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 3.44 ms
# 19:02:15> Loss Rate: 82.00%
# 19:02:15> Duplicate Rate: 2.00%
# 19:02:15> Transmission Duplicated
# 19:02:15> MLE_Alice Tx: message: 1|23|1743116535026688000
# 19:02:15> MLE_Alice Tx: message: 1|24|1743116535026689000
# 19:02:15> packet loss
# 19:02:15> MLE_Alice Tx: message: 1|25|1743116535026690000
# 19:02:15> MLE_Alice Tx: message: 1|26|1743116535026691000
# 19:02:15> MLE_Alice Tx: message: 1|27|1743116535026693000
# 19:02:15> MLE_Alice Tx: message: 1|28|1743116535026694000
# 19:02:15> MLE_Alice Tx: message: 1|29|1743116535026695000
# 19:02:15> MLE_Alice Tx: message: 1|30|1743116535026696000
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|23|1743116535026688000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|25|1743116535026690000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|26|1743116535026691000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|27|1743116535026693000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|28|1743116535026694000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|29|1743116535026695000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|30|1743116535026696000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|31|1743116535026698000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|32|1743116535026699000'
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 3.61 ms
# 19:02:15> Loss Rate: 81.00%
# 19:02:15> Duplicate Rate: 2.00%
# 19:02:15> MLE_Alice Tx: message: 1|31|1743116535026698000
# 19:02:15> MLE_Alice Tx: message: 1|32|1743116535026699000
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 3.77 ms
# 19:02:15> Loss Rate: 80.00%
# 19:02:15> Duplicate Rate: 2.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 3.92 ms
# 19:02:15> Loss Rate: 79.00%
# 19:02:15> Duplicate Rate: 2.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 4.06 ms
# 19:02:15> Loss Rate: 78.00%
# 19:02:15> Duplicate Rate: 2.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 4.18 ms
# 19:02:15> Loss Rate: 77.00%
# 19:02:15> Duplicate Rate: 2.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 4.30 ms
# 19:02:15> Loss Rate: 76.00%
# 19:02:15> Duplicate Rate: 2.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 4.41 ms
# 19:02:15> Loss Rate: 75.00%
# 19:02:15> Duplicate Rate: 2.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 4.51 ms
# 19:02:15> Loss Rate: 74.00%
# 19:02:15> Duplicate Rate: 2.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 4.60 ms
# 19:02:15> Loss Rate: 73.00%
# 19:02:15> Duplicate Rate: 2.00%
# 19:02:15> MLE_Alice Tx: message: 1|33|1743116535026700000
# 19:02:15> packet loss
# 19:02:15> MLE_Alice Tx: message: 1|34|1743116535026702000
# 19:02:15> MLE_Alice Tx: message: 1|35|1743116535026703000
# 19:02:15> MLE_Alice Tx: message: 1|36|1743116535026704000
# 19:02:15> Transmission Duplicated
# 19:02:15> MLE_Alice Tx: message: 1|37|1743116535026706000
# 19:02:15> MLE_Alice Tx: message: 1|38|1743116535026707000
# 19:02:15> MLE_Alice Tx: message: 1|39|1743116535026708000
# 19:02:15> MLE_Alice Tx: message: 1|40|1743116535026709000
# 19:02:15> Transmission Duplicated
# 19:02:15> MLE_Alice Tx: message: 1|41|1743116535026710000
# 19:02:15> packet loss
# 19:02:15> MLE_Alice Tx: message: 1|42|1743116535026712000
# 19:02:15> MLE_Alice Tx: message: 1|43|1743116535026713000
# 19:02:15> MLE_Alice Tx: message: 1|44|1743116535026714000
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|34|1743116535026702000'
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 4.73 ms
# 19:02:15> Loss Rate: 72.00%
# 19:02:15> Duplicate Rate: 2.00%
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|35|1743116535026703000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|36|1743116535026704000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|36|1743116535026704000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|37|1743116535026706000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|38|1743116535026707000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|39|1743116535026708000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|40|1743116535026709000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|40|1743116535026709000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|42|1743116535026712000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|43|1743116535026713000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|44|1743116535026714000'
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 4.85 ms
# 19:02:15> Loss Rate: 71.00%
# 19:02:15> Duplicate Rate: 2.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 4.97 ms
# 19:02:15> Loss Rate: 70.00%
# 19:02:15> Duplicate Rate: 2.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 4.97 ms
# 19:02:15> Loss Rate: 70.00%
# 19:02:15> Duplicate Rate: 3.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 5.08 ms
# 19:02:15> Loss Rate: 69.00%
# 19:02:15> Duplicate Rate: 3.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 5.19 ms
# 19:02:15> Loss Rate: 68.00%
# 19:02:15> Duplicate Rate: 3.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 5.30 ms
# 19:02:15> Loss Rate: 67.00%
# 19:02:15> Duplicate Rate: 3.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 5.39 ms
# 19:02:15> Loss Rate: 66.00%
# 19:02:15> Duplicate Rate: 3.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 5.39 ms
# 19:02:15> Loss Rate: 66.00%
# 19:02:15> Duplicate Rate: 4.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 5.49 ms
# 19:02:15> Loss Rate: 65.00%
# 19:02:15> Duplicate Rate: 4.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 5.58 ms
# 19:02:15> Loss Rate: 64.00%
# 19:02:15> Duplicate Rate: 4.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 5.67 ms
# 19:02:15> Loss Rate: 63.00%
# 19:02:15> Duplicate Rate: 4.00%
# 19:02:15> MLE_Alice Tx: message: 1|45|1743116535026715000
# 19:02:15> MLE_Alice Tx: message: 1|46|1743116535026717000
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|45|1743116535026715000'
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 5.77 ms
# 19:02:15> Loss Rate: 62.00%
# 19:02:15> Duplicate Rate: 4.00%
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|46|1743116535026717000'
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 5.86 ms
# 19:02:15> Loss Rate: 61.00%
# 19:02:15> Duplicate Rate: 4.00%
# 19:02:15> MLE_Alice Tx: message: 1|47|1743116535026718000
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|47|1743116535026718000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|47|1743116535026718000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|48|1743116535026719000'
# 19:02:15> Transmission Duplicated
# 19:02:15> MLE_Alice Tx: message: 1|48|1743116535026719000
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 5.95 ms
# 19:02:15> Loss Rate: 60.00%
# 19:02:15> Duplicate Rate: 4.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 5.95 ms
# 19:02:15> Loss Rate: 60.00%
# 19:02:15> Duplicate Rate: 5.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 6.04 ms
# 19:02:15> Loss Rate: 59.00%
# 19:02:15> Duplicate Rate: 5.00%
# 19:02:15> MLE_Alice Tx: message: 1|49|1743116535026720000
# 19:02:15> MLE_Alice Tx: message: 1|50|1743116535026721000
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|49|1743116535026720000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|50|1743116535026721000'
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 6.13 ms
# 19:02:15> Loss Rate: 58.00%
# 19:02:15> Duplicate Rate: 5.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 6.21 ms
# 19:02:15> Loss Rate: 57.00%
# 19:02:15> Duplicate Rate: 5.00%
# 19:02:15> MLE_Alice Tx: message: 1|51|1743116535026723000
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|51|1743116535026723000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|52|1743116535026724000'
# 19:02:15> MLE_Alice Tx: message: 1|52|1743116535026724000
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 6.30 ms
# 19:02:15> Loss Rate: 56.00%
# 19:02:15> Duplicate Rate: 5.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 6.38 ms
# 19:02:15> Loss Rate: 55.00%
# 19:02:15> Duplicate Rate: 5.00%
# 19:02:15> MLE_Alice Tx: message: 1|53|1743116535026725000
# 19:02:15> packet loss
# 19:02:15> MLE_Alice Tx: message: 1|54|1743116535026726000
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|54|1743116535026726000'
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 6.46 ms
# 19:02:15> Loss Rate: 54.00%
# 19:02:15> Duplicate Rate: 5.00%
# 19:02:15> MLE_Alice Tx: message: 1|55|1743116535026728000
# 19:02:15> MLE_Alice Tx: message: 1|56|1743116535026729000
# 19:02:15> MLE_Alice Tx: message: 1|57|1743116535026730000
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|55|1743116535026728000'
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 6.54 ms
# 19:02:15> Loss Rate: 53.00%
# 19:02:15> Duplicate Rate: 5.00%
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|56|1743116535026729000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|57|1743116535026730000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|58|1743116535026731000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|59|1743116535026732000'
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 6.62 ms
# 19:02:15> Loss Rate: 52.00%
# 19:02:15> Duplicate Rate: 5.00%
# 19:02:15> MLE_Alice Tx: message: 1|58|1743116535026731000
# 19:02:15> MLE_Alice Tx: message: 1|59|1743116535026732000
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 6.70 ms
# 19:02:15> Loss Rate: 51.00%
# 19:02:15> Duplicate Rate: 5.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 6.78 ms
# 19:02:15> Loss Rate: 50.00%
# 19:02:15> Duplicate Rate: 5.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 6.85 ms
# 19:02:15> Loss Rate: 49.00%
# 19:02:15> Duplicate Rate: 5.00%
# 19:02:15> MLE_Alice Tx: message: 1|60|1743116535026734000
# 19:02:15> MLE_Alice Tx: message: 1|61|1743116535026735000
# 19:02:15> packet loss
# 19:02:15> MLE_Alice Tx: message: 1|62|1743116535026736000
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|60|1743116535026734000'
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 6.92 ms
# 19:02:15> Loss Rate: 48.00%
# 19:02:15> Duplicate Rate: 5.00%
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|62|1743116535026736000'
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 7.00 ms
# 19:02:15> Loss Rate: 47.00%
# 19:02:15> Duplicate Rate: 5.00%
# 19:02:15> MLE_Alice Tx: message: 1|63|1743116535026737000
# 19:02:15> MLE_Alice Tx: message: 1|64|1743116535026738000
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|63|1743116535026737000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|64|1743116535026738000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|65|1743116535026740000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|67|1743116535026742000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|68|1743116535026743000'
# 19:02:15> MLE_Alice Tx: message: 1|65|1743116535026740000
# 19:02:15> MLE_Alice Tx: message: 1|66|1743116535026741000
# 19:02:15> packet loss
# 19:02:15> MLE_Alice Tx: message: 1|67|1743116535026742000
# 19:02:15> MLE_Alice Tx: message: 1|68|1743116535026743000
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 7.07 ms
# 19:02:15> Loss Rate: 46.00%
# 19:02:15> Duplicate Rate: 5.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 7.14 ms
# 19:02:15> Loss Rate: 45.00%
# 19:02:15> Duplicate Rate: 5.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 7.21 ms
# 19:02:15> Loss Rate: 44.00%
# 19:02:15> Duplicate Rate: 5.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 7.28 ms
# 19:02:15> Loss Rate: 43.00%
# 19:02:15> Duplicate Rate: 5.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 7.35 ms
# 19:02:15> Loss Rate: 42.00%
# 19:02:15> Duplicate Rate: 5.00%
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|69|1743116535026745000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|70|1743116535026746000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|71|1743116535026747000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|72|1743116535026748000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|73|1743116535026750000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|74|1743116535026751000'
# 19:02:15> MLE_Alice Tx: message: 1|69|1743116535026745000
# 19:02:15> MLE_Alice Tx: message: 1|70|1743116535026746000
# 19:02:15> MLE_Alice Tx: message: 1|71|1743116535026747000
# 19:02:15> MLE_Alice Tx: message: 1|72|1743116535026748000
# 19:02:15> MLE_Alice Tx: message: 1|73|1743116535026750000
# 19:02:15> MLE_Alice Tx: message: 1|74|1743116535026751000
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 7.41 ms
# 19:02:15> Loss Rate: 41.00%
# 19:02:15> Duplicate Rate: 5.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 7.48 ms
# 19:02:15> Loss Rate: 40.00%
# 19:02:15> Duplicate Rate: 5.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 7.54 ms
# 19:02:15> Loss Rate: 39.00%
# 19:02:15> Duplicate Rate: 5.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 7.61 ms
# 19:02:15> Loss Rate: 38.00%
# 19:02:15> Duplicate Rate: 5.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 7.67 ms
# 19:02:15> Loss Rate: 37.00%
# 19:02:15> Duplicate Rate: 5.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 7.73 ms
# 19:02:15> Loss Rate: 36.00%
# 19:02:15> Duplicate Rate: 5.00%
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|75|1743116535026752000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|76|1743116535026753000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|77|1743116535026754000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|78|1743116535026756000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|79|1743116535026757000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|80|1743116535026758000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|81|1743116535026759000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|82|1743116535026760000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|83|1743116535026762000'
# 19:02:15> MLE_Alice Tx: message: 1|75|1743116535026752000
# 19:02:15> MLE_Alice Tx: message: 1|76|1743116535026753000
# 19:02:15> MLE_Alice Tx: message: 1|77|1743116535026754000
# 19:02:15> MLE_Alice Tx: message: 1|78|1743116535026756000
# 19:02:15> MLE_Alice Tx: message: 1|79|1743116535026757000
# 19:02:15> MLE_Alice Tx: message: 1|80|1743116535026758000
# 19:02:15> MLE_Alice Tx: message: 1|81|1743116535026759000
# 19:02:15> MLE_Alice Tx: message: 1|82|1743116535026760000
# 19:02:15> MLE_Alice Tx: message: 1|83|1743116535026762000
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 7.79 ms
# 19:02:15> Loss Rate: 35.00%
# 19:02:15> Duplicate Rate: 5.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 7.86 ms
# 19:02:15> Loss Rate: 34.00%
# 19:02:15> Duplicate Rate: 5.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 7.92 ms
# 19:02:15> Loss Rate: 33.00%
# 19:02:15> Duplicate Rate: 5.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 7.98 ms
# 19:02:15> Loss Rate: 32.00%
# 19:02:15> Duplicate Rate: 5.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 8.04 ms
# 19:02:15> Loss Rate: 31.00%
# 19:02:15> Duplicate Rate: 5.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 8.10 ms
# 19:02:15> Loss Rate: 30.00%
# 19:02:15> Duplicate Rate: 5.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 8.16 ms
# 19:02:15> Loss Rate: 29.00%
# 19:02:15> Duplicate Rate: 5.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 8.21 ms
# 19:02:15> Loss Rate: 28.00%
# 19:02:15> Duplicate Rate: 5.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 8.27 ms
# 19:02:15> Loss Rate: 27.00%
# 19:02:15> Duplicate Rate: 5.00%
# 19:02:15> MLE_Alice Tx: message: 1|84|1743116535026763000
# 19:02:15> MLE_Alice Tx: message: 1|85|1743116535026764000
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|84|1743116535026763000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|85|1743116535026764000'
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 8.33 ms
# 19:02:15> Loss Rate: 26.00%
# 19:02:15> Duplicate Rate: 5.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 8.39 ms
# 19:02:15> Loss Rate: 25.00%
# 19:02:15> Duplicate Rate: 5.00%
# 19:02:15> MLE_Alice Tx: message: 1|86|1743116535026765000
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|86|1743116535026765000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|87|1743116535026767000'
# 19:02:15> MLE_Alice Tx: message: 1|87|1743116535026767000
# 19:02:15> MLE_Alice Tx: message: 1|88|1743116535026768000
# 19:02:15> MLE_Alice Tx: message: 1|89|1743116535026769000
# 19:02:15> MLE_Alice Tx: message: 1|90|1743116535026770000
# 19:02:15> MLE_Alice Tx: message: 1|91|1743116535026771000
# 19:02:15> MLE_Alice Tx: message: 1|92|1743116535026773000
# 19:02:15> MLE_Alice Tx: message: 1|93|1743116535026774000
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 8.46 ms
# 19:02:15> Loss Rate: 24.00%
# 19:02:15> Duplicate Rate: 5.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 8.52 ms
# 19:02:15> Loss Rate: 23.00%
# 19:02:15> Duplicate Rate: 5.00%
# 19:02:15> MLE_Alice Tx: message: 1|94|1743116535026775000
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|88|1743116535026768000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|89|1743116535026769000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|90|1743116535026770000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|91|1743116535026771000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|92|1743116535026773000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|93|1743116535026774000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|94|1743116535026775000'
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 8.59 ms
# 19:02:15> Loss Rate: 22.00%
# 19:02:15> Duplicate Rate: 5.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 8.66 ms
# 19:02:15> Loss Rate: 21.00%
# 19:02:15> Duplicate Rate: 5.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 8.72 ms
# 19:02:15> Loss Rate: 20.00%
# 19:02:15> Duplicate Rate: 5.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 8.79 ms
# 19:02:15> Loss Rate: 19.00%
# 19:02:15> Duplicate Rate: 5.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 8.85 ms
# 19:02:15> Loss Rate: 18.00%
# 19:02:15> Duplicate Rate: 5.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 8.91 ms
# 19:02:15> Loss Rate: 17.00%
# 19:02:15> Duplicate Rate: 5.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 8.98 ms
# 19:02:15> Loss Rate: 16.00%
# 19:02:15> Duplicate Rate: 5.00%
# 19:02:15> MLE_Alice Tx: message: 1|95|1743116535026776000
# 19:02:15> MLE_Alice Tx: message: 1|96|1743116535026777000
# 19:02:15> MLE_Alice Tx: message: 1|97|1743116535026779000
# 19:02:15> MLE_Alice Tx: message: 1|98|1743116535026780000
# 19:02:15> MLE_Alice Tx: message: 1|99|1743116535026781000
# 19:02:15> packet loss
# 19:02:15> MLE_Alice Tx: message: 1|100|1743116535026782000
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|95|1743116535026776000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|96|1743116535026777000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|97|1743116535026779000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|98|1743116535026780000'
# 19:02:15 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|100|1743116535026782000'
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 9.04 ms
# 19:02:15> Loss Rate: 15.00%
# 19:02:15> Duplicate Rate: 5.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 9.11 ms
# 19:02:15> Loss Rate: 14.00%
# 19:02:15> Duplicate Rate: 5.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 9.18 ms
# 19:02:15> Loss Rate: 13.00%
# 19:02:15> Duplicate Rate: 5.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 9.24 ms
# 19:02:15> Loss Rate: 12.00%
# 19:02:15> Duplicate Rate: 5.00%
# 19:02:15> --- Measurement Results for MLE_Bob ---
# 19:02:15> Average Delay: 9.31 ms
# 19:02:15> Loss Rate: 11.00%
# 19:02:15> Duplicate Rate: 5.00%
# 19:02:18> Button Pressed
# 19:02:18> MLE_Bob Tx: message: 1|1|1743116538272001000
# 19:02:18> MLE_Bob Tx: message: 1|2|1743116538272046000
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|1|1743116538272001000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|2|1743116538272046000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|3|1743116538272050000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|5|1743116538272058000'
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 1.34 ms
# 19:02:18> Loss Rate: 99.00%
# 19:02:18> Duplicate Rate: 0.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 1.38 ms
# 19:02:18> Loss Rate: 98.00%
# 19:02:18> Duplicate Rate: 0.00%
# 19:02:18> MLE_Bob Tx: message: 1|3|1743116538272050000
# 19:02:18> MLE_Bob Tx: message: 1|4|1743116538272055000
# 19:02:18> packet loss
# 19:02:18> MLE_Bob Tx: message: 1|5|1743116538272058000
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 1.49 ms
# 19:02:18> Loss Rate: 97.00%
# 19:02:18> Duplicate Rate: 0.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 1.56 ms
# 19:02:18> Loss Rate: 96.00%
# 19:02:18> Duplicate Rate: 0.00%
# 19:02:18> MLE_Bob Tx: message: 1|6|1743116538272060000
# 19:02:18> MLE_Bob Tx: message: 1|7|1743116538272063000
# 19:02:18> MLE_Bob Tx: message: 1|8|1743116538272065000
# 19:02:18> MLE_Bob Tx: message: 1|9|1743116538272068000
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|6|1743116538272060000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|7|1743116538272063000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|8|1743116538272065000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|9|1743116538272068000'
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 2.21 ms
# 19:02:18> Loss Rate: 95.00%
# 19:02:18> Duplicate Rate: 0.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 2.66 ms
# 19:02:18> Loss Rate: 94.00%
# 19:02:18> Duplicate Rate: 0.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 2.99 ms
# 19:02:18> Loss Rate: 93.00%
# 19:02:18> Duplicate Rate: 0.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 3.25 ms
# 19:02:18> Loss Rate: 92.00%
# 19:02:18> Duplicate Rate: 0.00%
# 19:02:18> MLE_Bob Tx: message: 1|10|1743116538272071000
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|10|1743116538272071000'
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 3.63 ms
# 19:02:18> Loss Rate: 91.00%
# 19:02:18> Duplicate Rate: 0.00%
# 19:02:18> MLE_Bob Tx: message: 1|11|1743116538272074000
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|11|1743116538272074000'
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 3.96 ms
# 19:02:18> Loss Rate: 90.00%
# 19:02:18> Duplicate Rate: 0.00%
# 19:02:18> MLE_Bob Tx: message: 1|12|1743116538272076000
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|12|1743116538272076000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|12|1743116538272076000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|13|1743116538272079000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|14|1743116538272081000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|15|1743116538272084000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|15|1743116538272084000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|16|1743116538272086000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|17|1743116538272089000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|17|1743116538272089000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|18|1743116538272091000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|19|1743116538272094000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|20|1743116538272096000'
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 4.27 ms
# 19:02:18> Loss Rate: 89.00%
# 19:02:18> Duplicate Rate: 0.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 4.27 ms
# 19:02:18> Loss Rate: 89.00%
# 19:02:18> Duplicate Rate: 1.00%
# 19:02:18> Transmission Duplicated
# 19:02:18> MLE_Bob Tx: message: 1|13|1743116538272079000
# 19:02:18> MLE_Bob Tx: message: 1|14|1743116538272081000
# 19:02:18> MLE_Bob Tx: message: 1|15|1743116538272084000
# 19:02:18> Transmission Duplicated
# 19:02:18> MLE_Bob Tx: message: 1|16|1743116538272086000
# 19:02:18> MLE_Bob Tx: message: 1|17|1743116538272089000
# 19:02:18> Transmission Duplicated
# 19:02:18> MLE_Bob Tx: message: 1|18|1743116538272091000
# 19:02:18> MLE_Bob Tx: message: 1|19|1743116538272094000
# 19:02:18> MLE_Bob Tx: message: 1|20|1743116538272096000
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 4.58 ms
# 19:02:18> Loss Rate: 88.00%
# 19:02:18> Duplicate Rate: 1.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 4.85 ms
# 19:02:18> Loss Rate: 87.00%
# 19:02:18> Duplicate Rate: 1.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 5.08 ms
# 19:02:18> Loss Rate: 86.00%
# 19:02:18> Duplicate Rate: 1.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 5.08 ms
# 19:02:18> Loss Rate: 86.00%
# 19:02:18> Duplicate Rate: 2.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 5.30 ms
# 19:02:18> Loss Rate: 85.00%
# 19:02:18> Duplicate Rate: 2.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 5.48 ms
# 19:02:18> Loss Rate: 84.00%
# 19:02:18> Duplicate Rate: 2.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 5.48 ms
# 19:02:18> Loss Rate: 84.00%
# 19:02:18> Duplicate Rate: 3.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 5.66 ms
# 19:02:18> Loss Rate: 83.00%
# 19:02:18> Duplicate Rate: 3.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 5.81 ms
# 19:02:18> Loss Rate: 82.00%
# 19:02:18> Duplicate Rate: 3.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 5.96 ms
# 19:02:18> Loss Rate: 81.00%
# 19:02:18> Duplicate Rate: 3.00%
# 19:02:18> MLE_Bob Tx: message: 1|21|1743116538272099000
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|21|1743116538272099000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|22|1743116538272101000'
# 19:02:18> MLE_Bob Tx: message: 1|22|1743116538272101000
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 6.15 ms
# 19:02:18> Loss Rate: 80.00%
# 19:02:18> Duplicate Rate: 3.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 6.33 ms
# 19:02:18> Loss Rate: 79.00%
# 19:02:18> Duplicate Rate: 3.00%
# 19:02:18> MLE_Bob Tx: message: 1|23|1743116538272104000
# 19:02:18> MLE_Bob Tx: message: 1|24|1743116538272106000
# 19:02:18> MLE_Bob Tx: message: 1|25|1743116538272109000
# 19:02:18> MLE_Bob Tx: message: 1|26|1743116538272111000
# 19:02:18> MLE_Bob Tx: message: 1|27|1743116538272113000
# 19:02:18> MLE_Bob Tx: message: 1|28|1743116538272116000
# 19:02:18> MLE_Bob Tx: message: 1|29|1743116538272119000
# 19:02:18> MLE_Bob Tx: message: 1|30|1743116538272121000
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|23|1743116538272104000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|24|1743116538272106000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|25|1743116538272109000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|26|1743116538272111000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|27|1743116538272113000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|28|1743116538272116000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|29|1743116538272119000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|30|1743116538272121000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|31|1743116538272124000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|32|1743116538272126000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|33|1743116538272129000'
# 19:02:18> MLE_Bob Tx: message: 1|31|1743116538272124000
# 19:02:18> MLE_Bob Tx: message: 1|32|1743116538272126000
# 19:02:18> MLE_Bob Tx: message: 1|33|1743116538272129000
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 6.55 ms
# 19:02:18> Loss Rate: 78.00%
# 19:02:18> Duplicate Rate: 3.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 6.76 ms
# 19:02:18> Loss Rate: 77.00%
# 19:02:18> Duplicate Rate: 3.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 6.96 ms
# 19:02:18> Loss Rate: 76.00%
# 19:02:18> Duplicate Rate: 3.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 7.14 ms
# 19:02:18> Loss Rate: 75.00%
# 19:02:18> Duplicate Rate: 3.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 7.31 ms
# 19:02:18> Loss Rate: 74.00%
# 19:02:18> Duplicate Rate: 3.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 7.48 ms
# 19:02:18> Loss Rate: 73.00%
# 19:02:18> Duplicate Rate: 3.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 7.63 ms
# 19:02:18> Loss Rate: 72.00%
# 19:02:18> Duplicate Rate: 3.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 7.79 ms
# 19:02:18> Loss Rate: 71.00%
# 19:02:18> Duplicate Rate: 3.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 7.94 ms
# 19:02:18> Loss Rate: 70.00%
# 19:02:18> Duplicate Rate: 3.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 8.09 ms
# 19:02:18> Loss Rate: 69.00%
# 19:02:18> Duplicate Rate: 3.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 8.23 ms
# 19:02:18> Loss Rate: 68.00%
# 19:02:18> Duplicate Rate: 3.00%
# 19:02:18> MLE_Bob Tx: message: 1|34|1743116538272140000
# 19:02:18> MLE_Bob Tx: message: 1|35|1743116538272143000
# 19:02:18> MLE_Bob Tx: message: 1|36|1743116538272145000
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|34|1743116538272140000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|35|1743116538272143000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|36|1743116538272145000'
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 8.40 ms
# 19:02:18> Loss Rate: 67.00%
# 19:02:18> Duplicate Rate: 3.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 8.57 ms
# 19:02:18> Loss Rate: 66.00%
# 19:02:18> Duplicate Rate: 3.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 8.73 ms
# 19:02:18> Loss Rate: 65.00%
# 19:02:18> Duplicate Rate: 3.00%
# 19:02:18> MLE_Bob Tx: message: 1|37|1743116538272148000
# 19:02:18> MLE_Bob Tx: message: 1|38|1743116538272150000
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|37|1743116538272148000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|38|1743116538272150000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|39|1743116538272153000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|40|1743116538272155000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|41|1743116538272158000'
# 19:02:18> MLE_Bob Tx: message: 1|39|1743116538272153000
# 19:02:18> MLE_Bob Tx: message: 1|40|1743116538272155000
# 19:02:18> MLE_Bob Tx: message: 1|41|1743116538272158000
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 8.90 ms
# 19:02:18> Loss Rate: 64.00%
# 19:02:18> Duplicate Rate: 3.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 9.06 ms
# 19:02:18> Loss Rate: 63.00%
# 19:02:18> Duplicate Rate: 3.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 9.22 ms
# 19:02:18> Loss Rate: 62.00%
# 19:02:18> Duplicate Rate: 3.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 9.38 ms
# 19:02:18> Loss Rate: 61.00%
# 19:02:18> Duplicate Rate: 3.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 9.52 ms
# 19:02:18> Loss Rate: 60.00%
# 19:02:18> Duplicate Rate: 3.00%
# 19:02:18> Transmission Duplicated
# 19:02:18> MLE_Bob Tx: message: 1|42|1743116538272160000
# 19:02:18> MLE_Bob Tx: message: 1|43|1743116538272162000
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|41|1743116538272158000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|42|1743116538272160000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|43|1743116538272162000'
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 9.52 ms
# 19:02:18> Loss Rate: 60.00%
# 19:02:18> Duplicate Rate: 4.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 9.68 ms
# 19:02:18> Loss Rate: 59.00%
# 19:02:18> Duplicate Rate: 4.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 9.84 ms
# 19:02:18> Loss Rate: 58.00%
# 19:02:18> Duplicate Rate: 4.00%
# 19:02:18> Transmission Duplicated
# 19:02:18> MLE_Bob Tx: message: 1|44|1743116538272165000
# 19:02:18> MLE_Bob Tx: message: 1|45|1743116538272167000
# 19:02:18> MLE_Bob Tx: message: 1|46|1743116538272170000
# 19:02:18> MLE_Bob Tx: message: 1|47|1743116538272172000
# 19:02:18> MLE_Bob Tx: message: 1|48|1743116538272175000
# 19:02:18> MLE_Bob Tx: message: 1|49|1743116538272177000
# 19:02:18> MLE_Bob Tx: message: 1|50|1743116538272180000
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|43|1743116538272162000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|44|1743116538272165000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|45|1743116538272167000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|46|1743116538272170000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|47|1743116538272172000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|48|1743116538272175000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|49|1743116538272177000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|50|1743116538272180000'
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 9.84 ms
# 19:02:18> Loss Rate: 58.00%
# 19:02:18> Duplicate Rate: 5.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 10.00 ms
# 19:02:18> Loss Rate: 57.00%
# 19:02:18> Duplicate Rate: 5.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 10.16 ms
# 19:02:18> Loss Rate: 56.00%
# 19:02:18> Duplicate Rate: 5.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 10.32 ms
# 19:02:18> Loss Rate: 55.00%
# 19:02:18> Duplicate Rate: 5.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 10.47 ms
# 19:02:18> Loss Rate: 54.00%
# 19:02:18> Duplicate Rate: 5.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 10.62 ms
# 19:02:18> Loss Rate: 53.00%
# 19:02:18> Duplicate Rate: 5.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 10.77 ms
# 19:02:18> Loss Rate: 52.00%
# 19:02:18> Duplicate Rate: 5.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 10.91 ms
# 19:02:18> Loss Rate: 51.00%
# 19:02:18> Duplicate Rate: 5.00%
# 19:02:18> MLE_Bob Tx: message: 1|51|1743116538272182000
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|51|1743116538272182000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|52|1743116538272185000'
# 19:02:18> MLE_Bob Tx: message: 1|52|1743116538272185000
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 11.05 ms
# 19:02:18> Loss Rate: 50.00%
# 19:02:18> Duplicate Rate: 5.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 11.19 ms
# 19:02:18> Loss Rate: 49.00%
# 19:02:18> Duplicate Rate: 5.00%
# 19:02:18> MLE_Bob Tx: message: 1|53|1743116538272187000
# 19:02:18> MLE_Bob Tx: message: 1|54|1743116538272190000
# 19:02:18> MLE_Bob Tx: message: 1|55|1743116538272192000
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|53|1743116538272187000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|54|1743116538272190000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|55|1743116538272192000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|56|1743116538272194000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|57|1743116538272197000'
# 19:02:18> MLE_Bob Tx: message: 1|56|1743116538272194000
# 19:02:18> MLE_Bob Tx: message: 1|57|1743116538272197000
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 11.34 ms
# 19:02:18> Loss Rate: 48.00%
# 19:02:18> Duplicate Rate: 5.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 11.48 ms
# 19:02:18> Loss Rate: 47.00%
# 19:02:18> Duplicate Rate: 5.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 11.61 ms
# 19:02:18> Loss Rate: 46.00%
# 19:02:18> Duplicate Rate: 5.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 11.74 ms
# 19:02:18> Loss Rate: 45.00%
# 19:02:18> Duplicate Rate: 5.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 11.87 ms
# 19:02:18> Loss Rate: 44.00%
# 19:02:18> Duplicate Rate: 5.00%
# 19:02:18> MLE_Bob Tx: message: 1|58|1743116538272199000
# 19:02:18> packet loss
# 19:02:18> MLE_Bob Tx: message: 1|59|1743116538272202000
# 19:02:18> MLE_Bob Tx: message: 1|60|1743116538272204000
# 19:02:18> MLE_Bob Tx: message: 1|61|1743116538272207000
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|59|1743116538272202000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|60|1743116538272204000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|61|1743116538272207000'
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 12.00 ms
# 19:02:18> Loss Rate: 43.00%
# 19:02:18> Duplicate Rate: 5.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 12.12 ms
# 19:02:18> Loss Rate: 42.00%
# 19:02:18> Duplicate Rate: 5.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 12.25 ms
# 19:02:18> Loss Rate: 41.00%
# 19:02:18> Duplicate Rate: 5.00%
# 19:02:18> MLE_Bob Tx: message: 1|62|1743116538272209000
# 19:02:18> MLE_Bob Tx: message: 1|63|1743116538272212000
# 19:02:18> MLE_Bob Tx: message: 1|64|1743116538272214000
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|62|1743116538272209000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|63|1743116538272212000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|64|1743116538272214000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|65|1743116538272217000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|66|1743116538272219000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|67|1743116538272221000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|68|1743116538272224000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|69|1743116538272226000'
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 12.37 ms
# 19:02:18> Loss Rate: 40.00%
# 19:02:18> Duplicate Rate: 5.00%
# 19:02:18> MLE_Bob Tx: message: 1|65|1743116538272217000
# 19:02:18> MLE_Bob Tx: message: 1|66|1743116538272219000
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 12.49 ms
# 19:02:18> Loss Rate: 39.00%
# 19:02:18> Duplicate Rate: 5.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 12.61 ms
# 19:02:18> Loss Rate: 38.00%
# 19:02:18> Duplicate Rate: 5.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 12.73 ms
# 19:02:18> Loss Rate: 37.00%
# 19:02:18> Duplicate Rate: 5.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 12.84 ms
# 19:02:18> Loss Rate: 36.00%
# 19:02:18> Duplicate Rate: 5.00%
# 19:02:18> MLE_Bob Tx: message: 1|67|1743116538272221000
# 19:02:18> MLE_Bob Tx: message: 1|68|1743116538272224000
# 19:02:18> MLE_Bob Tx: message: 1|69|1743116538272226000
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 12.95 ms
# 19:02:18> Loss Rate: 35.00%
# 19:02:18> Duplicate Rate: 5.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 13.06 ms
# 19:02:18> Loss Rate: 34.00%
# 19:02:18> Duplicate Rate: 5.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 13.16 ms
# 19:02:18> Loss Rate: 33.00%
# 19:02:18> Duplicate Rate: 5.00%
# 19:02:18> MLE_Bob Tx: message: 1|70|1743116538272229000
# 19:02:18> MLE_Bob Tx: message: 1|71|1743116538272231000
# 19:02:18> MLE_Bob Tx: message: 1|72|1743116538272234000
# 19:02:18> MLE_Bob Tx: message: 1|73|1743116538272236000
# 19:02:18> MLE_Bob Tx: message: 1|74|1743116538272239000
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|70|1743116538272229000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|71|1743116538272231000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|72|1743116538272234000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|73|1743116538272236000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|74|1743116538272239000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|75|1743116538272241000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|76|1743116538272243000'
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 13.28 ms
# 19:02:18> Loss Rate: 32.00%
# 19:02:18> Duplicate Rate: 5.00%
# 19:02:18> MLE_Bob Tx: message: 1|75|1743116538272241000
# 19:02:18> MLE_Bob Tx: message: 1|76|1743116538272243000
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 13.39 ms
# 19:02:18> Loss Rate: 31.00%
# 19:02:18> Duplicate Rate: 5.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 13.49 ms
# 19:02:18> Loss Rate: 30.00%
# 19:02:18> Duplicate Rate: 5.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 13.60 ms
# 19:02:18> Loss Rate: 29.00%
# 19:02:18> Duplicate Rate: 5.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 13.70 ms
# 19:02:18> Loss Rate: 28.00%
# 19:02:18> Duplicate Rate: 5.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 13.81 ms
# 19:02:18> Loss Rate: 27.00%
# 19:02:18> Duplicate Rate: 5.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 13.91 ms
# 19:02:18> Loss Rate: 26.00%
# 19:02:18> Duplicate Rate: 5.00%
# 19:02:18> MLE_Bob Tx: message: 1|77|1743116538272246000
# 19:02:18> MLE_Bob Tx: message: 1|78|1743116538272248000
# 19:02:18> MLE_Bob Tx: message: 1|79|1743116538272251000
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|77|1743116538272246000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|78|1743116538272248000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|79|1743116538272251000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|80|1743116538272253000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|81|1743116538272256000'
# 19:02:18> MLE_Bob Tx: message: 1|80|1743116538272253000
# 19:02:18> MLE_Bob Tx: message: 1|81|1743116538272256000
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 14.01 ms
# 19:02:18> Loss Rate: 25.00%
# 19:02:18> Duplicate Rate: 5.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 14.11 ms
# 19:02:18> Loss Rate: 24.00%
# 19:02:18> Duplicate Rate: 5.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 14.21 ms
# 19:02:18> Loss Rate: 23.00%
# 19:02:18> Duplicate Rate: 5.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 14.31 ms
# 19:02:18> Loss Rate: 22.00%
# 19:02:18> Duplicate Rate: 5.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 14.41 ms
# 19:02:18> Loss Rate: 21.00%
# 19:02:18> Duplicate Rate: 5.00%
# 19:02:18> MLE_Bob Tx: message: 1|82|1743116538272258000
# 19:02:18> MLE_Bob Tx: message: 1|83|1743116538272260000
# 19:02:18> packet loss
# 19:02:18> MLE_Bob Tx: message: 1|84|1743116538272263000
# 19:02:18> MLE_Bob Tx: message: 1|85|1743116538272265000
# 19:02:18> MLE_Bob Tx: message: 1|86|1743116538272268000
# 19:02:18> MLE_Bob Tx: message: 1|87|1743116538272270000
# 19:02:18> MLE_Bob Tx: message: 1|88|1743116538272273000
# 19:02:18> MLE_Bob Tx: message: 1|89|1743116538272275000
# 19:02:18> MLE_Bob Tx: message: 1|90|1743116538272278000
# 19:02:18> MLE_Bob Tx: message: 1|91|1743116538272280000
# 19:02:18> MLE_Bob Tx: message: 1|92|1743116538272282000
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|82|1743116538272258000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|84|1743116538272263000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|85|1743116538272265000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|86|1743116538272268000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|87|1743116538272270000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|88|1743116538272273000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|89|1743116538272275000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|90|1743116538272278000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|91|1743116538272280000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|92|1743116538272282000'
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 14.52 ms
# 19:02:18> Loss Rate: 20.00%
# 19:02:18> Duplicate Rate: 5.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 14.63 ms
# 19:02:18> Loss Rate: 19.00%
# 19:02:18> Duplicate Rate: 5.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 14.73 ms
# 19:02:18> Loss Rate: 18.00%
# 19:02:18> Duplicate Rate: 5.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 14.84 ms
# 19:02:18> Loss Rate: 17.00%
# 19:02:18> Duplicate Rate: 5.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 14.94 ms
# 19:02:18> Loss Rate: 16.00%
# 19:02:18> Duplicate Rate: 5.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 15.05 ms
# 19:02:18> Loss Rate: 15.00%
# 19:02:18> Duplicate Rate: 5.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 15.15 ms
# 19:02:18> Loss Rate: 14.00%
# 19:02:18> Duplicate Rate: 5.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 15.25 ms
# 19:02:18> Loss Rate: 13.00%
# 19:02:18> Duplicate Rate: 5.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 15.34 ms
# 19:02:18> Loss Rate: 12.00%
# 19:02:18> Duplicate Rate: 5.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 15.44 ms
# 19:02:18> Loss Rate: 11.00%
# 19:02:18> Duplicate Rate: 5.00%
# 19:02:18> MLE_Bob Tx: message: 1|93|1743116538272285000
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|93|1743116538272285000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|94|1743116538272288000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|95|1743116538272291000'
# 19:02:18> MLE_Bob Tx: message: 1|94|1743116538272288000
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 15.54 ms
# 19:02:18> Loss Rate: 10.00%
# 19:02:18> Duplicate Rate: 5.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 15.64 ms
# 19:02:18> Loss Rate: 9.00%
# 19:02:18> Duplicate Rate: 5.00%
# 19:02:18> MLE_Bob Tx: message: 1|95|1743116538272291000
# 19:02:18> MLE_Bob Tx: message: 1|96|1743116538272294000
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 15.73 ms
# 19:02:18> Loss Rate: 8.00%
# 19:02:18> Duplicate Rate: 5.00%
# 19:02:18> MLE_Bob Tx: message: 1|97|1743116538272296000
# 19:02:18> packet loss
# 19:02:18> MLE_Bob Tx: message: 1|98|1743116538272299000
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|96|1743116538272294000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|98|1743116538272299000'
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 15.83 ms
# 19:02:18> Loss Rate: 7.00%
# 19:02:18> Duplicate Rate: 5.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 15.93 ms
# 19:02:18> Loss Rate: 6.00%
# 19:02:18> Duplicate Rate: 5.00%
# 19:02:18> MLE_Bob Tx: message: 1|99|1743116538272302000
# 19:02:18> MLE_Bob Tx: message: 1|100|1743116538272304000
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|99|1743116538272302000'
# 19:02:18 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|100|1743116538272304000'
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 16.03 ms
# 19:02:18> Loss Rate: 5.00%
# 19:02:18> Duplicate Rate: 5.00%
# 19:02:18> --- Measurement Results for MLE_Alice ---
# 19:02:18> Average Delay: 16.13 ms
# 19:02:18> Loss Rate: 4.00%
# 19:02:18> Duplicate Rate: 5.00%
