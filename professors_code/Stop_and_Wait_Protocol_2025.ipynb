# %%
import time
import socket
from queue import Queue 
from threading import Thread, Condition
from ipywidgets import widgets
from IPython.display import display
import random

# %%
class EXP_Output:
    def __init__(self):
        #self.out = widgets.Output(layout={'border': '1px solid black'})
        #display(self.out)
        #with self.out:
        #print("Experiment outputs")

        self.Queue_Print = Queue()
        self.thread = Thread(target=self.loop_Print)
        self.thread.start()

    def print(self, msg):
        text_out = time.strftime("%H:%M:%S", time.localtime()) + "> "
        self.Queue_Print.put(text_out+msg)

    def loop_Print(self):
        while True:
            msg = self.Queue_Print.get()
            #with self.out:
            print(msg)
            self.Queue_Print.task_done()

# %%
class ALE_TextInput:
    
    def __init__(self, exp_out):
        
        self.Queue_User = Queue()
        self.exp_out = exp_out

        # Create a text input widget
        self.Text = widgets.Text(
                        value='',
                        placeholder='Type something and press enter',
                        description='To send:',
                        disabled=False
                    )

        # create a button object
        self.Botton =  widgets.Button(
                            description='Submit',
                            disabled=False,
                            button_style='', 
                            tooltip='Click me to submit a string',
                        )

        # Define a function to handle the click action on the button
        def on_submit_button_clicked(b):

            global thread_running
            
            msg = self.Text.value
            #self.exp_out.print("ALE_0: received input: "+str(msg))
                
            if thread_running == True:
                if msg == "end":
                    thread_running = False
                
                for i in range(20):
                    self.Queue_User.put(msg+str(i))

            self.Text.value = ''  # Clear the input field after submission

        # Attach the event to the button
        self.Botton.on_click(on_submit_button_clicked)
        
        # Display the widgets
        display(self.Text, self.Botton)
        
    # to get a message from user queue. this function can block the thread
    def get(self):
        return self.Queue_User.get()

# %%
class ALE_TR:
    
    def __init__(self, name, upper_Tx, lower_TR, exp_out):
        
        self.Name     = name
        self.Upper_Tx = upper_Tx  # must provide get()
        self.Lower_TR = lower_TR  # must provide send(msg), and receive()
        self.exp_out  = exp_out
        
    def loop_Tx(self):

        global thread_running
        c = 0
        self.exp_out.print(self.Name + ": loop_Tx starting")
    
        while (thread_running == True):

            c = c + 1

            # get text from Upper_Tx, which must provide a get method
            # this thread is blocked here
            msg = self.Upper_Tx.get()
            
            text_out = self.Name + " Tx: message " + str(c) + ": " + str(msg)
            self.exp_out.print(text_out)

            # add the text to the queue
            self.Lower_TR.send(msg)
            
    def loop_Rx(self):
        
        global thread_running
        c = 0
        self.exp_out.print(self.Name + ": loop_Rx starting")
    
        while (thread_running == True):

            c = c + 1

            # get message from a lower layer
            # this thread is blocked here
            msg = self.Lower_TR.receive()
            
            text_out = self.Name + " Rx: message " + str(c) + ": " + str(msg)
            self.exp_out.print(text_out)

# %%
# state of DLE
STATE_READY_TO_SEND = 0 # ready to send a packet to the DLE entity in another node through lower layer
STATE_WAITING_ACK   = 1 # waiting for ACK from the DLE entity in another node

# events of DLE
EVENT_UPPER_TX  = 0 # upper layer wants to send a packet
EVENT_LOWER_DAT = 1 # lower layer forwards an incoming data packet
EVENT_LOWER_ACK = 2 # lower layer forwards an incoming data packet
EVENT_TIMEOUT   = 3 # timer timeout
        
class DLE_TR_FSM:
    
    def __init__(self, name, lower_TR, exp_out):
        
        self.Name      = name
        self.Lower_TR  = lower_TR   # must provide send(msg) and receive()
        self.Queue_Tx  = Queue()
        self.Queue_Rx  = Queue()
        self.exp_out   = exp_out
        
        # create a queue for Finite State Machine
        self.Queue_FSM = Queue()
        
        # create a flag = condition to start sending
        self.cv_TxOp = Condition()
        self.TxOp    = True

        # init state to STATE_WAITING_UPPER
        self.State = STATE_READY_TO_SEND
        
        self.Procedure = [[self.FSM_upper_Tx, self.FSM_abnormal],
                          [self.FSM_lower_Rx, self.FSM_lower_Rx],
                          [self.FSM_abnormal, self.FSM_lower_Rx_ack],
                          [self.FSM_abnormal, self.FSM_timeout]] 
        

        # new features for retransmission
        # timer
        self.cv_Timer      = Condition()
        self.timer_active  = False
        self.timer_counter = 0
        
        # transmission 
        self.tx_buffer  = ''
        self.tx_seq_num = '0'
        
        # reception
        self.tx_ack_num = '0'
        
        
    def loop_Tx(self):

        global thread_running
        c = 0
        self.exp_out.print(self.Name + ": loop_Tx starting")
    
        while (thread_running == True):

            # waiting for the ready to sent signal
            with self.cv_TxOp: 
                while (self.TxOp != True): 
                    self.cv_TxOp.wait()
            
                self.TxOp = False
                
                c = c + 1

                # get a message from queue
                msg = self.Queue_Tx.get()
                text_out = self.Name + " Tx: message " + str(c) + ": " + str(msg)
                self.exp_out.print(text_out)
            
                self.event_add(EVENT_UPPER_TX, msg) 

    def loop_Rx(self):
        
        global thread_running
        c = 0
        self.exp_out.print(self.Name + ": loop_Rx starting")
    
        while (thread_running == True):

            c = c + 1

            # get message from a lower layer
            # this thread is blocked here
            msg = self.Lower_TR.receive()
            
            text_out = self.Name + " Rx: message " + str(c) + ": " + str(msg)
            self.exp_out.print(text_out)
            
            # add an event for FSM, assuming that msg is a sequence of bytes
            msg_type = msg[0]
            if (msg_type == '0'):
                self.event_add(EVENT_LOWER_DAT, msg[1:])
            elif (msg_type == '1'):
                self.event_add(EVENT_LOWER_ACK, msg[1:])
            else:
                text_out = self.Name + " Rx: message type unknown " + msg_type
                self.exp_out.print(text_out)

    def receive(self):
        return self.Queue_Rx.get()
    
    def send(self, msg):
        self.Queue_Tx.put(msg)
        
    def event_add(self, ev_type, msg):
        
        # preparing an event
        if (isinstance(msg, str)):
            msg = msg.encode()
        
        # the event is a sequence of bytes
        event = ev_type.to_bytes(1, "big")+msg
        
        # add event to queue
        self.Queue_FSM.put(event)        
        

    def loop_FSM(self):
        
        global thread_running
        self.exp_out.print(self.Name + ": loop_FSM starting")
        
        while (thread_running == True):
            
            # get the next event
            event = self.Queue_FSM.get()
            
            ev_type = event[0]
            
            text_out = self.Name + " FSM: state: " + str(self.State)+" event type: " + str(ev_type)
            self.exp_out.print(text_out)
            
            # process the event
            msg = event[1:].decode('utf-8') # message becomes a string
            self.Procedure[ev_type][self.State](msg)
        
    def FSM_abnormal(self, msg):
        
        text_out = self.Name + " FSM: error! " + msg
        self.exp_out.print(text_out)
    
    def FSM_upper_Tx(self, msg):   
        
        text_out = self.Name + " FSM: to send: " + msg
        self.exp_out.print(text_out)

        # buffer the message (for retransmission)
        self.tx_buffer = msg
        
        # prepare to send a data message
        msg = '0' + self.tx_seq_num + msg     # inicating a new packet and its sequence number
        self.Lower_TR.send(msg)

        # waiting for ACK
        self.State = STATE_WAITING_ACK
        
        # start timer
        with self.cv_Timer:
            self.timer_active  = True
            self.timer_counter = 10
            self.cv_Timer.notify()    
    
    def FSM_lower_Rx(self, msg):

        # get the sequence number
        seq = msg[0]
        msg = msg[1:]
        
        # received a new data packet        
        text_out = self.Name + " FSM: received: " + msg
        self.exp_out.print(text_out)

        if (seq == self.tx_ack_num):
            
            # put the message in a receiving queue
            self.Queue_Rx.put(msg)
            
            self.tx_ack_num = chr(ord(self.tx_ack_num) + 1)
            if (self.tx_ack_num == chr(ord('9') + 1)):
                self.tx_ack_num = '0'
        
        else:
            text_out  = self.Name + " FSM: received received frame " + seq
            text_out += " but expected " + self.tx_ack_num
            self.exp_out.print(text_out)
            

        # to send an ACK
        self.Lower_TR.send('1'+seq)

                
    def FSM_lower_Rx_ack(self, msg):
        
        ack = msg[0] # get the ack number
        if (ack != self.tx_seq_num):
            
            # the received ack does not match the seq
            text_out = "ACK # " + ack + " does not match local seq # " + self.tx_seq_num
            self.exp_out.print(text_out)
            return

        # stop timer
        self.timer_active = False
        
        # inc the seq
        self.tx_seq_num = chr(ord(self.tx_seq_num) + 1)
        if (self.tx_seq_num == chr(ord('9') + 1)):
                self.tx_seq_num = '0'
        
        # ready to send the next upper layer packet
        with self.cv_TxOp:
            self.State = STATE_READY_TO_SEND
            self.TxOp  = True
            self.cv_TxOp.notify()
            
    def FSM_timeout(self, msg):
        
        text_out = self.Name + " FSM: to resend frame " + self.tx_seq_num + " " + self.tx_buffer
        self.exp_out.print(text_out)
        
        # prepare to send a data message
        msg = '0' + self.tx_seq_num + self.tx_buffer     # inicating a new packet and its sequence number
        self.Lower_TR.send(msg)
        
        # start timer
        with self.cv_Timer:
            self.timer_active  = True
            self.timer_counter = 10
            self.cv_Timer.notify()

    def loop_timer(self):
        
        global thread_running
        self.exp_out.print(self.Name + ": loop_Timer starting")
        
        while (thread_running == True):
            
            with self.cv_Timer: 
                while (self.timer_active == False): 
                    self.cv_Timer.wait() 
            
                time.sleep(0.5)

                if (self.timer_counter == 0):
                    # add an event for timeout
                    self.event_add(EVENT_TIMEOUT, 'x')
                    self.timer_active = False

                else:
                    self.timer_counter = self.timer_counter - 1

# %%
class PLE_TR:

    def __init__(self, name, Socket, AP_Tx, AP_Rx, exp_out):
        
        self.Name      = name
        self.Socket    = Socket
        self.AP_Tx     = AP_Tx
        self.AP_Rx     = AP_Rx
        self.Queue_Tx  = Queue()
        self.Queue_Rx  = Queue()
        self.exp_out   = exp_out
        
    def loop_Tx(self):
        
        global thread_running
        self.exp_out.print(self.Name + ": loop_Tx starting")
    
        while (thread_running == True):
        
            # get a message from queue
            msg = self.Queue_Tx.get()
            
            text_out = self.Name + " Tx: message: " + str(msg)
            self.exp_out.print(text_out)
            
            # sending the message using socket
            msg_bytes = str.encode(msg)
            if (random.random() < 0.1):
                self.exp_out.print("packet loss")

            elif (random.random() < 0.05):
                self.Socket.sendto(msg_bytes, self.AP_Tx)
                self.Socket.sendto(msg_bytes, self.AP_Tx)
                self.exp_out.print("Transmission Duplicated")
            else:
                # sending the message using socket
                self.Socket.sendto(msg_bytes, self.AP_Tx)

    def loop_Rx(self):
        
        global thread_running
        global bufferSize
        self.exp_out.print(self.Name + ": loop_Rx starting")
    
        # binding the socket with the IP and port
        self.Socket.bind(self.AP_Rx)
        
        while (thread_running == True):
        
            # get a message from socket, this thread is blocked here
            msg_addr = self.Socket.recvfrom(bufferSize)

            # Random delay ranging from 0 - 2 seconds.
            delay = random.uniform(0, 2)
            time.sleep(delay)
    
            msg  = msg_addr[0].decode('utf-8')
            addr = msg_addr[1]
            
            text_out = self.Name + " Rx: from " + str(addr) + ": " + str(msg)
            self.exp_out.print(text_out)
            
            self.Queue_Rx.put(msg)
            
    def send(self, msg):
        self.Queue_Tx.put(msg)
        
    def receive(self):
        return self.Queue_Rx.get()

# %%
class MLE_TR:
    def __init__(self, lower_layer, experiment_id=1):
        self.lower_layer = lower_layer
        self.experiment_id = experiment_id
        self.sent_messages = {}
        self.received_messages = {}
        
        self.button = widgets.Button(description="Run Measurment Experiment")
        self.button.on_click(self.send_messages_callback)
        display(self.button)

    def send_messages_callback(self, b):
        """
        Callback function triggered by the button click.
        Sends 100 messages with an unique ID and timesamp
        """

        for msg_id in range(1, 101):
            timestamp = time.time_ns()
            packet = f"{self.experiment_id},{msg_id},{timestamp}" # Construct the package format
            self.sent_messages[msg_id] = timestamp
            self.lower_layer.send(packet)
            print(f"Sent: {packet}")

    def loop_Rx(self):
        """
        Loop that continously receives messages from the lower layer
        For each received packet, it:
            - Parses the packet to extract the data
            - Calculates the delay between when the package was sent and received
            - Tracks duplicates received packets

        Once 100 unique messages are received, it calcules:
            - The average delay
            - The loss rate (if missing, 20% chance of that happening)
            - Duplicate rate, if any
        """
        delays = []
        total_expected = 100

        while True:
            packet = self.lower_layer.receive()
            try:
                experiment_id, message_id, sent_time = packet.split(',')
                message_id = int(message_id)
                sent_time = int(sent_time)
            except Exception as e:
                print(f"Error - {e} - parsing packet: ", packet)
                continue

            # Compute the delay in milliseconds using the current timestamp
            current_time = time.time_ns()
            delay_ms = (current_time - sent_time) / 1e6
            delays.append(delay_ms)
            
            # Count how many times this message ID is received (for duplicate detection)
            self.received_messages[message_id] = self.received_messages.get(message_id, 0) + 1
            print(f"Received: {packet}, Delay: {delay_ms:.2f} ms")
            
            # Optionally break out of the loop when all 100 unique messages have been received.
            if len(self.received_messages) == total_expected:
                break

        # Calculate average delay across all received messages
        avg_delay = sum(delays) / len(delays) if delays else 0
        
        # Compute loss rate based on missing unique message IDs
        loss_rate = (total_expected - len(self.received_messages)) / total_expected
        
        # Compute duplicate rate by summing up extra receptions beyond the first for each message
        duplicate_count = sum(count - 1 for count in self.received_messages.values() if count > 1)
        duplicate_rate = duplicate_count / total_expected
        
        print(f"Average Delay: {avg_delay:.2f} ms")
        print(f"Loss Rate: {loss_rate * 100:.2f}%")
        print(f"Duplicate Rate: {duplicate_rate * 100:.2f}%")

# %%
thread_running = False
bufferSize = 1024

# (0) creating an output object
exp_out = EXP_Output()

# (1) create physical layer entities
AP_local_1  = ("127.0.0.1", 30000)
AP_remote_1 = ("127.0.0.1", 31111)
Socket_1    = socket.socket(family=socket.AF_INET, type=socket.SOCK_DGRAM)
PLE_1       = PLE_TR("PLE_Alice", Socket_1, AP_remote_1, AP_local_1, exp_out)

# (2) create date link layer entities
DLE_1 = DLE_TR_FSM("DLE_Alice", PLE_1, exp_out)

# (3) create application layer entities
ALE_0 = ALE_TextInput(exp_out)
ALE_1 = ALE_TR("ALE_Alice", ALE_0, DLE_1, exp_out)
# Out:
# Text(value='', description='To send:', placeholder='Type something and press enter')
# Button(description='Submit', style=ButtonStyle(), tooltip='Click me to submit a string')

# %%
# (4) create physical layer entities
AP_local_2  = ("127.0.0.1", 31111)
AP_remote_2 = ("127.0.0.1", 30000)
Socket_2    = socket.socket(family=socket.AF_INET, type=socket.SOCK_DGRAM)
PLE_2       = PLE_TR("PLE_Bob", Socket_2, AP_remote_2, AP_local_2, exp_out)

# (5) create date link layer entities
DLE_2 = DLE_TR_FSM("DLE_Bob", PLE_2, exp_out)

# (6) create application layer entities
ALE_3 = ALE_TextInput(exp_out)
ALE_2 = ALE_TR("ALE_Bob", ALE_3, DLE_2, exp_out)
# Out:
# Text(value='', description='To send:', placeholder='Type something and press enter')
# Button(description='Submit', style=ButtonStyle(), tooltip='Click me to submit a string')

# %%
# (7) create measurement layer entities
MLE_1 = MLE_TR(DLE_1, experiment_id=1)
# Out:
# Button(description='Run Measurment Experiment', style=ButtonStyle())
# Sent: 1,1,1742843977193503000
# Sent: 1,2,1742843977193555000
# Sent: 1,3,1742843977193564000
# Sent: 1,4,1742843977193570000
# Sent: 1,5,1742843977193574000
# Sent: 1,6,1742843977193579000
# Sent: 1,7,1742843977193583000
# Sent: 1,8,1742843977193588000
# Sent: 1,9,1742843977193592000
# Sent: 1,10,1742843977193598000
# Sent: 1,11,1742843977193602000
# Sent: 1,12,1742843977193607000
# Sent: 1,13,1742843977193611000
# Sent: 1,14,1742843977193615000
# Sent: 1,15,1742843977193619000
# Sent: 1,16,1742843977193624000
# Sent: 1,17,1742843977193628000
# Sent: 1,18,1742843977193632000
# Sent: 1,19,1742843977193635000
# Sent: 1,20,1742843977193640000
# Sent: 1,21,1742843977193644000
# Sent: 1,22,1742843977193648000
# Sent: 1,23,1742843977193653000
# Sent: 1,24,1742843977193657000
# Sent: 1,25,1742843977193661000
# Sent: 1,26,1742843977193665000
# Sent: 1,27,1742843977193669000
# Sent: 1,28,1742843977193673000
# Sent: 1,29,1742843977193677000
# Sent: 1,30,1742843977193681000
# Sent: 1,31,1742843977193686000
# Sent: 1,32,1742843977193690000
# Sent: 1,33,1742843977193694000
# Sent: 1,34,1742843977193698000
# Sent: 1,35,1742843977193702000
# Sent: 1,36,1742843977193706000
# Sent: 1,37,1742843977193710000
# Sent: 1,38,1742843977193713000
# Sent: 1,39,1742843977193718000
# Sent: 1,40,1742843977193721000
# Sent: 1,41,1742843977193725000
# Sent: 1,42,1742843977193730000
# Sent: 1,43,1742843977193734000
# Sent: 1,44,1742843977193742000
# Sent: 1,45,1742843977193745000
# Sent: 1,46,1742843977193749000
# Sent: 1,47,1742843977193753000
# Sent: 1,48,1742843977193757000
# Sent: 1,49,1742843977193765000
# Sent: 1,50,1742843977193769000
# Sent: 1,51,1742843977193773000
# Sent: 1,52,1742843977193777000
# Sent: 1,53,1742843977193781000
# Sent: 1,54,1742843977193785000
# Sent: 1,55,1742843977193788000
# Sent: 1,56,1742843977193792000
# Sent: 1,57,1742843977193796000
# Sent: 1,58,1742843977193800000
# Sent: 1,59,1742843977193804000
# Sent: 1,60,1742843977193808000
# Sent: 1,61,1742843977193812000
# Sent: 1,62,1742843977193816000
# Sent: 1,63,1742843977193819000
# Sent: 1,64,1742843977193823000
# Sent: 1,65,1742843977193827000
# Sent: 1,66,1742843977193831000
# Sent: 1,67,1742843977193835000
# Sent: 1,68,1742843977193839000
# Sent: 1,69,1742843977193843000
# Sent: 1,70,1742843977193847000
# Sent: 1,71,1742843977193851000
# Sent: 1,72,1742843977193855000
# Sent: 1,73,1742843977193858000
# Sent: 1,74,1742843977193862000
# Sent: 1,75,1742843977193866000
# Sent: 1,76,1742843977193870000
# Sent: 1,77,1742843977193874000
# Sent: 1,78,1742843977193878000
# Sent: 1,79,1742843977193882000
# Sent: 1,80,1742843977193886000
# Sent: 1,81,1742843977193889000
# Sent: 1,82,1742843977193893000
# Sent: 1,83,1742843977193897000
# Sent: 1,84,1742843977193901000
# Sent: 1,85,1742843977193905000
# Sent: 1,86,1742843977193909000
# Sent: 1,87,1742843977193914000
# Sent: 1,88,1742843977193918000
# Sent: 1,89,1742843977193922000
# Sent: 1,90,1742843977193926000
# Sent: 1,91,1742843977193929000
# Sent: 1,92,1742843977193933000
# Sent: 1,93,1742843977193937000
# Sent: 1,94,1742843977193941000
# Sent: 1,95,1742843977193945000
# Sent: 1,96,1742843977193949000
# Sent: 1,97,1742843977193953000
# Sent: 1,98,1742843977193957000
# Sent: 1,99,1742843977193961000
# Sent: 1,100,1742843977193965000

# %%
# start the loops of all entities
# all loops must be blocked at a certain position

t1_1 = Thread(target = ALE_1.loop_Tx, args = ()) 
t2_1 = Thread(target = ALE_1.loop_Rx, args = ()) 
t3_1 = Thread(target = DLE_1.loop_Tx, args = ())
t4_1 = Thread(target = DLE_1.loop_Rx, args = ())
t5_1 = Thread(target = PLE_1.loop_Tx, args = ()) 
t6_1 = Thread(target = PLE_1.loop_Rx, args = ())
f1_1 = Thread(target = DLE_1.loop_FSM, args = ())
f2_1 = Thread(target = DLE_1.loop_timer, args = ())


t1_2 = Thread(target = ALE_2.loop_Tx, args = ()) 
t2_2 = Thread(target = ALE_2.loop_Rx, args = ()) 
t3_2 = Thread(target = DLE_2.loop_Tx, args = ())
t4_2 = Thread(target = DLE_2.loop_Rx, args = ())
t5_2 = Thread(target = PLE_2.loop_Tx, args = ()) 
t6_2 = Thread(target = PLE_2.loop_Rx, args = ()) 
f1_2 = Thread(target = DLE_2.loop_FSM, args = ())
f2_2 = Thread(target = DLE_2.loop_timer, args = ())

thread_running = True

t1_1.start()
t2_1.start()
t3_1.start()
t4_1.start()
t5_1.start()
t6_1.start()
t1_2.start()
t2_2.start()
t3_2.start()
t4_2.start()
t5_2.start()
t6_2.start()
f1_1.start()
f1_2.start()
f2_1.start()
f2_2.start()
# Out:
# 15:16:07> ALE_Alice: loop_Tx starting
# 15:16:07> ALE_Alice: loop_Rx starting
# 15:16:07> DLE_Alice: loop_Tx starting
# 15:16:07> DLE_Alice: loop_Rx starting
# 15:16:07> PLE_Alice: loop_Tx starting
# 15:16:07> PLE_Alice: loop_Rx starting
# 15:16:07> ALE_Bob: loop_Tx starting
# 15:16:07> ALE_Bob: loop_Rx starting
# 15:16:07> DLE_Bob: loop_Tx starting
# 15:16:07> DLE_Bob: loop_Rx starting
# 15:16:07> PLE_Bob: loop_Tx starting
# 15:16:07> PLE_Bob: loop_Rx starting
# 15:16:07> DLE_Alice: loop_FSM starting
# 15:16:07> DLE_Bob: loop_FSM starting
# 15:16:07> DLE_Alice: loop_Timer starting
# 15:16:07> DLE_Bob: loop_Timer starting
# 15:19:37> DLE_Alice Tx: message 1: 1,1,1742843977193503000
# 15:19:37> DLE_Alice FSM: state: 0 event type: 0
# 15:19:37> DLE_Alice FSM: to send: 1,1,1742843977193503000
# 15:19:37> PLE_Alice Tx: message: 001,1,1742843977193503000
# 15:19:38> PLE_Bob Rx: from ('127.0.0.1', 30000): 001,1,1742843977193503000
# 15:19:38> DLE_Bob Rx: message 1: 001,1,1742843977193503000
# 15:19:38> DLE_Bob FSM: state: 0 event type: 1
# 15:19:38> DLE_Bob FSM: received: 1,1,1742843977193503000
# 15:19:38> ALE_Bob Rx: message 1: 1,1,1742843977193503000
# 15:19:38> PLE_Bob Tx: message: 10
# 15:19:38> packet loss
# 15:19:42> DLE_Alice FSM: state: 1 event type: 3
# 15:19:42> DLE_Alice FSM: to resend frame 0 1,1,1742843977193503000
# 15:19:42> PLE_Alice Tx: message: 001,1,1742843977193503000
# 15:19:43> PLE_Bob Rx: from ('127.0.0.1', 30000): 001,1,1742843977193503000
# 15:19:43> DLE_Bob Rx: message 2: 001,1,1742843977193503000
# 15:19:43> DLE_Bob FSM: state: 0 event type: 1
# 15:19:43> DLE_Bob FSM: received: 1,1,1742843977193503000
# 15:19:43> DLE_Bob FSM: received received frame 0 but expected 1
# 15:19:43> PLE_Bob Tx: message: 10
# 15:19:44> PLE_Alice Rx: from ('127.0.0.1', 31111): 10
# 15:19:44> DLE_Alice Rx: message 1: 10
# 15:19:44> DLE_Alice FSM: state: 1 event type: 2
# 15:19:44> DLE_Alice Tx: message 2: 1,2,1742843977193555000
# 15:19:44> DLE_Alice FSM: state: 0 event type: 0
# 15:19:44> DLE_Alice FSM: to send: 1,2,1742843977193555000
# 15:19:44> PLE_Alice Tx: message: 011,2,1742843977193555000
# 15:19:46> PLE_Bob Rx: from ('127.0.0.1', 30000): 011,2,1742843977193555000
# 15:19:46> DLE_Bob Rx: message 3: 011,2,1742843977193555000
# 15:19:46> DLE_Bob FSM: state: 0 event type: 1
# 15:19:46> DLE_Bob FSM: received: 1,2,1742843977193555000
# 15:19:46> PLE_Bob Tx: message: 11
# 15:19:46> ALE_Bob Rx: message 2: 1,2,1742843977193555000
# 15:19:47> PLE_Alice Rx: from ('127.0.0.1', 31111): 11
# 15:19:47> DLE_Alice Rx: message 2: 11
# 15:19:47> DLE_Alice FSM: state: 1 event type: 2
# 15:19:47> DLE_Alice Tx: message 3: 1,3,1742843977193564000
# 15:19:47> DLE_Alice FSM: state: 0 event type: 0
# 15:19:47> DLE_Alice FSM: to send: 1,3,1742843977193564000
# 15:19:47> PLE_Alice Tx: message: 021,3,1742843977193564000
# 15:19:48> PLE_Bob Rx: from ('127.0.0.1', 30000): 021,3,1742843977193564000
# 15:19:48> DLE_Bob Rx: message 4: 021,3,1742843977193564000
# 15:19:48> DLE_Bob FSM: state: 0 event type: 1
# 15:19:48> DLE_Bob FSM: received: 1,3,1742843977193564000
# 15:19:48> PLE_Bob Tx: message: 12
# 15:19:48> ALE_Bob Rx: message 3: 1,3,1742843977193564000
# 15:19:50> PLE_Alice Rx: from ('127.0.0.1', 31111): 12
# 15:19:50> DLE_Alice Rx: message 3: 12
# 15:19:50> DLE_Alice FSM: state: 1 event type: 2
# 15:19:50> DLE_Alice Tx: message 4: 1,4,1742843977193570000
# 15:19:50> DLE_Alice FSM: state: 0 event type: 0
# 15:19:50> DLE_Alice FSM: to send: 1,4,1742843977193570000
# 15:19:50> PLE_Alice Tx: message: 031,4,1742843977193570000
# 15:19:50> PLE_Bob Rx: from ('127.0.0.1', 30000): 031,4,1742843977193570000
# 15:19:50> DLE_Bob Rx: message 5: 031,4,1742843977193570000
# 15:19:50> DLE_Bob FSM: state: 0 event type: 1
# 15:19:50> DLE_Bob FSM: received: 1,4,1742843977193570000
# 15:19:50> ALE_Bob Rx: message 4: 1,4,1742843977193570000
# 15:19:50> PLE_Bob Tx: message: 13
# 15:19:51> PLE_Alice Rx: from ('127.0.0.1', 31111): 13
# 15:19:51> DLE_Alice Rx: message 4: 13
# 15:19:51> DLE_Alice FSM: state: 1 event type: 2
# 15:19:51> DLE_Alice Tx: message 5: 1,5,1742843977193574000
# 15:19:51> DLE_Alice FSM: state: 0 event type: 0
# 15:19:51> DLE_Alice FSM: to send: 1,5,1742843977193574000
# 15:19:51> PLE_Alice Tx: message: 041,5,1742843977193574000
# 15:19:52> PLE_Bob Rx: from ('127.0.0.1', 30000): 041,5,1742843977193574000
# 15:19:52> DLE_Bob Rx: message 6: 041,5,1742843977193574000
# 15:19:52> DLE_Bob FSM: state: 0 event type: 1
# 15:19:52> DLE_Bob FSM: received: 1,5,1742843977193574000
# 15:19:52> ALE_Bob Rx: message 5: 1,5,1742843977193574000
# 15:19:52> PLE_Bob Tx: message: 14
# 15:19:54> PLE_Alice Rx: from ('127.0.0.1', 31111): 14
# 15:19:54> DLE_Alice Rx: message 5: 14
# 15:19:54> DLE_Alice FSM: state: 1 event type: 2
# 15:19:54> DLE_Alice Tx: message 6: 1,6,1742843977193579000
# 15:19:54> DLE_Alice FSM: state: 0 event type: 0
# 15:19:54> DLE_Alice FSM: to send: 1,6,1742843977193579000
# 15:19:54> PLE_Alice Tx: message: 051,6,1742843977193579000
# 15:19:56> PLE_Bob Rx: from ('127.0.0.1', 30000): 051,6,1742843977193579000
# 15:19:56> DLE_Bob Rx: message 7: 051,6,1742843977193579000
# 15:19:56> DLE_Bob FSM: state: 0 event type: 1
# 15:19:56> DLE_Bob FSM: received: 1,6,1742843977193579000
# 15:19:56> PLE_Bob Tx: message: 15
# 15:19:56> ALE_Bob Rx: message 6: 1,6,1742843977193579000
# 15:19:57> PLE_Alice Rx: from ('127.0.0.1', 31111): 15
# 15:19:57> DLE_Alice Rx: message 6: 15
# 15:19:57> DLE_Alice FSM: state: 1 event type: 2
# 15:19:57> DLE_Alice Tx: message 7: 1,7,1742843977193583000
# 15:19:57> DLE_Alice FSM: state: 0 event type: 0
# 15:19:57> DLE_Alice FSM: to send: 1,7,1742843977193583000
# 15:19:57> PLE_Alice Tx: message: 061,7,1742843977193583000
# 15:19:57> PLE_Bob Rx: from ('127.0.0.1', 30000): 061,7,1742843977193583000
# 15:19:57> DLE_Bob Rx: message 8: 061,7,1742843977193583000
# 15:19:57> DLE_Bob FSM: state: 0 event type: 1
# 15:19:57> DLE_Bob FSM: received: 1,7,1742843977193583000
# 15:19:57> PLE_Bob Tx: message: 16
# 15:19:57> ALE_Bob Rx: message 7: 1,7,1742843977193583000
# 15:19:58> PLE_Alice Rx: from ('127.0.0.1', 31111): 16
# 15:19:58> DLE_Alice Rx: message 7: 16
# 15:19:58> DLE_Alice FSM: state: 1 event type: 2
# 15:19:58> DLE_Alice Tx: message 8: 1,8,1742843977193588000
# 15:19:58> DLE_Alice FSM: state: 0 event type: 0
# 15:19:58> DLE_Alice FSM: to send: 1,8,1742843977193588000
# 15:19:58> PLE_Alice Tx: message: 071,8,1742843977193588000
# 15:19:58> packet loss
# 15:20:04> DLE_Alice FSM: state: 1 event type: 3
# 15:20:04> DLE_Alice FSM: to resend frame 7 1,8,1742843977193588000
# 15:20:04> PLE_Alice Tx: message: 071,8,1742843977193588000
# 15:20:06> PLE_Bob Rx: from ('127.0.0.1', 30000): 071,8,1742843977193588000
# 15:20:06> DLE_Bob Rx: message 9: 071,8,1742843977193588000
# 15:20:06> DLE_Bob FSM: state: 0 event type: 1
# 15:20:06> DLE_Bob FSM: received: 1,8,1742843977193588000
# 15:20:06> ALE_Bob Rx: message 8: 1,8,1742843977193588000
# 15:20:06> PLE_Bob Tx: message: 17
# 15:20:07> PLE_Alice Rx: from ('127.0.0.1', 31111): 17
# 15:20:07> DLE_Alice Rx: message 8: 17
# 15:20:07> DLE_Alice FSM: state: 1 event type: 2
# 15:20:07> DLE_Alice Tx: message 9: 1,9,1742843977193592000
# 15:20:07> DLE_Alice FSM: state: 0 event type: 0
# 15:20:07> DLE_Alice FSM: to send: 1,9,1742843977193592000
# 15:20:07> PLE_Alice Tx: message: 081,9,1742843977193592000
# 15:20:08> PLE_Bob Rx: from ('127.0.0.1', 30000): 081,9,1742843977193592000
# 15:20:08> DLE_Bob Rx: message 10: 081,9,1742843977193592000
# 15:20:08> DLE_Bob FSM: state: 0 event type: 1
# 15:20:08> DLE_Bob FSM: received: 1,9,1742843977193592000
# 15:20:08> PLE_Bob Tx: message: 18
# 15:20:08> ALE_Bob Rx: message 9: 1,9,1742843977193592000
# 15:20:09> PLE_Alice Rx: from ('127.0.0.1', 31111): 18
# 15:20:09> DLE_Alice Rx: message 9: 18
# 15:20:09> DLE_Alice FSM: state: 1 event type: 2
# 15:20:09> DLE_Alice Tx: message 10: 1,10,1742843977193598000
# 15:20:09> DLE_Alice FSM: state: 0 event type: 0
# 15:20:09> DLE_Alice FSM: to send: 1,10,1742843977193598000
# 15:20:09> PLE_Alice Tx: message: 091,10,1742843977193598000
# 15:20:09> PLE_Bob Rx: from ('127.0.0.1', 30000): 091,10,1742843977193598000
# 15:20:09> DLE_Bob Rx: message 11: 091,10,1742843977193598000
# 15:20:09> DLE_Bob FSM: state: 0 event type: 1
# 15:20:09> DLE_Bob FSM: received: 1,10,1742843977193598000
# 15:20:09> PLE_Bob Tx: message: 19
# 15:20:09> ALE_Bob Rx: message 10: 1,10,1742843977193598000
# 15:20:10> PLE_Alice Rx: from ('127.0.0.1', 31111): 19
# 15:20:10> DLE_Alice Rx: message 10: 19
# 15:20:10> DLE_Alice FSM: state: 1 event type: 2
# 15:20:10> DLE_Alice Tx: message 11: 1,11,1742843977193602000
# 15:20:10> DLE_Alice FSM: state: 0 event type: 0
# 15:20:10> DLE_Alice FSM: to send: 1,11,1742843977193602000
# 15:20:10> PLE_Alice Tx: message: 001,11,1742843977193602000
# 15:20:10> PLE_Bob Rx: from ('127.0.0.1', 30000): 001,11,1742843977193602000
# 15:20:10> DLE_Bob Rx: message 12: 001,11,1742843977193602000
# 15:20:10> DLE_Bob FSM: state: 0 event type: 1
# 15:20:10> DLE_Bob FSM: received: 1,11,1742843977193602000
# 15:20:10> PLE_Bob Tx: message: 10
# 15:20:10> ALE_Bob Rx: message 11: 1,11,1742843977193602000
# 15:20:11> PLE_Alice Rx: from ('127.0.0.1', 31111): 10
# 15:20:11> DLE_Alice Rx: message 11: 10
# 15:20:11> DLE_Alice FSM: state: 1 event type: 2
# 15:20:11> DLE_Alice Tx: message 12: 1,12,1742843977193607000
# 15:20:11> DLE_Alice FSM: state: 0 event type: 0
# 15:20:11> DLE_Alice FSM: to send: 1,12,1742843977193607000
# 15:20:11> PLE_Alice Tx: message: 011,12,1742843977193607000
# 15:20:11> PLE_Bob Rx: from ('127.0.0.1', 30000): 011,12,1742843977193607000
# 15:20:11> DLE_Bob Rx: message 13: 011,12,1742843977193607000
# 15:20:11> DLE_Bob FSM: state: 0 event type: 1
# 15:20:11> DLE_Bob FSM: received: 1,12,1742843977193607000
# 15:20:11> PLE_Bob Tx: message: 11
# 15:20:11> packet loss
# 15:20:11> ALE_Bob Rx: message 12: 1,12,1742843977193607000
# 15:20:17> DLE_Alice FSM: state: 1 event type: 3
# 15:20:17> DLE_Alice FSM: to resend frame 1 1,12,1742843977193607000
# 15:20:17> PLE_Alice Tx: message: 011,12,1742843977193607000
# 15:20:18> PLE_Bob Rx: from ('127.0.0.1', 30000): 011,12,1742843977193607000
# 15:20:18> DLE_Bob Rx: message 14: 011,12,1742843977193607000
# 15:20:18> DLE_Bob FSM: state: 0 event type: 1
# 15:20:18> DLE_Bob FSM: received: 1,12,1742843977193607000
# 15:20:18> DLE_Bob FSM: received received frame 1 but expected 2
# 15:20:18> PLE_Bob Tx: message: 11
# 15:20:19> PLE_Alice Rx: from ('127.0.0.1', 31111): 11
# 15:20:19> DLE_Alice Rx: message 12: 11
# 15:20:19> DLE_Alice FSM: state: 1 event type: 2
# 15:20:19> DLE_Alice Tx: message 13: 1,13,1742843977193611000
# 15:20:19> DLE_Alice FSM: state: 0 event type: 0
# 15:20:19> DLE_Alice FSM: to send: 1,13,1742843977193611000
# 15:20:19> PLE_Alice Tx: message: 021,13,1742843977193611000
# 15:20:19> Transmission Duplicated
# 15:20:19> PLE_Bob Rx: from ('127.0.0.1', 30000): 021,13,1742843977193611000
# 15:20:19> DLE_Bob Rx: message 15: 021,13,1742843977193611000
# 15:20:19> DLE_Bob FSM: state: 0 event type: 1
# 15:20:19> DLE_Bob FSM: received: 1,13,1742843977193611000
# 15:20:19> ALE_Bob Rx: message 13: 1,13,1742843977193611000
# 15:20:19> PLE_Bob Tx: message: 12
# 15:20:20> PLE_Alice Rx: from ('127.0.0.1', 31111): 12
# 15:20:20> DLE_Alice Rx: message 13: 12
# 15:20:20> DLE_Alice FSM: state: 1 event type: 2
# 15:20:20> DLE_Alice Tx: message 14: 1,14,1742843977193615000
# 15:20:20> DLE_Alice FSM: state: 0 event type: 0
# 15:20:20> DLE_Alice FSM: to send: 1,14,1742843977193615000
# 15:20:20> PLE_Alice Tx: message: 031,14,1742843977193615000
# 15:20:20> PLE_Bob Rx: from ('127.0.0.1', 30000): 021,13,1742843977193611000
# 15:20:20> DLE_Bob Rx: message 16: 021,13,1742843977193611000
# 15:20:20> DLE_Bob FSM: state: 0 event type: 1
# 15:20:20> DLE_Bob FSM: received: 1,13,1742843977193611000
# 15:20:20> DLE_Bob FSM: received received frame 2 but expected 3
# 15:20:20> PLE_Bob Tx: message: 12
# 15:20:21> PLE_Alice Rx: from ('127.0.0.1', 31111): 12
# 15:20:21> DLE_Alice Rx: message 14: 12
# 15:20:21> DLE_Alice FSM: state: 1 event type: 2
# 15:20:21> ACK # 2 does not match local seq # 3
# 15:20:22> PLE_Bob Rx: from ('127.0.0.1', 30000): 031,14,1742843977193615000
# 15:20:22> DLE_Bob Rx: message 17: 031,14,1742843977193615000
# 15:20:22> DLE_Bob FSM: state: 0 event type: 1
# 15:20:22> DLE_Bob FSM: received: 1,14,1742843977193615000
# 15:20:22> PLE_Bob Tx: message: 13
# 15:20:22> packet loss
# 15:20:22> ALE_Bob Rx: message 14: 1,14,1742843977193615000
# 15:20:25> DLE_Alice FSM: state: 1 event type: 3
# 15:20:25> DLE_Alice FSM: to resend frame 3 1,14,1742843977193615000
# 15:20:25> PLE_Alice Tx: message: 031,14,1742843977193615000
# 15:20:26> PLE_Bob Rx: from ('127.0.0.1', 30000): 031,14,1742843977193615000
# 15:20:26> DLE_Bob Rx: message 18: 031,14,1742843977193615000
# 15:20:26> DLE_Bob FSM: state: 0 event type: 1
# 15:20:26> DLE_Bob FSM: received: 1,14,1742843977193615000
# 15:20:26> DLE_Bob FSM: received received frame 3 but expected 4
# 15:20:26> PLE_Bob Tx: message: 13
# 15:20:26> packet loss
# 15:24:55> DLE_Alice FSM: state: 1 event type: 3
# 15:24:55> DLE_Alice FSM: to resend frame 3 1,14,1742843977193615000
# 15:24:55> PLE_Alice Tx: message: 031,14,1742843977193615000
# 15:24:56> PLE_Bob Rx: from ('127.0.0.1', 30000): 031,14,1742843977193615000
# 15:24:56> DLE_Bob Rx: message 19: 031,14,1742843977193615000
# 15:24:56> DLE_Bob FSM: state: 0 event type: 1
# 15:24:56> DLE_Bob FSM: received: 1,14,1742843977193615000
# 15:24:56> DLE_Bob FSM: received received frame 3 but expected 4
# 15:24:56> PLE_Bob Tx: message: 13
# 15:24:56> packet loss
# 15:25:01> DLE_Alice FSM: state: 1 event type: 3
# 15:25:01> DLE_Alice FSM: to resend frame 3 1,14,1742843977193615000
# 15:25:01> PLE_Alice Tx: message: 031,14,1742843977193615000
# 15:25:01> PLE_Bob Rx: from ('127.0.0.1', 30000): 031,14,1742843977193615000
# 15:25:01> DLE_Bob Rx: message 20: 031,14,1742843977193615000
# 15:25:01> DLE_Bob FSM: state: 0 event type: 1
# 15:25:01> DLE_Bob FSM: received: 1,14,1742843977193615000
# 15:25:01> DLE_Bob FSM: received received frame 3 but expected 4
# 15:25:01> PLE_Bob Tx: message: 13
# 15:25:02> PLE_Alice Rx: from ('127.0.0.1', 31111): 13
# 15:25:02> DLE_Alice Rx: message 15: 13
# 15:25:02> DLE_Alice FSM: state: 1 event type: 2
# 15:25:02> DLE_Alice Tx: message 15: 1,15,1742843977193619000
# 15:25:02> DLE_Alice FSM: state: 0 event type: 0
# 15:25:02> DLE_Alice FSM: to send: 1,15,1742843977193619000
# 15:25:02> PLE_Alice Tx: message: 041,15,1742843977193619000
# 15:25:03> PLE_Bob Rx: from ('127.0.0.1', 30000): 041,15,1742843977193619000
# 15:25:03> DLE_Bob Rx: message 21: 041,15,1742843977193619000
# 15:25:03> DLE_Bob FSM: state: 0 event type: 1
# 15:25:03> DLE_Bob FSM: received: 1,15,1742843977193619000
# 15:25:03> PLE_Bob Tx: message: 14
# 15:25:03> ALE_Bob Rx: message 15: 1,15,1742843977193619000
# 15:25:03> PLE_Alice Rx: from ('127.0.0.1', 31111): 14
# 15:25:03> DLE_Alice Rx: message 16: 14
# 15:25:03> DLE_Alice FSM: state: 1 event type: 2
# 15:25:03> DLE_Alice Tx: message 16: 1,16,1742843977193624000
# 15:25:03> DLE_Alice FSM: state: 0 event type: 0
# 15:25:03> DLE_Alice FSM: to send: 1,16,1742843977193624000
# 15:25:03> PLE_Alice Tx: message: 051,16,1742843977193624000
# 15:25:04> PLE_Bob Rx: from ('127.0.0.1', 30000): 051,16,1742843977193624000
# 15:25:04> DLE_Bob Rx: message 22: 051,16,1742843977193624000
# 15:25:04> DLE_Bob FSM: state: 0 event type: 1
# 15:25:04> DLE_Bob FSM: received: 1,16,1742843977193624000
# 15:25:04> ALE_Bob Rx: message 16: 1,16,1742843977193624000
# 15:25:04> PLE_Bob Tx: message: 15
# 15:25:04> PLE_Alice Rx: from ('127.0.0.1', 31111): 15
# 15:25:04> DLE_Alice Rx: message 17: 15
# 15:25:04> DLE_Alice FSM: state: 1 event type: 2
# 15:25:04> DLE_Alice Tx: message 17: 1,17,1742843977193628000
# 15:25:04> DLE_Alice FSM: state: 0 event type: 0
# 15:25:04> DLE_Alice FSM: to send: 1,17,1742843977193628000
# 15:25:04> PLE_Alice Tx: message: 061,17,1742843977193628000
# 15:25:06> PLE_Bob Rx: from ('127.0.0.1', 30000): 061,17,1742843977193628000
# 15:25:06> DLE_Bob Rx: message 23: 061,17,1742843977193628000
# 15:25:06> DLE_Bob FSM: state: 0 event type: 1
# 15:25:06> DLE_Bob FSM: received: 1,17,1742843977193628000
# 15:25:06> ALE_Bob Rx: message 17: 1,17,1742843977193628000
# 15:25:06> PLE_Bob Tx: message: 16
# 15:25:07> PLE_Alice Rx: from ('127.0.0.1', 31111): 16
# 15:25:07> DLE_Alice Rx: message 18: 16
# 15:25:07> DLE_Alice FSM: state: 1 event type: 2
# 15:25:07> DLE_Alice Tx: message 18: 1,18,1742843977193632000
# 15:25:07> DLE_Alice FSM: state: 0 event type: 0
# 15:25:07> DLE_Alice FSM: to send: 1,18,1742843977193632000
# 15:25:07> PLE_Alice Tx: message: 071,18,1742843977193632000
# 15:25:14> PLE_Bob Rx: from ('127.0.0.1', 30000): 071,18,1742843977193632000
# 15:25:14> DLE_Bob Rx: message 24: 071,18,1742843977193632000
# 15:25:14> DLE_Bob FSM: state: 0 event type: 1
# 15:25:14> DLE_Bob FSM: received: 1,18,1742843977193632000
# 15:25:14> ALE_Bob Rx: message 18: 1,18,1742843977193632000
# 15:25:14> PLE_Bob Tx: message: 17
# 15:25:14> PLE_Alice Rx: from ('127.0.0.1', 31111): 17
# 15:25:14> DLE_Alice Rx: message 19: 17
# 15:25:14> DLE_Alice FSM: state: 1 event type: 2
# 15:25:14> DLE_Alice Tx: message 19: 1,19,1742843977193635000
# 15:25:14> DLE_Alice FSM: state: 0 event type: 0
# 15:25:14> DLE_Alice FSM: to send: 1,19,1742843977193635000
# 15:25:14> PLE_Alice Tx: message: 081,19,1742843977193635000
# 15:25:15> PLE_Bob Rx: from ('127.0.0.1', 30000): 081,19,1742843977193635000
# 15:25:15> DLE_Bob Rx: message 25: 081,19,1742843977193635000
# 15:25:15> DLE_Bob FSM: state: 0 event type: 1
# 15:25:15> DLE_Bob FSM: received: 1,19,1742843977193635000
# 15:25:15> PLE_Bob Tx: message: 18
# 15:25:15> ALE_Bob Rx: message 19: 1,19,1742843977193635000
# 15:25:16> PLE_Alice Rx: from ('127.0.0.1', 31111): 18
# 15:25:16> DLE_Alice Rx: message 20: 18
# 15:25:16> DLE_Alice FSM: state: 1 event type: 2
# 15:25:16> DLE_Alice Tx: message 20: 1,20,1742843977193640000
# 15:25:16> DLE_Alice FSM: state: 0 event type: 0
# 15:25:16> DLE_Alice FSM: to send: 1,20,1742843977193640000
# 15:25:16> PLE_Alice Tx: message: 091,20,1742843977193640000
# 15:25:18> PLE_Bob Rx: from ('127.0.0.1', 30000): 091,20,1742843977193640000
# 15:25:18> DLE_Bob Rx: message 26: 091,20,1742843977193640000
# 15:25:18> DLE_Bob FSM: state: 0 event type: 1
# 15:25:18> DLE_Bob FSM: received: 1,20,1742843977193640000
# 15:25:18> PLE_Bob Tx: message: 19
# 15:25:18> ALE_Bob Rx: message 20: 1,20,1742843977193640000
# 15:25:18> PLE_Alice Rx: from ('127.0.0.1', 31111): 19
# 15:25:18> DLE_Alice Rx: message 21: 19
# 15:25:18> DLE_Alice FSM: state: 1 event type: 2
# 15:25:18> DLE_Alice Tx: message 21: 1,21,1742843977193644000
# 15:25:18> DLE_Alice FSM: state: 0 event type: 0
# 15:25:18> DLE_Alice FSM: to send: 1,21,1742843977193644000
# 15:25:18> PLE_Alice Tx: message: 001,21,1742843977193644000
# 15:25:18> packet loss
# 15:25:24> DLE_Alice FSM: state: 1 event type: 3
# 15:25:24> DLE_Alice FSM: to resend frame 0 1,21,1742843977193644000
# 15:25:24> PLE_Alice Tx: message: 001,21,1742843977193644000
# 15:25:24> PLE_Bob Rx: from ('127.0.0.1', 30000): 001,21,1742843977193644000
# 15:25:24> DLE_Bob Rx: message 27: 001,21,1742843977193644000
# 15:25:24> DLE_Bob FSM: state: 0 event type: 1
# 15:25:24> DLE_Bob FSM: received: 1,21,1742843977193644000
# 15:25:24> PLE_Bob Tx: message: 10
# 15:25:24> ALE_Bob Rx: message 21: 1,21,1742843977193644000
# 15:25:24> PLE_Alice Rx: from ('127.0.0.1', 31111): 10
# 15:25:24> DLE_Alice Rx: message 22: 10
# 15:25:24> DLE_Alice FSM: state: 1 event type: 2
# 15:25:24> DLE_Alice Tx: message 22: 1,22,1742843977193648000
# 15:25:24> DLE_Alice FSM: state: 0 event type: 0
# 15:25:24> DLE_Alice FSM: to send: 1,22,1742843977193648000
# 15:25:24> PLE_Alice Tx: message: 011,22,1742843977193648000
# 15:25:26> PLE_Bob Rx: from ('127.0.0.1', 30000): 011,22,1742843977193648000
# 15:25:26> DLE_Bob Rx: message 28: 011,22,1742843977193648000
# 15:25:26> DLE_Bob FSM: state: 0 event type: 1
# 15:25:26> DLE_Bob FSM: received: 1,22,1742843977193648000
# 15:25:26> ALE_Bob Rx: message 22: 1,22,1742843977193648000
# 15:25:26> PLE_Bob Tx: message: 11
# 15:25:26> packet loss
# 15:25:30> DLE_Alice FSM: state: 1 event type: 3
# 15:25:30> DLE_Alice FSM: to resend frame 1 1,22,1742843977193648000
# 15:25:30> PLE_Alice Tx: message: 011,22,1742843977193648000
# 15:27:09> PLE_Bob Rx: from ('127.0.0.1', 30000): 011,22,1742843977193648000
# 15:27:09> DLE_Bob Rx: message 29: 011,22,1742843977193648000
# 15:27:09> DLE_Bob FSM: state: 0 event type: 1
# 15:27:09> DLE_Bob FSM: received: 1,22,1742843977193648000
# 15:27:09> DLE_Bob FSM: received received frame 1 but expected 2
# 15:27:09> PLE_Bob Tx: message: 11
# 15:27:10> PLE_Alice Rx: from ('127.0.0.1', 31111): 11
# 15:27:10> DLE_Alice Rx: message 23: 11
# 15:27:10> DLE_Alice FSM: state: 1 event type: 2
# 15:27:10> DLE_Alice Tx: message 23: 1,23,1742843977193653000
# 15:27:10> DLE_Alice FSM: state: 0 event type: 0
# 15:27:10> DLE_Alice FSM: to send: 1,23,1742843977193653000
# 15:27:10> PLE_Alice Tx: message: 021,23,1742843977193653000
# 15:27:11> PLE_Bob Rx: from ('127.0.0.1', 30000): 021,23,1742843977193653000
# 15:27:11> DLE_Bob Rx: message 30: 021,23,1742843977193653000
# 15:27:11> DLE_Bob FSM: state: 0 event type: 1
# 15:27:11> DLE_Bob FSM: received: 1,23,1742843977193653000
# 15:27:11> PLE_Bob Tx: message: 12
# 15:27:11> packet loss
# 15:27:11> ALE_Bob Rx: message 23: 1,23,1742843977193653000
# 15:27:16> DLE_Alice FSM: state: 1 event type: 3
# 15:27:16> DLE_Alice FSM: to resend frame 2 1,23,1742843977193653000
# 15:27:16> PLE_Alice Tx: message: 021,23,1742843977193653000
# 15:27:17> PLE_Bob Rx: from ('127.0.0.1', 30000): 021,23,1742843977193653000
# 15:27:17> DLE_Bob Rx: message 31: 021,23,1742843977193653000
# 15:27:17> DLE_Bob FSM: state: 0 event type: 1
# 15:27:17> DLE_Bob FSM: received: 1,23,1742843977193653000
# 15:27:17> DLE_Bob FSM: received received frame 2 but expected 3
# 15:27:17> PLE_Bob Tx: message: 12
# 15:27:19> PLE_Alice Rx: from ('127.0.0.1', 31111): 12
# 15:27:19> DLE_Alice Rx: message 24: 12
# 15:27:19> DLE_Alice FSM: state: 1 event type: 2
# 15:27:19> DLE_Alice Tx: message 24: 1,24,1742843977193657000
# 15:27:19> DLE_Alice FSM: state: 0 event type: 0
# 15:27:19> DLE_Alice FSM: to send: 1,24,1742843977193657000
# 15:27:19> PLE_Alice Tx: message: 031,24,1742843977193657000
# 15:27:23> PLE_Bob Rx: from ('127.0.0.1', 30000): 031,24,1742843977193657000
# 15:27:23> DLE_Bob Rx: message 32: 031,24,1742843977193657000
# 15:27:23> DLE_Bob FSM: state: 0 event type: 1
# 15:27:23> DLE_Bob FSM: received: 1,24,1742843977193657000
# 15:27:23> ALE_Bob Rx: message 24: 1,24,1742843977193657000
# 15:27:23> PLE_Bob Tx: message: 13
# 15:27:24> PLE_Alice Rx: from ('127.0.0.1', 31111): 13
# 15:27:24> DLE_Alice Rx: message 25: 13
# 15:27:24> DLE_Alice FSM: state: 1 event type: 2
# 15:27:24> DLE_Alice Tx: message 25: 1,25,1742843977193661000
# 15:27:24> DLE_Alice FSM: state: 0 event type: 0
# 15:27:24> DLE_Alice FSM: to send: 1,25,1742843977193661000
# 15:27:24> PLE_Alice Tx: message: 041,25,1742843977193661000
# 15:27:26> PLE_Bob Rx: from ('127.0.0.1', 30000): 041,25,1742843977193661000
# 15:27:26> DLE_Bob Rx: message 33: 041,25,1742843977193661000
# 15:27:26> DLE_Bob FSM: state: 0 event type: 1
# 15:27:26> DLE_Bob FSM: received: 1,25,1742843977193661000
# 15:27:26> PLE_Bob Tx: message: 14
# 15:27:26> packet loss
# 15:27:26> ALE_Bob Rx: message 25: 1,25,1742843977193661000
# 15:27:30> DLE_Alice FSM: state: 1 event type: 3
# 15:27:30> DLE_Alice FSM: to resend frame 4 1,25,1742843977193661000
# 15:27:30> PLE_Alice Tx: message: 041,25,1742843977193661000
# 15:28:17> PLE_Bob Rx: from ('127.0.0.1', 30000): 041,25,1742843977193661000
# 15:28:17> DLE_Bob Rx: message 34: 041,25,1742843977193661000
# 15:28:17> DLE_Bob FSM: state: 0 event type: 1
# 15:28:17> DLE_Bob FSM: received: 1,25,1742843977193661000
# 15:28:17> DLE_Bob FSM: received received frame 4 but expected 5
# 15:28:17> PLE_Bob Tx: message: 14
# 15:28:18> PLE_Alice Rx: from ('127.0.0.1', 31111): 14
# 15:28:18> DLE_Alice Rx: message 26: 14
# 15:28:18> DLE_Alice FSM: state: 1 event type: 2
# 15:28:18> DLE_Alice Tx: message 26: 1,26,1742843977193665000
# 15:28:18> DLE_Alice FSM: state: 0 event type: 0
# 15:28:18> DLE_Alice FSM: to send: 1,26,1742843977193665000
# 15:28:18> PLE_Alice Tx: message: 051,26,1742843977193665000
# 15:28:20> PLE_Bob Rx: from ('127.0.0.1', 30000): 051,26,1742843977193665000
# 15:28:20> DLE_Bob Rx: message 35: 051,26,1742843977193665000
# 15:28:20> DLE_Bob FSM: state: 0 event type: 1
# 15:28:20> DLE_Bob FSM: received: 1,26,1742843977193665000
# 15:28:20> ALE_Bob Rx: message 26: 1,26,1742843977193665000
# 15:28:20> PLE_Bob Tx: message: 15
# 15:28:20> packet loss
# 15:28:24> DLE_Alice FSM: state: 1 event type: 3
# 15:28:24> DLE_Alice FSM: to resend frame 5 1,26,1742843977193665000
# 15:28:24> PLE_Alice Tx: message: 051,26,1742843977193665000
# 15:28:25> PLE_Bob Rx: from ('127.0.0.1', 30000): 051,26,1742843977193665000
# 15:28:25> DLE_Bob Rx: message 36: 051,26,1742843977193665000
# 15:28:25> DLE_Bob FSM: state: 0 event type: 1
# 15:28:25> DLE_Bob FSM: received: 1,26,1742843977193665000
# 15:28:25> DLE_Bob FSM: received received frame 5 but expected 6
# 15:28:25> PLE_Bob Tx: message: 15
# 15:28:26> PLE_Alice Rx: from ('127.0.0.1', 31111): 15
# 15:28:26> DLE_Alice Rx: message 27: 15
# 15:28:26> DLE_Alice FSM: state: 1 event type: 2
# 15:28:26> DLE_Alice Tx: message 27: 1,27,1742843977193669000
# 15:28:26> DLE_Alice FSM: state: 0 event type: 0
# 15:28:26> DLE_Alice FSM: to send: 1,27,1742843977193669000
# 15:28:26> PLE_Alice Tx: message: 061,27,1742843977193669000
# 15:28:26> PLE_Bob Rx: from ('127.0.0.1', 30000): 061,27,1742843977193669000
# 15:28:26> DLE_Bob Rx: message 37: 061,27,1742843977193669000
# 15:28:26> DLE_Bob FSM: state: 0 event type: 1
# 15:28:26> DLE_Bob FSM: received: 1,27,1742843977193669000
# 15:28:26> ALE_Bob Rx: message 27: 1,27,1742843977193669000
# 15:28:26> PLE_Bob Tx: message: 16
# 15:28:27> PLE_Alice Rx: from ('127.0.0.1', 31111): 16
# 15:28:27> DLE_Alice Rx: message 28: 16
# 15:28:27> DLE_Alice FSM: state: 1 event type: 2
# 15:28:27> DLE_Alice Tx: message 28: 1,28,1742843977193673000
# 15:28:27> DLE_Alice FSM: state: 0 event type: 0
# 15:28:27> DLE_Alice FSM: to send: 1,28,1742843977193673000
# 15:28:27> PLE_Alice Tx: message: 071,28,1742843977193673000
# 15:28:28> PLE_Bob Rx: from ('127.0.0.1', 30000): 071,28,1742843977193673000
# 15:28:28> DLE_Bob Rx: message 38: 071,28,1742843977193673000
# 15:28:28> DLE_Bob FSM: state: 0 event type: 1
# 15:28:28> DLE_Bob FSM: received: 1,28,1742843977193673000
# 15:28:28> PLE_Bob Tx: message: 17
# 15:28:28> packet loss
# 15:28:28> ALE_Bob Rx: message 28: 1,28,1742843977193673000
# 15:28:33> DLE_Alice FSM: state: 1 event type: 3
# 15:28:33> DLE_Alice FSM: to resend frame 7 1,28,1742843977193673000
# 15:28:33> PLE_Alice Tx: message: 071,28,1742843977193673000
# 15:28:33> PLE_Bob Rx: from ('127.0.0.1', 30000): 071,28,1742843977193673000
# 15:28:33> DLE_Bob Rx: message 39: 071,28,1742843977193673000
# 15:28:33> DLE_Bob FSM: state: 0 event type: 1
# 15:28:33> DLE_Bob FSM: received: 1,28,1742843977193673000
# 15:28:33> DLE_Bob FSM: received received frame 7 but expected 8
# 15:28:33> PLE_Bob Tx: message: 17
# 15:28:33> PLE_Alice Rx: from ('127.0.0.1', 31111): 17
# 15:28:33> DLE_Alice Rx: message 29: 17
# 15:28:33> DLE_Alice FSM: state: 1 event type: 2
# 15:28:33> DLE_Alice Tx: message 29: 1,29,1742843977193677000
# 15:28:33> DLE_Alice FSM: state: 0 event type: 0
# 15:28:33> DLE_Alice FSM: to send: 1,29,1742843977193677000
# 15:28:33> PLE_Alice Tx: message: 081,29,1742843977193677000
# 15:28:34> PLE_Bob Rx: from ('127.0.0.1', 30000): 081,29,1742843977193677000
# 15:28:34> DLE_Bob Rx: message 40: 081,29,1742843977193677000
# 15:28:34> DLE_Bob FSM: state: 0 event type: 1
# 15:28:34> DLE_Bob FSM: received: 1,29,1742843977193677000
# 15:28:34> ALE_Bob Rx: message 29: 1,29,1742843977193677000
# 15:28:34> PLE_Bob Tx: message: 18
# 15:28:35> PLE_Alice Rx: from ('127.0.0.1', 31111): 18
# 15:28:35> DLE_Alice Rx: message 30: 18
# 15:28:35> DLE_Alice FSM: state: 1 event type: 2
# 15:28:35> DLE_Alice Tx: message 30: 1,30,1742843977193681000
# 15:28:35> DLE_Alice FSM: state: 0 event type: 0
# 15:28:35> DLE_Alice FSM: to send: 1,30,1742843977193681000
# 15:28:35> PLE_Alice Tx: message: 091,30,1742843977193681000
# 15:28:37> PLE_Bob Rx: from ('127.0.0.1', 30000): 091,30,1742843977193681000
# 15:28:37> DLE_Bob Rx: message 41: 091,30,1742843977193681000
# 15:28:37> DLE_Bob FSM: state: 0 event type: 1
# 15:28:37> DLE_Bob FSM: received: 1,30,1742843977193681000
# 15:28:37> PLE_Bob Tx: message: 19
# 15:28:37> ALE_Bob Rx: message 30: 1,30,1742843977193681000
# 15:28:38> PLE_Alice Rx: from ('127.0.0.1', 31111): 19
# 15:28:38> DLE_Alice Rx: message 31: 19
# 15:28:38> DLE_Alice FSM: state: 1 event type: 2
# 15:28:38> DLE_Alice Tx: message 31: 1,31,1742843977193686000
# 15:28:38> DLE_Alice FSM: state: 0 event type: 0
# 15:28:38> DLE_Alice FSM: to send: 1,31,1742843977193686000
# 15:28:38> PLE_Alice Tx: message: 001,31,1742843977193686000
# 15:28:39> PLE_Bob Rx: from ('127.0.0.1', 30000): 001,31,1742843977193686000
# 15:28:39> DLE_Bob Rx: message 42: 001,31,1742843977193686000
# 15:28:39> DLE_Bob FSM: state: 0 event type: 1
# 15:28:39> DLE_Bob FSM: received: 1,31,1742843977193686000
# 15:28:39> ALE_Bob Rx: message 31: 1,31,1742843977193686000
# 15:28:39> PLE_Bob Tx: message: 10
# 15:28:40> PLE_Alice Rx: from ('127.0.0.1', 31111): 10
# 15:28:40> DLE_Alice Rx: message 32: 10
# 15:28:40> DLE_Alice FSM: state: 1 event type: 2
# 15:28:40> DLE_Alice Tx: message 32: 1,32,1742843977193690000
# 15:28:40> DLE_Alice FSM: state: 0 event type: 0
# 15:28:40> DLE_Alice FSM: to send: 1,32,1742843977193690000
# 15:28:40> PLE_Alice Tx: message: 011,32,1742843977193690000
# 15:28:42> PLE_Bob Rx: from ('127.0.0.1', 30000): 011,32,1742843977193690000
# 15:28:42> DLE_Bob Rx: message 43: 011,32,1742843977193690000
# 15:28:42> DLE_Bob FSM: state: 0 event type: 1
# 15:28:42> DLE_Bob FSM: received: 1,32,1742843977193690000
# 15:28:42> ALE_Bob Rx: message 32: 1,32,1742843977193690000
# 15:28:42> PLE_Bob Tx: message: 11
# 15:28:44> PLE_Alice Rx: from ('127.0.0.1', 31111): 11
# 15:28:44> DLE_Alice Rx: message 33: 11
# 15:28:44> DLE_Alice FSM: state: 1 event type: 2
# 15:28:44> DLE_Alice Tx: message 33: 1,33,1742843977193694000
# 15:28:44> DLE_Alice FSM: state: 0 event type: 0
# 15:28:44> DLE_Alice FSM: to send: 1,33,1742843977193694000
# 15:28:44> PLE_Alice Tx: message: 021,33,1742843977193694000
# 15:28:44> Transmission Duplicated
# 15:28:45> PLE_Bob Rx: from ('127.0.0.1', 30000): 021,33,1742843977193694000
# 15:28:45> DLE_Bob Rx: message 44: 021,33,1742843977193694000
# 15:28:45> DLE_Bob FSM: state: 0 event type: 1
# 15:28:45> DLE_Bob FSM: received: 1,33,1742843977193694000
# 15:28:45> PLE_Bob Tx: message: 12
# 15:28:45> ALE_Bob Rx: message 33: 1,33,1742843977193694000
# 15:28:46> PLE_Bob Rx: from ('127.0.0.1', 30000): 021,33,1742843977193694000
# 15:28:46> DLE_Bob Rx: message 45: 021,33,1742843977193694000
# 15:28:46> DLE_Bob FSM: state: 0 event type: 1
# 15:28:46> DLE_Bob FSM: received: 1,33,1742843977193694000
# 15:28:46> DLE_Bob FSM: received received frame 2 but expected 3
# 15:28:46> PLE_Bob Tx: message: 12
# 15:28:46> PLE_Alice Rx: from ('127.0.0.1', 31111): 12
# 15:28:46> DLE_Alice Rx: message 34: 12
# 15:28:46> DLE_Alice FSM: state: 1 event type: 2
# 15:28:46> DLE_Alice Tx: message 34: 1,34,1742843977193698000
# 15:28:46> DLE_Alice FSM: state: 0 event type: 0
# 15:28:46> DLE_Alice FSM: to send: 1,34,1742843977193698000
# 15:28:46> PLE_Alice Tx: message: 031,34,1742843977193698000
# 15:28:47> PLE_Alice Rx: from ('127.0.0.1', 31111): 12
# 15:28:47> DLE_Alice Rx: message 35: 12
# 15:28:47> DLE_Alice FSM: state: 1 event type: 2
# 15:28:47> ACK # 2 does not match local seq # 3
# 15:28:47> PLE_Bob Rx: from ('127.0.0.1', 30000): 031,34,1742843977193698000
# 15:28:47> DLE_Bob Rx: message 46: 031,34,1742843977193698000
# 15:28:47> DLE_Bob FSM: state: 0 event type: 1
# 15:28:47> DLE_Bob FSM: received: 1,34,1742843977193698000
# 15:28:47> PLE_Bob Tx: message: 13
# 15:28:47> ALE_Bob Rx: message 34: 1,34,1742843977193698000
# 15:28:48> PLE_Alice Rx: from ('127.0.0.1', 31111): 13
# 15:28:48> DLE_Alice Rx: message 36: 13
# 15:28:48> DLE_Alice FSM: state: 1 event type: 2
# 15:28:48> DLE_Alice Tx: message 35: 1,35,1742843977193702000
# 15:28:48> DLE_Alice FSM: state: 0 event type: 0
# 15:28:48> DLE_Alice FSM: to send: 1,35,1742843977193702000
# 15:28:48> PLE_Alice Tx: message: 041,35,1742843977193702000
# 15:28:50> PLE_Bob Rx: from ('127.0.0.1', 30000): 041,35,1742843977193702000
# 15:28:50> DLE_Bob Rx: message 47: 041,35,1742843977193702000
# 15:28:50> DLE_Bob FSM: state: 0 event type: 1
# 15:28:50> DLE_Bob FSM: received: 1,35,1742843977193702000
# 15:28:50> ALE_Bob Rx: message 35: 1,35,1742843977193702000
# 15:28:50> PLE_Bob Tx: message: 14
# 15:28:51> PLE_Alice Rx: from ('127.0.0.1', 31111): 14
# 15:28:51> DLE_Alice Rx: message 37: 14
# 15:28:51> DLE_Alice FSM: state: 1 event type: 2
# 15:28:51> DLE_Alice Tx: message 36: 1,36,1742843977193706000
# 15:28:51> DLE_Alice FSM: state: 0 event type: 0
# 15:28:51> DLE_Alice FSM: to send: 1,36,1742843977193706000
# 15:28:51> PLE_Alice Tx: message: 051,36,1742843977193706000
# 15:28:52> PLE_Bob Rx: from ('127.0.0.1', 30000): 051,36,1742843977193706000
# 15:28:52> DLE_Bob Rx: message 48: 051,36,1742843977193706000
# 15:28:52> DLE_Bob FSM: state: 0 event type: 1
# 15:28:52> DLE_Bob FSM: received: 1,36,1742843977193706000
# 15:28:52> ALE_Bob Rx: message 36: 1,36,1742843977193706000
# 15:28:52> PLE_Bob Tx: message: 15
# 15:28:53> PLE_Alice Rx: from ('127.0.0.1', 31111): 15
# 15:28:53> DLE_Alice Rx: message 38: 15
# 15:28:53> DLE_Alice FSM: state: 1 event type: 2
# 15:28:53> DLE_Alice Tx: message 37: 1,37,1742843977193710000
# 15:28:53> DLE_Alice FSM: state: 0 event type: 0
# 15:28:53> DLE_Alice FSM: to send: 1,37,1742843977193710000
# 15:28:53> PLE_Alice Tx: message: 061,37,1742843977193710000
# 15:28:54> PLE_Bob Rx: from ('127.0.0.1', 30000): 061,37,1742843977193710000
# 15:28:54> DLE_Bob Rx: message 49: 061,37,1742843977193710000
# 15:28:54> DLE_Bob FSM: state: 0 event type: 1
# 15:28:54> DLE_Bob FSM: received: 1,37,1742843977193710000
# 15:28:54> PLE_Bob Tx: message: 16
# 15:28:54> ALE_Bob Rx: message 37: 1,37,1742843977193710000
# 15:28:55> PLE_Alice Rx: from ('127.0.0.1', 31111): 16
# 15:28:55> DLE_Alice Rx: message 39: 16
# 15:28:55> DLE_Alice FSM: state: 1 event type: 2
# 15:28:55> DLE_Alice Tx: message 38: 1,38,1742843977193713000
# 15:28:55> DLE_Alice FSM: state: 0 event type: 0
# 15:28:55> DLE_Alice FSM: to send: 1,38,1742843977193713000
# 15:28:55> PLE_Alice Tx: message: 071,38,1742843977193713000
# 15:28:57> PLE_Bob Rx: from ('127.0.0.1', 30000): 071,38,1742843977193713000
# 15:28:57> DLE_Bob Rx: message 50: 071,38,1742843977193713000
# 15:28:57> DLE_Bob FSM: state: 0 event type: 1
# 15:28:57> DLE_Bob FSM: received: 1,38,1742843977193713000
# 15:28:57> PLE_Bob Tx: message: 17
# 15:28:57> ALE_Bob Rx: message 38: 1,38,1742843977193713000
# 15:28:57> PLE_Alice Rx: from ('127.0.0.1', 31111): 17
# 15:28:57> DLE_Alice Rx: message 40: 17
# 15:28:57> DLE_Alice FSM: state: 1 event type: 2
# 15:28:57> DLE_Alice Tx: message 39: 1,39,1742843977193718000
# 15:28:57> DLE_Alice FSM: state: 0 event type: 0
# 15:28:57> DLE_Alice FSM: to send: 1,39,1742843977193718000
# 15:28:57> PLE_Alice Tx: message: 081,39,1742843977193718000
# 15:28:57> packet loss
# 15:29:03> DLE_Alice FSM: state: 1 event type: 3
# 15:29:03> DLE_Alice FSM: to resend frame 8 1,39,1742843977193718000
# 15:29:03> PLE_Alice Tx: message: 081,39,1742843977193718000
# 15:29:05> PLE_Bob Rx: from ('127.0.0.1', 30000): 081,39,1742843977193718000
# 15:29:05> DLE_Bob Rx: message 51: 081,39,1742843977193718000
# 15:29:05> DLE_Bob FSM: state: 0 event type: 1
# 15:29:05> DLE_Bob FSM: received: 1,39,1742843977193718000
# 15:29:05> PLE_Bob Tx: message: 18
# 15:29:05> ALE_Bob Rx: message 39: 1,39,1742843977193718000
# 15:29:06> PLE_Alice Rx: from ('127.0.0.1', 31111): 18
# 15:29:06> DLE_Alice Rx: message 41: 18
# 15:29:06> DLE_Alice FSM: state: 1 event type: 2
# 15:29:06> DLE_Alice Tx: message 40: 1,40,1742843977193721000
# 15:29:06> DLE_Alice FSM: state: 0 event type: 0
# 15:29:06> DLE_Alice FSM: to send: 1,40,1742843977193721000
# 15:29:06> PLE_Alice Tx: message: 091,40,1742843977193721000
# 15:29:08> PLE_Bob Rx: from ('127.0.0.1', 30000): 091,40,1742843977193721000
# 15:29:08> DLE_Bob Rx: message 52: 091,40,1742843977193721000
# 15:29:08> DLE_Bob FSM: state: 0 event type: 1
# 15:29:08> DLE_Bob FSM: received: 1,40,1742843977193721000
# 15:29:08> PLE_Bob Tx: message: 19
# 15:29:08> ALE_Bob Rx: message 40: 1,40,1742843977193721000
# 15:29:09> PLE_Alice Rx: from ('127.0.0.1', 31111): 19
# 15:29:09> DLE_Alice Rx: message 42: 19
# 15:29:09> DLE_Alice FSM: state: 1 event type: 2
# 15:29:09> DLE_Alice Tx: message 41: 1,41,1742843977193725000
# 15:29:09> DLE_Alice FSM: state: 0 event type: 0
# 15:29:09> DLE_Alice FSM: to send: 1,41,1742843977193725000
# 15:29:09> PLE_Alice Tx: message: 001,41,1742843977193725000
# 15:29:09> PLE_Bob Rx: from ('127.0.0.1', 30000): 001,41,1742843977193725000
# 15:29:09> DLE_Bob Rx: message 53: 001,41,1742843977193725000
# 15:29:09> DLE_Bob FSM: state: 0 event type: 1
# 15:29:09> DLE_Bob FSM: received: 1,41,1742843977193725000
# 15:29:09> ALE_Bob Rx: message 41: 1,41,1742843977193725000
# 15:29:09> PLE_Bob Tx: message: 10
# 15:29:11> PLE_Alice Rx: from ('127.0.0.1', 31111): 10
# 15:29:11> DLE_Alice Rx: message 43: 10
# 15:29:11> DLE_Alice FSM: state: 1 event type: 2
# 15:29:11> DLE_Alice Tx: message 42: 1,42,1742843977193730000
# 15:29:11> DLE_Alice FSM: state: 0 event type: 0
# 15:29:11> DLE_Alice FSM: to send: 1,42,1742843977193730000
# 15:29:11> PLE_Alice Tx: message: 011,42,1742843977193730000
# 15:29:11> PLE_Bob Rx: from ('127.0.0.1', 30000): 011,42,1742843977193730000
# 15:29:11> DLE_Bob Rx: message 54: 011,42,1742843977193730000
# 15:29:11> DLE_Bob FSM: state: 0 event type: 1
# 15:29:11> DLE_Bob FSM: received: 1,42,1742843977193730000
# 15:29:11> PLE_Bob Tx: message: 11
# 15:29:11> ALE_Bob Rx: message 42: 1,42,1742843977193730000
# 15:29:13> PLE_Alice Rx: from ('127.0.0.1', 31111): 11
# 15:29:13> DLE_Alice Rx: message 44: 11
# 15:29:13> DLE_Alice FSM: state: 1 event type: 2
# 15:29:13> DLE_Alice Tx: message 43: 1,43,1742843977193734000
# 15:29:13> DLE_Alice FSM: state: 0 event type: 0
# 15:29:13> DLE_Alice FSM: to send: 1,43,1742843977193734000
# 15:29:13> PLE_Alice Tx: message: 021,43,1742843977193734000
# 15:29:14> PLE_Bob Rx: from ('127.0.0.1', 30000): 021,43,1742843977193734000
# 15:29:14> DLE_Bob Rx: message 55: 021,43,1742843977193734000
# 15:29:14> DLE_Bob FSM: state: 0 event type: 1
# 15:29:14> DLE_Bob FSM: received: 1,43,1742843977193734000
# 15:29:14> PLE_Bob Tx: message: 12
# 15:29:14> ALE_Bob Rx: message 43: 1,43,1742843977193734000
# 15:29:15> PLE_Alice Rx: from ('127.0.0.1', 31111): 12
# 15:29:15> DLE_Alice Rx: message 45: 12
# 15:29:15> DLE_Alice FSM: state: 1 event type: 2
# 15:29:15> DLE_Alice Tx: message 44: 1,44,1742843977193742000
# 15:29:15> DLE_Alice FSM: state: 0 event type: 0
# 15:29:15> DLE_Alice FSM: to send: 1,44,1742843977193742000
# 15:29:15> PLE_Alice Tx: message: 031,44,1742843977193742000
# 15:29:15> packet loss
# 15:29:21> DLE_Alice FSM: state: 1 event type: 3
# 15:29:21> DLE_Alice FSM: to resend frame 3 1,44,1742843977193742000
# 15:29:21> PLE_Alice Tx: message: 031,44,1742843977193742000
# 15:29:22> PLE_Bob Rx: from ('127.0.0.1', 30000): 031,44,1742843977193742000
# 15:29:22> DLE_Bob Rx: message 56: 031,44,1742843977193742000
# 15:29:22> DLE_Bob FSM: state: 0 event type: 1
# 15:29:22> DLE_Bob FSM: received: 1,44,1742843977193742000
# 15:29:22> ALE_Bob Rx: message 44: 1,44,1742843977193742000
# 15:29:22> PLE_Bob Tx: message: 13
# 15:29:23> PLE_Alice Rx: from ('127.0.0.1', 31111): 13
# 15:29:23> DLE_Alice Rx: message 46: 13
# 15:29:23> DLE_Alice FSM: state: 1 event type: 2
# 15:29:23> DLE_Alice Tx: message 45: 1,45,1742843977193745000
# 15:29:23> DLE_Alice FSM: state: 0 event type: 0
# 15:29:23> DLE_Alice FSM: to send: 1,45,1742843977193745000
# 15:29:23> PLE_Alice Tx: message: 041,45,1742843977193745000
# 15:29:23> PLE_Bob Rx: from ('127.0.0.1', 30000): 041,45,1742843977193745000
# 15:29:23> DLE_Bob Rx: message 57: 041,45,1742843977193745000
# 15:29:23> DLE_Bob FSM: state: 0 event type: 1
# 15:29:23> DLE_Bob FSM: received: 1,45,1742843977193745000
# 15:29:23> PLE_Bob Tx: message: 14
# 15:29:23> ALE_Bob Rx: message 45: 1,45,1742843977193745000
# 15:29:23> PLE_Alice Rx: from ('127.0.0.1', 31111): 14
# 15:29:23> DLE_Alice Rx: message 47: 14
# 15:29:23> DLE_Alice FSM: state: 1 event type: 2
# 15:29:23> DLE_Alice Tx: message 46: 1,46,1742843977193749000
# 15:29:23> DLE_Alice FSM: state: 0 event type: 0
# 15:29:23> DLE_Alice FSM: to send: 1,46,1742843977193749000
# 15:29:23> PLE_Alice Tx: message: 051,46,1742843977193749000
# 15:29:24> PLE_Bob Rx: from ('127.0.0.1', 30000): 051,46,1742843977193749000
# 15:29:24> DLE_Bob Rx: message 58: 051,46,1742843977193749000
# 15:29:24> DLE_Bob FSM: state: 0 event type: 1
# 15:29:24> DLE_Bob FSM: received: 1,46,1742843977193749000
# 15:29:24> ALE_Bob Rx: message 46: 1,46,1742843977193749000
# 15:29:24> PLE_Bob Tx: message: 15
# 15:29:26> PLE_Alice Rx: from ('127.0.0.1', 31111): 15
# 15:29:26> DLE_Alice Rx: message 48: 15
# 15:29:26> DLE_Alice FSM: state: 1 event type: 2
# 15:29:26> DLE_Alice Tx: message 47: 1,47,1742843977193753000
# 15:29:26> DLE_Alice FSM: state: 0 event type: 0
# 15:29:26> DLE_Alice FSM: to send: 1,47,1742843977193753000
# 15:29:26> PLE_Alice Tx: message: 061,47,1742843977193753000
# 15:29:26> packet loss
# 15:29:32> DLE_Alice FSM: state: 1 event type: 3
# 15:29:32> DLE_Alice FSM: to resend frame 6 1,47,1742843977193753000
# 15:29:32> PLE_Alice Tx: message: 061,47,1742843977193753000
# 15:29:33> PLE_Bob Rx: from ('127.0.0.1', 30000): 061,47,1742843977193753000
# 15:29:33> DLE_Bob Rx: message 59: 061,47,1742843977193753000
# 15:29:33> DLE_Bob FSM: state: 0 event type: 1
# 15:29:33> DLE_Bob FSM: received: 1,47,1742843977193753000
# 15:29:33> PLE_Bob Tx: message: 16
# 15:29:33> ALE_Bob Rx: message 47: 1,47,1742843977193753000
# 15:29:34> PLE_Alice Rx: from ('127.0.0.1', 31111): 16
# 15:29:34> DLE_Alice Rx: message 49: 16
# 15:29:34> DLE_Alice FSM: state: 1 event type: 2
# 15:29:34> DLE_Alice Tx: message 48: 1,48,1742843977193757000
# 15:29:34> DLE_Alice FSM: state: 0 event type: 0
# 15:29:34> DLE_Alice FSM: to send: 1,48,1742843977193757000
# 15:29:34> PLE_Alice Tx: message: 071,48,1742843977193757000
# 15:29:34> PLE_Bob Rx: from ('127.0.0.1', 30000): 071,48,1742843977193757000
# 15:29:34> DLE_Bob Rx: message 60: 071,48,1742843977193757000
# 15:29:34> DLE_Bob FSM: state: 0 event type: 1
# 15:29:34> DLE_Bob FSM: received: 1,48,1742843977193757000
# 15:29:34> ALE_Bob Rx: message 48: 1,48,1742843977193757000
# 15:29:34> PLE_Bob Tx: message: 17
# 15:29:36> PLE_Alice Rx: from ('127.0.0.1', 31111): 17
# 15:29:36> DLE_Alice Rx: message 50: 17
# 15:29:36> DLE_Alice FSM: state: 1 event type: 2
# 15:29:36> DLE_Alice Tx: message 49: 1,49,1742843977193765000
# 15:29:36> DLE_Alice FSM: state: 0 event type: 0
# 15:29:36> DLE_Alice FSM: to send: 1,49,1742843977193765000
# 15:29:36> PLE_Alice Tx: message: 081,49,1742843977193765000
# 15:29:37> PLE_Bob Rx: from ('127.0.0.1', 30000): 081,49,1742843977193765000
# 15:29:37> DLE_Bob Rx: message 61: 081,49,1742843977193765000
# 15:29:37> DLE_Bob FSM: state: 0 event type: 1
# 15:29:37> DLE_Bob FSM: received: 1,49,1742843977193765000
# 15:29:37> ALE_Bob Rx: message 49: 1,49,1742843977193765000
# 15:29:37> PLE_Bob Tx: message: 18
# 15:29:37> PLE_Alice Rx: from ('127.0.0.1', 31111): 18
# 15:29:37> DLE_Alice Rx: message 51: 18
# 15:29:37> DLE_Alice FSM: state: 1 event type: 2
# 15:29:37> DLE_Alice Tx: message 50: 1,50,1742843977193769000
# 15:29:37> DLE_Alice FSM: state: 0 event type: 0
# 15:29:37> DLE_Alice FSM: to send: 1,50,1742843977193769000
# 15:29:37> PLE_Alice Tx: message: 091,50,1742843977193769000
# 15:29:38> PLE_Bob Rx: from ('127.0.0.1', 30000): 091,50,1742843977193769000
# 15:29:38> DLE_Bob Rx: message 62: 091,50,1742843977193769000
# 15:29:38> DLE_Bob FSM: state: 0 event type: 1
# 15:29:38> DLE_Bob FSM: received: 1,50,1742843977193769000
# 15:29:38> PLE_Bob Tx: message: 19
# 15:29:38> ALE_Bob Rx: message 50: 1,50,1742843977193769000
# 15:29:38> PLE_Alice Rx: from ('127.0.0.1', 31111): 19
# 15:29:38> DLE_Alice Rx: message 52: 19
# 15:29:38> DLE_Alice FSM: state: 1 event type: 2
# 15:29:38> DLE_Alice Tx: message 51: 1,51,1742843977193773000
# 15:29:38> DLE_Alice FSM: state: 0 event type: 0
# 15:29:38> DLE_Alice FSM: to send: 1,51,1742843977193773000
# 15:29:38> PLE_Alice Tx: message: 001,51,1742843977193773000
# 15:29:39> PLE_Bob Rx: from ('127.0.0.1', 30000): 001,51,1742843977193773000
# 15:29:39> DLE_Bob Rx: message 63: 001,51,1742843977193773000
# 15:29:39> DLE_Bob FSM: state: 0 event type: 1
# 15:29:39> DLE_Bob FSM: received: 1,51,1742843977193773000
# 15:29:39> ALE_Bob Rx: message 51: 1,51,1742843977193773000
# 15:29:39> PLE_Bob Tx: message: 10
# 15:29:40> PLE_Alice Rx: from ('127.0.0.1', 31111): 10
# 15:29:40> DLE_Alice Rx: message 53: 10
# 15:29:40> DLE_Alice FSM: state: 1 event type: 2
# 15:29:40> DLE_Alice Tx: message 52: 1,52,1742843977193777000
# 15:29:40> DLE_Alice FSM: state: 0 event type: 0
# 15:29:40> DLE_Alice FSM: to send: 1,52,1742843977193777000
# 15:29:40> PLE_Alice Tx: message: 011,52,1742843977193777000
# 15:29:40> PLE_Bob Rx: from ('127.0.0.1', 30000): 011,52,1742843977193777000
# 15:29:40> DLE_Bob Rx: message 64: 011,52,1742843977193777000
# 15:29:40> DLE_Bob FSM: state: 0 event type: 1
# 15:29:40> DLE_Bob FSM: received: 1,52,1742843977193777000
# 15:29:40> PLE_Bob Tx: message: 11
# 15:29:40> ALE_Bob Rx: message 52: 1,52,1742843977193777000
# 15:29:41> PLE_Alice Rx: from ('127.0.0.1', 31111): 11
# 15:29:41> DLE_Alice Rx: message 54: 11
# 15:29:41> DLE_Alice FSM: state: 1 event type: 2
# 15:29:41> DLE_Alice Tx: message 53: 1,53,1742843977193781000
# 15:29:41> DLE_Alice FSM: state: 0 event type: 0
# 15:29:41> DLE_Alice FSM: to send: 1,53,1742843977193781000
# 15:29:41> PLE_Alice Tx: message: 021,53,1742843977193781000
# 15:29:41> PLE_Bob Rx: from ('127.0.0.1', 30000): 021,53,1742843977193781000
# 15:29:41> DLE_Bob Rx: message 65: 021,53,1742843977193781000
# 15:29:41> DLE_Bob FSM: state: 0 event type: 1
# 15:29:41> DLE_Bob FSM: received: 1,53,1742843977193781000
# 15:29:41> ALE_Bob Rx: message 53: 1,53,1742843977193781000
# 15:29:41> PLE_Bob Tx: message: 12
# 15:29:43> PLE_Alice Rx: from ('127.0.0.1', 31111): 12
# 15:29:43> DLE_Alice Rx: message 55: 12
# 15:29:43> DLE_Alice FSM: state: 1 event type: 2
# 15:29:43> DLE_Alice Tx: message 54: 1,54,1742843977193785000
# 15:29:43> DLE_Alice FSM: state: 0 event type: 0
# 15:29:43> DLE_Alice FSM: to send: 1,54,1742843977193785000
# 15:29:43> PLE_Alice Tx: message: 031,54,1742843977193785000
# 15:29:43> PLE_Bob Rx: from ('127.0.0.1', 30000): 031,54,1742843977193785000
# 15:29:43> DLE_Bob Rx: message 66: 031,54,1742843977193785000
# 15:29:43> DLE_Bob FSM: state: 0 event type: 1
# 15:29:43> DLE_Bob FSM: received: 1,54,1742843977193785000
# 15:29:43> PLE_Bob Tx: message: 13
# 15:29:43> ALE_Bob Rx: message 54: 1,54,1742843977193785000
# 15:29:44> PLE_Alice Rx: from ('127.0.0.1', 31111): 13
# 15:29:44> DLE_Alice Rx: message 56: 13
# 15:29:44> DLE_Alice FSM: state: 1 event type: 2
# 15:29:44> DLE_Alice Tx: message 55: 1,55,1742843977193788000
# 15:29:44> DLE_Alice FSM: state: 0 event type: 0
# 15:29:44> DLE_Alice FSM: to send: 1,55,1742843977193788000
# 15:29:44> PLE_Alice Tx: message: 041,55,1742843977193788000
# 15:29:46> PLE_Bob Rx: from ('127.0.0.1', 30000): 041,55,1742843977193788000
# 15:29:46> DLE_Bob Rx: message 67: 041,55,1742843977193788000
# 15:29:46> DLE_Bob FSM: state: 0 event type: 1
# 15:29:46> DLE_Bob FSM: received: 1,55,1742843977193788000
# 15:29:46> PLE_Bob Tx: message: 14
# 15:29:46> ALE_Bob Rx: message 55: 1,55,1742843977193788000
# 15:29:46> PLE_Alice Rx: from ('127.0.0.1', 31111): 14
# 15:29:46> DLE_Alice Rx: message 57: 14
# 15:29:46> DLE_Alice FSM: state: 1 event type: 2
# 15:29:46> DLE_Alice Tx: message 56: 1,56,1742843977193792000
# 15:29:46> DLE_Alice FSM: state: 0 event type: 0
# 15:29:46> DLE_Alice FSM: to send: 1,56,1742843977193792000
# 15:29:46> PLE_Alice Tx: message: 051,56,1742843977193792000
# 15:29:47> PLE_Bob Rx: from ('127.0.0.1', 30000): 051,56,1742843977193792000
# 15:29:47> DLE_Bob Rx: message 68: 051,56,1742843977193792000
# 15:29:47> DLE_Bob FSM: state: 0 event type: 1
# 15:29:47> DLE_Bob FSM: received: 1,56,1742843977193792000
# 15:29:47> ALE_Bob Rx: message 56: 1,56,1742843977193792000
# 15:29:47> PLE_Bob Tx: message: 15
# 15:29:48> PLE_Alice Rx: from ('127.0.0.1', 31111): 15
# 15:29:48> DLE_Alice Rx: message 58: 15
# 15:29:48> DLE_Alice FSM: state: 1 event type: 2
# 15:29:48> DLE_Alice Tx: message 57: 1,57,1742843977193796000
# 15:29:48> DLE_Alice FSM: state: 0 event type: 0
# 15:29:48> DLE_Alice FSM: to send: 1,57,1742843977193796000
# 15:29:48> PLE_Alice Tx: message: 061,57,1742843977193796000
# 15:29:49> PLE_Bob Rx: from ('127.0.0.1', 30000): 061,57,1742843977193796000
# 15:29:49> DLE_Bob Rx: message 69: 061,57,1742843977193796000
# 15:29:49> DLE_Bob FSM: state: 0 event type: 1
# 15:29:49> DLE_Bob FSM: received: 1,57,1742843977193796000
# 15:29:49> PLE_Bob Tx: message: 16
# 15:29:49> ALE_Bob Rx: message 57: 1,57,1742843977193796000
# 15:29:51> PLE_Alice Rx: from ('127.0.0.1', 31111): 16
# 15:29:51> DLE_Alice Rx: message 59: 16
# ...
# 15:31:49> DLE_Bob FSM: state: 0 event type: 1
# 15:31:49> DLE_Bob FSM: received: 1,83,1742843977193897000
# 15:31:49> DLE_Bob FSM: received received frame 2 but expected 3
# 15:31:49> PLE_Bob Tx: message: 12
# 15:31:50> PLE_Alice Rx: from ('127.0.0.1', 31111): 12
# 15:31:50> DLE_Alice Rx: message 87: 12
# 15:31:50> DLE_Alice FSM: state: 1 event type: 2
# 15:31:50> DLE_Alice Tx: message 84: 1,84,1742843977193901000
# 15:31:50> DLE_Alice FSM: state: 0 event type: 0
# 15:31:50> DLE_Alice FSM: to send: 1,84,1742843977193901000
# 15:31:50> PLE_Alice Tx: message: 031,84,1742843977193901000
# 15:31:52> PLE_Bob Rx: from ('127.0.0.1', 30000): 031,84,1742843977193901000
# 15:31:52> DLE_Bob Rx: message 106: 031,84,1742843977193901000
# 15:31:52> DLE_Bob FSM: state: 0 event type: 1
# 15:31:52> DLE_Bob FSM: received: 1,84,1742843977193901000
# 15:31:52> PLE_Bob Tx: message: 13
# 15:31:52> ALE_Bob Rx: message 84: 1,84,1742843977193901000
# 15:31:53> PLE_Alice Rx: from ('127.0.0.1', 31111): 13
# 15:31:53> DLE_Alice Rx: message 88: 13
# 15:31:53> DLE_Alice FSM: state: 1 event type: 2
# 15:31:53> DLE_Alice Tx: message 85: 1,85,1742843977193905000
# 15:31:53> DLE_Alice FSM: state: 0 event type: 0
# 15:31:53> DLE_Alice FSM: to send: 1,85,1742843977193905000
# 15:31:53> PLE_Alice Tx: message: 041,85,1742843977193905000
# 15:31:54> PLE_Bob Rx: from ('127.0.0.1', 30000): 041,85,1742843977193905000
# 15:31:54> DLE_Bob Rx: message 107: 041,85,1742843977193905000
# 15:31:54> DLE_Bob FSM: state: 0 event type: 1
# 15:31:54> DLE_Bob FSM: received: 1,85,1742843977193905000
# 15:31:54> ALE_Bob Rx: message 85: 1,85,1742843977193905000
# 15:31:54> PLE_Bob Tx: message: 14
# 15:31:54> PLE_Alice Rx: from ('127.0.0.1', 31111): 14
# 15:31:54> DLE_Alice Rx: message 89: 14
# 15:31:54> DLE_Alice FSM: state: 1 event type: 2
# 15:31:54> DLE_Alice Tx: message 86: 1,86,1742843977193909000
# 15:31:54> DLE_Alice FSM: state: 0 event type: 0
# 15:31:54> DLE_Alice FSM: to send: 1,86,1742843977193909000
# 15:31:54> PLE_Alice Tx: message: 051,86,1742843977193909000
# 15:31:54> packet loss
# 15:32:00> DLE_Alice FSM: state: 1 event type: 3
# 15:32:00> DLE_Alice FSM: to resend frame 5 1,86,1742843977193909000
# 15:32:00> PLE_Alice Tx: message: 051,86,1742843977193909000
# 15:32:01> PLE_Bob Rx: from ('127.0.0.1', 30000): 051,86,1742843977193909000
# 15:32:01> DLE_Bob Rx: message 108: 051,86,1742843977193909000
# 15:32:01> DLE_Bob FSM: state: 0 event type: 1
# 15:32:01> DLE_Bob FSM: received: 1,86,1742843977193909000
# 15:32:01> PLE_Bob Tx: message: 15
# 15:32:01> ALE_Bob Rx: message 86: 1,86,1742843977193909000
# 15:32:03> PLE_Alice Rx: from ('127.0.0.1', 31111): 15
# 15:32:03> DLE_Alice Rx: message 90: 15
# 15:32:03> DLE_Alice FSM: state: 1 event type: 2
# 15:32:03> DLE_Alice Tx: message 87: 1,87,1742843977193914000
# 15:32:03> DLE_Alice FSM: state: 0 event type: 0
# 15:32:03> DLE_Alice FSM: to send: 1,87,1742843977193914000
# 15:32:03> PLE_Alice Tx: message: 061,87,1742843977193914000
# 15:32:05> PLE_Bob Rx: from ('127.0.0.1', 30000): 061,87,1742843977193914000
# 15:32:05> DLE_Bob Rx: message 109: 061,87,1742843977193914000
# 15:32:05> DLE_Bob FSM: state: 0 event type: 1
# 15:32:05> DLE_Bob FSM: received: 1,87,1742843977193914000
# 15:32:05> PLE_Bob Tx: message: 16
# 15:32:05> packet loss
# 15:32:05> ALE_Bob Rx: message 87: 1,87,1742843977193914000
# 15:32:09> DLE_Alice FSM: state: 1 event type: 3
# 15:32:09> DLE_Alice FSM: to resend frame 6 1,87,1742843977193914000
# 15:32:09> PLE_Alice Tx: message: 061,87,1742843977193914000
# 15:32:10> PLE_Bob Rx: from ('127.0.0.1', 30000): 061,87,1742843977193914000
# 15:32:10> DLE_Bob Rx: message 110: 061,87,1742843977193914000
# 15:32:10> DLE_Bob FSM: state: 0 event type: 1
# 15:32:10> DLE_Bob FSM: received: 1,87,1742843977193914000
# 15:32:10> DLE_Bob FSM: received received frame 6 but expected 7
# 15:32:10> PLE_Bob Tx: message: 16
# 15:32:10> PLE_Alice Rx: from ('127.0.0.1', 31111): 16
# 15:32:10> DLE_Alice Rx: message 91: 16
# 15:32:10> DLE_Alice FSM: state: 1 event type: 2
# 15:32:10> DLE_Alice Tx: message 88: 1,88,1742843977193918000
# 15:32:10> DLE_Alice FSM: state: 0 event type: 0
# 15:32:10> DLE_Alice FSM: to send: 1,88,1742843977193918000
# 15:32:10> PLE_Alice Tx: message: 071,88,1742843977193918000
# 15:32:11> PLE_Bob Rx: from ('127.0.0.1', 30000): 071,88,1742843977193918000
# 15:32:11> DLE_Bob Rx: message 111: 071,88,1742843977193918000
# 15:32:11> DLE_Bob FSM: state: 0 event type: 1
# 15:32:11> DLE_Bob FSM: received: 1,88,1742843977193918000
# 15:32:11> ALE_Bob Rx: message 88: 1,88,1742843977193918000
# 15:32:11> PLE_Bob Tx: message: 17
# 15:32:11> PLE_Alice Rx: from ('127.0.0.1', 31111): 17
# 15:32:11> DLE_Alice Rx: message 92: 17
# 15:32:11> DLE_Alice FSM: state: 1 event type: 2
# 15:32:11> DLE_Alice Tx: message 89: 1,89,1742843977193922000
# 15:32:11> DLE_Alice FSM: state: 0 event type: 0
# 15:32:11> DLE_Alice FSM: to send: 1,89,1742843977193922000
# 15:32:11> PLE_Alice Tx: message: 081,89,1742843977193922000
# 15:32:11> Transmission Duplicated
# 15:32:13> PLE_Bob Rx: from ('127.0.0.1', 30000): 081,89,1742843977193922000
# 15:32:13> DLE_Bob Rx: message 112: 081,89,1742843977193922000
# 15:32:13> DLE_Bob FSM: state: 0 event type: 1
# 15:32:13> DLE_Bob FSM: received: 1,89,1742843977193922000
# 15:32:13> PLE_Bob Tx: message: 18
# 15:32:13> ALE_Bob Rx: message 89: 1,89,1742843977193922000
# 15:32:13> Transmission Duplicated
# 15:32:13> PLE_Alice Rx: from ('127.0.0.1', 31111): 18
# 15:32:13> DLE_Alice Rx: message 93: 18
# 15:32:13> DLE_Alice FSM: state: 1 event type: 2
# 15:32:13> DLE_Alice Tx: message 90: 1,90,1742843977193926000
# 15:32:13> DLE_Alice FSM: state: 0 event type: 0
# 15:32:13> DLE_Alice FSM: to send: 1,90,1742843977193926000
# 15:32:13> PLE_Alice Tx: message: 091,90,1742843977193926000
# 15:32:14> PLE_Bob Rx: from ('127.0.0.1', 30000): 081,89,1742843977193922000
# 15:32:14> DLE_Bob Rx: message 113: 081,89,1742843977193922000
# 15:32:14> DLE_Bob FSM: state: 0 event type: 1
# 15:32:14> DLE_Bob FSM: received: 1,89,1742843977193922000
# 15:32:14> DLE_Bob FSM: received received frame 8 but expected 9
# 15:32:14> PLE_Bob Tx: message: 18
# 15:32:14> PLE_Alice Rx: from ('127.0.0.1', 31111): 18
# 15:32:14> DLE_Alice Rx: message 94: 18
# 15:32:14> DLE_Alice FSM: state: 1 event type: 2
# 15:32:14> ACK # 8 does not match local seq # 9
# 15:32:15> PLE_Bob Rx: from ('127.0.0.1', 30000): 091,90,1742843977193926000
# 15:32:15> DLE_Bob Rx: message 114: 091,90,1742843977193926000
# 15:32:15> DLE_Bob FSM: state: 0 event type: 1
# 15:32:15> DLE_Bob FSM: received: 1,90,1742843977193926000
# 15:32:15> ALE_Bob Rx: message 90: 1,90,1742843977193926000
# 15:32:15> PLE_Bob Tx: message: 19
# 15:32:16> PLE_Alice Rx: from ('127.0.0.1', 31111): 18
# 15:32:16> DLE_Alice Rx: message 95: 18
# 15:32:16> DLE_Alice FSM: state: 1 event type: 2
# 15:32:16> ACK # 8 does not match local seq # 9
# 15:32:16> PLE_Alice Rx: from ('127.0.0.1', 31111): 19
# 15:32:16> DLE_Alice Rx: message 96: 19
# 15:32:16> DLE_Alice FSM: state: 1 event type: 2
# 15:32:16> DLE_Alice Tx: message 91: 1,91,1742843977193929000
# 15:32:16> DLE_Alice FSM: state: 0 event type: 0
# 15:32:16> DLE_Alice FSM: to send: 1,91,1742843977193929000
# 15:32:16> PLE_Alice Tx: message: 001,91,1742843977193929000
# 15:32:17> PLE_Bob Rx: from ('127.0.0.1', 30000): 001,91,1742843977193929000
# 15:32:17> DLE_Bob Rx: message 115: 001,91,1742843977193929000
# 15:32:17> DLE_Bob FSM: state: 0 event type: 1
# 15:32:17> DLE_Bob FSM: received: 1,91,1742843977193929000
# 15:32:17> PLE_Bob Tx: message: 10
# 15:32:17> ALE_Bob Rx: message 91: 1,91,1742843977193929000
# 15:32:17> Transmission Duplicated
# 15:32:18> PLE_Alice Rx: from ('127.0.0.1', 31111): 10
# 15:32:18> DLE_Alice Rx: message 97: 10
# 15:32:18> DLE_Alice FSM: state: 1 event type: 2
# 15:32:18> DLE_Alice Tx: message 92: 1,92,1742843977193933000
# 15:32:18> DLE_Alice FSM: state: 0 event type: 0
# 15:32:18> DLE_Alice FSM: to send: 1,92,1742843977193933000
# 15:32:18> PLE_Alice Tx: message: 011,92,1742843977193933000
# 15:32:19> PLE_Alice Rx: from ('127.0.0.1', 31111): 10
# 15:32:19> DLE_Alice Rx: message 98: 10
# 15:32:19> DLE_Alice FSM: state: 1 event type: 2
# 15:32:19> ACK # 0 does not match local seq # 1
# 15:32:19> PLE_Bob Rx: from ('127.0.0.1', 30000): 011,92,1742843977193933000
# 15:32:19> DLE_Bob Rx: message 116: 011,92,1742843977193933000
# 15:32:19> DLE_Bob FSM: state: 0 event type: 1
# 15:32:19> DLE_Bob FSM: received: 1,92,1742843977193933000
# 15:32:19> PLE_Bob Tx: message: 11
# 15:32:19> ALE_Bob Rx: message 92: 1,92,1742843977193933000
# 15:32:20> PLE_Alice Rx: from ('127.0.0.1', 31111): 11
# 15:32:20> DLE_Alice Rx: message 99: 11
# 15:32:20> DLE_Alice FSM: state: 1 event type: 2
# 15:32:20> DLE_Alice Tx: message 93: 1,93,1742843977193937000
# 15:32:20> DLE_Alice FSM: state: 0 event type: 0
# 15:32:20> DLE_Alice FSM: to send: 1,93,1742843977193937000
# 15:32:20> PLE_Alice Tx: message: 021,93,1742843977193937000
# 15:32:21> PLE_Bob Rx: from ('127.0.0.1', 30000): 021,93,1742843977193937000
# 15:32:21> DLE_Bob Rx: message 117: 021,93,1742843977193937000
# 15:32:21> DLE_Bob FSM: state: 0 event type: 1
# 15:32:21> DLE_Bob FSM: received: 1,93,1742843977193937000
# 15:32:21> PLE_Bob Tx: message: 12
# 15:32:21> ALE_Bob Rx: message 93: 1,93,1742843977193937000
# 15:32:22> PLE_Alice Rx: from ('127.0.0.1', 31111): 12
# 15:32:22> DLE_Alice Rx: message 100: 12
# 15:32:22> DLE_Alice FSM: state: 1 event type: 2
# 15:32:22> DLE_Alice Tx: message 94: 1,94,1742843977193941000
# 15:32:22> DLE_Alice FSM: state: 0 event type: 0
# 15:32:22> DLE_Alice FSM: to send: 1,94,1742843977193941000
# 15:32:22> PLE_Alice Tx: message: 031,94,1742843977193941000
# 15:32:22> Transmission Duplicated
# 15:32:24> PLE_Bob Rx: from ('127.0.0.1', 30000): 031,94,1742843977193941000
# 15:32:24> DLE_Bob Rx: message 118: 031,94,1742843977193941000
# 15:32:24> DLE_Bob FSM: state: 0 event type: 1
# 15:32:24> DLE_Bob FSM: received: 1,94,1742843977193941000
# 15:32:24> PLE_Bob Tx: message: 13
# 15:32:24> ALE_Bob Rx: message 94: 1,94,1742843977193941000
# 15:32:24> PLE_Bob Rx: from ('127.0.0.1', 30000): 031,94,1742843977193941000
# 15:32:24> DLE_Bob Rx: message 119: 031,94,1742843977193941000
# 15:32:24> DLE_Bob FSM: state: 0 event type: 1
# 15:32:24> DLE_Bob FSM: received: 1,94,1742843977193941000
# 15:32:24> DLE_Bob FSM: received received frame 3 but expected 4
# 15:32:24> PLE_Bob Tx: message: 13
# 15:32:24> PLE_Alice Rx: from ('127.0.0.1', 31111): 13
# 15:32:24> DLE_Alice Rx: message 101: 13
# 15:32:24> DLE_Alice FSM: state: 1 event type: 2
# 15:32:24> DLE_Alice Tx: message 95: 1,95,1742843977193945000
# 15:32:24> DLE_Alice FSM: state: 0 event type: 0
# 15:32:24> DLE_Alice FSM: to send: 1,95,1742843977193945000
# 15:32:24> PLE_Alice Tx: message: 041,95,1742843977193945000
# 15:32:25> PLE_Bob Rx: from ('127.0.0.1', 30000): 041,95,1742843977193945000
# 15:32:25> DLE_Bob Rx: message 120: 041,95,1742843977193945000
# 15:32:25> DLE_Bob FSM: state: 0 event type: 1
# 15:32:25> DLE_Bob FSM: received: 1,95,1742843977193945000
# 15:32:25> PLE_Bob Tx: message: 14
# 15:32:25> ALE_Bob Rx: message 95: 1,95,1742843977193945000
# 15:32:26> PLE_Alice Rx: from ('127.0.0.1', 31111): 13
# 15:32:26> DLE_Alice Rx: message 102: 13
# 15:32:26> DLE_Alice FSM: state: 1 event type: 2
# 15:32:26> ACK # 3 does not match local seq # 4
# 15:32:26> PLE_Alice Rx: from ('127.0.0.1', 31111): 14
# 15:32:26> DLE_Alice Rx: message 103: 14
# 15:32:26> DLE_Alice FSM: state: 1 event type: 2
# 15:32:26> DLE_Alice Tx: message 96: 1,96,1742843977193949000
# 15:32:26> DLE_Alice FSM: state: 0 event type: 0
# 15:32:26> DLE_Alice FSM: to send: 1,96,1742843977193949000
# 15:32:26> PLE_Alice Tx: message: 051,96,1742843977193949000
# 15:32:28> PLE_Bob Rx: from ('127.0.0.1', 30000): 051,96,1742843977193949000
# 15:32:28> DLE_Bob Rx: message 121: 051,96,1742843977193949000
# 15:32:28> DLE_Bob FSM: state: 0 event type: 1
# 15:32:28> DLE_Bob FSM: received: 1,96,1742843977193949000
# 15:32:28> ALE_Bob Rx: message 96: 1,96,1742843977193949000
# 15:32:28> PLE_Bob Tx: message: 15
# 15:32:30> PLE_Alice Rx: from ('127.0.0.1', 31111): 15
# 15:32:30> DLE_Alice Rx: message 104: 15
# 15:32:30> DLE_Alice FSM: state: 1 event type: 2
# 15:32:30> DLE_Alice Tx: message 97: 1,97,1742843977193953000
# 15:32:30> DLE_Alice FSM: state: 0 event type: 0
# 15:32:30> DLE_Alice FSM: to send: 1,97,1742843977193953000
# 15:32:30> PLE_Alice Tx: message: 061,97,1742843977193953000
# 15:32:31> PLE_Bob Rx: from ('127.0.0.1', 30000): 061,97,1742843977193953000
# 15:32:31> DLE_Bob Rx: message 122: 061,97,1742843977193953000
# 15:32:31> DLE_Bob FSM: state: 0 event type: 1
# 15:32:31> DLE_Bob FSM: received: 1,97,1742843977193953000
# 15:32:31> ALE_Bob Rx: message 97: 1,97,1742843977193953000
# 15:32:31> PLE_Bob Tx: message: 16
# 15:32:31> packet loss
# 15:32:36> DLE_Alice FSM: state: 1 event type: 3
# 15:32:36> DLE_Alice FSM: to resend frame 6 1,97,1742843977193953000
# 15:32:36> PLE_Alice Tx: message: 061,97,1742843977193953000
# 15:32:36> Transmission Duplicated
# 15:32:36> PLE_Bob Rx: from ('127.0.0.1', 30000): 061,97,1742843977193953000
# 15:32:36> DLE_Bob Rx: message 123: 061,97,1742843977193953000
# 15:32:36> DLE_Bob FSM: state: 0 event type: 1
# 15:32:36> DLE_Bob FSM: received: 1,97,1742843977193953000
# 15:32:36> DLE_Bob FSM: received received frame 6 but expected 7
# 15:32:36> PLE_Bob Tx: message: 16
# 15:32:37> PLE_Alice Rx: from ('127.0.0.1', 31111): 16
# 15:32:37> DLE_Alice Rx: message 105: 16
# 15:32:37> DLE_Alice FSM: state: 1 event type: 2
# 15:32:37> DLE_Alice Tx: message 98: 1,98,1742843977193957000
# 15:32:37> DLE_Alice FSM: state: 0 event type: 0
# 15:32:37> DLE_Alice FSM: to send: 1,98,1742843977193957000
# 15:32:37> PLE_Alice Tx: message: 071,98,1742843977193957000
# 15:32:38> PLE_Bob Rx: from ('127.0.0.1', 30000): 061,97,1742843977193953000
# 15:32:38> DLE_Bob Rx: message 124: 061,97,1742843977193953000
# 15:32:38> DLE_Bob FSM: state: 0 event type: 1
# 15:32:38> DLE_Bob FSM: received: 1,97,1742843977193953000
# 15:32:38> DLE_Bob FSM: received received frame 6 but expected 7
# 15:32:38> PLE_Bob Tx: message: 16
# 15:32:39> PLE_Bob Rx: from ('127.0.0.1', 30000): 071,98,1742843977193957000
# 15:32:39> DLE_Bob Rx: message 125: 071,98,1742843977193957000
# 15:32:39> DLE_Bob FSM: state: 0 event type: 1
# 15:32:39> DLE_Bob FSM: received: 1,98,1742843977193957000
# 15:32:39> ALE_Bob Rx: message 98: 1,98,1742843977193957000
# 15:32:39> PLE_Bob Tx: message: 17
# 15:32:39> Transmission Duplicated
# 15:32:40> PLE_Alice Rx: from ('127.0.0.1', 31111): 16
# 15:32:40> DLE_Alice Rx: message 106: 16
# 15:32:40> DLE_Alice FSM: state: 1 event type: 2
# 15:32:40> ACK # 6 does not match local seq # 7
# 15:32:40> PLE_Alice Rx: from ('127.0.0.1', 31111): 17
# 15:32:40> DLE_Alice Rx: message 107: 17
# 15:32:40> DLE_Alice FSM: state: 1 event type: 2
# 15:32:40> DLE_Alice Tx: message 99: 1,99,1742843977193961000
# 15:32:40> DLE_Alice FSM: state: 0 event type: 0
# 15:32:40> DLE_Alice FSM: to send: 1,99,1742843977193961000
# 15:32:40> PLE_Alice Tx: message: 081,99,1742843977193961000
# 15:32:40> PLE_Alice Rx: from ('127.0.0.1', 31111): 17
# 15:32:40> DLE_Alice Rx: message 108: 17
# 15:32:40> DLE_Alice FSM: state: 1 event type: 2
# 15:32:40> ACK # 7 does not match local seq # 8
# 15:32:42> PLE_Bob Rx: from ('127.0.0.1', 30000): 081,99,1742843977193961000
# 15:32:42> DLE_Bob Rx: message 126: 081,99,1742843977193961000
# 15:32:42> DLE_Bob FSM: state: 0 event type: 1
# 15:32:42> DLE_Bob FSM: received: 1,99,1742843977193961000
# 15:32:42> PLE_Bob Tx: message: 18
# 15:32:42> ALE_Bob Rx: message 99: 1,99,1742843977193961000
# 15:32:42> PLE_Alice Rx: from ('127.0.0.1', 31111): 18
# 15:32:42> DLE_Alice Rx: message 109: 18
# 15:32:42> DLE_Alice FSM: state: 1 event type: 2
# 15:32:42> DLE_Alice Tx: message 100: 1,100,1742843977193965000
# 15:32:42> DLE_Alice FSM: state: 0 event type: 0
# 15:32:42> DLE_Alice FSM: to send: 1,100,1742843977193965000
# 15:32:42> PLE_Alice Tx: message: 091,100,1742843977193965000
# 15:32:43> PLE_Bob Rx: from ('127.0.0.1', 30000): 091,100,1742843977193965000
# 15:32:43> DLE_Bob Rx: message 127: 091,100,1742843977193965000
# 15:32:43> DLE_Bob FSM: state: 0 event type: 1
# 15:32:43> DLE_Bob FSM: received: 1,100,1742843977193965000
# 15:32:43> PLE_Bob Tx: message: 19
# 15:32:43> ALE_Bob Rx: message 100: 1,100,1742843977193965000
# 15:32:45> PLE_Alice Rx: from ('127.0.0.1', 31111): 19
# 15:32:45> DLE_Alice Rx: message 110: 19
# 15:32:45> DLE_Alice FSM: state: 1 event type: 2
