# %%
import time
import socket
from queue import Queue 
from threading import Thread, Condition
from ipywidgets import widgets
from IPython.display import display
import random

# %%
class EXP_Output:
    def __init__(self):
        #self.out = widgets.Output(layout={'border': '1px solid black'})
        #display(self.out)
        #with self.out:
        #print("Experiment outputs")

        self.Queue_Print = Queue()
        self.thread = Thread(target=self.loop_Print)
        self.thread.start()

    def print(self, msg):
        text_out = time.strftime("%H:%M:%S", time.localtime()) + "> "
        self.Queue_Print.put(text_out+msg)

    def loop_Print(self):
        while True:
            msg = self.Queue_Print.get()
            #with self.out:
            print(msg)
            self.Queue_Print.task_done()

# %%
class ALE_TextInput:
    
    def __init__(self, exp_out):
        
        self.Queue_User = Queue()
        self.exp_out = exp_out

        # Create a text input widget
        self.Text = widgets.Text(
                        value='',
                        placeholder='Type something and press enter',
                        description='To send:',
                        disabled=False
                    )

        # create a button object
        self.Botton =  widgets.Button(
                            description='Submit',
                            disabled=False,
                            button_style='', 
                            tooltip='Click me to submit a string',
                        )

        # Define a function to handle the click action on the button
        def on_submit_button_clicked(b):

            global thread_running
            
            msg = self.Text.value
            #self.exp_out.print("ALE_0: received input: "+str(msg))
                
            if thread_running == True:
                if msg == "end":
                    thread_running = False
                
                for i in range(20):
                    self.Queue_User.put(msg+str(i))

            self.Text.value = ''  # Clear the input field after submission

        # Attach the event to the button
        self.Botton.on_click(on_submit_button_clicked)
        
        # Display the widgets
        display(self.Text, self.Botton)
        
    # to get a message from user queue. this function can block the thread
    def get(self):
        return self.Queue_User.get()

# %%
class ALE_TR:
    
    def __init__(self, name, upper_Tx, lower_TR, exp_out):
        
        self.Name     = name
        self.Upper_Tx = upper_Tx  # must provide get()
        self.Lower_TR = lower_TR  # must provide send(msg), and receive()
        self.exp_out  = exp_out
        
    def loop_Tx(self):

        global thread_running
        c = 0
        self.exp_out.print(self.Name + ": loop_Tx starting")
    
        while (thread_running == True):

            c = c + 1

            # get text from Upper_Tx, which must provide a get method
            # this thread is blocked here
            msg = self.Upper_Tx.get()
            
            text_out = self.Name + " Tx: message " + str(c) + ": " + str(msg)
            self.exp_out.print(text_out)

            # add the text to the queue
            self.Lower_TR.send(msg)
            
    def loop_Rx(self):
        
        global thread_running
        c = 0
        self.exp_out.print(self.Name + ": loop_Rx starting")
    
        while (thread_running == True):

            c = c + 1

            # get message from a lower layer
            # this thread is blocked here
            msg = self.Lower_TR.receive()
            
            text_out = self.Name + " Rx: message " + str(c) + ": " + str(msg)
            self.exp_out.print(text_out)

# %%
# state of DLE
STATE_READY_TO_SEND = 0 # ready to send a packet to the DLE entity in another node through lower layer
STATE_WAITING_ACK   = 1 # waiting for ACK from the DLE entity in another node

# events of DLE
EVENT_UPPER_TX  = 0 # upper layer wants to send a packet
EVENT_LOWER_DAT = 1 # lower layer forwards an incoming data packet
EVENT_LOWER_ACK = 2 # lower layer forwards an incoming data packet
EVENT_TIMEOUT   = 3 # timer timeout
        
class DLE_TR_FSM:
    
    def __init__(self, name, lower_TR, exp_out):
        
        self.Name      = name
        self.Lower_TR  = lower_TR   # must provide send(msg) and receive()
        self.Queue_Tx  = Queue()
        self.Queue_Rx  = Queue()
        self.exp_out   = exp_out
        
        # create a queue for Finite State Machine
        self.Queue_FSM = Queue()
        
        # create a flag = condition to start sending
        self.cv_TxOp = Condition()
        self.TxOp    = True

        # init state to STATE_WAITING_UPPER
        self.State = STATE_READY_TO_SEND
        
        self.Procedure = [[self.FSM_upper_Tx, self.FSM_abnormal],
                          [self.FSM_lower_Rx, self.FSM_lower_Rx],
                          [self.FSM_abnormal, self.FSM_lower_Rx_ack],
                          [self.FSM_abnormal, self.FSM_timeout]] 
        

        # new features for retransmission
        # timer
        self.cv_Timer      = Condition()
        self.timer_active  = False
        self.timer_counter = 0
        
        # transmission 
        self.tx_buffer  = ''
        self.tx_seq_num = '0'
        
        # reception
        self.tx_ack_num = '0'
        
        
    def loop_Tx(self):

        global thread_running
        c = 0
        self.exp_out.print(self.Name + ": loop_Tx starting")
    
        while (thread_running == True):

            # waiting for the ready to sent signal
            with self.cv_TxOp: 
                while (self.TxOp != True): 
                    self.cv_TxOp.wait()
            
                self.TxOp = False
                
                c = c + 1

                # get a message from queue
                msg = self.Queue_Tx.get()
                text_out = self.Name + " Tx: message " + str(c) + ": " + str(msg)
                self.exp_out.print(text_out)
            
                self.event_add(EVENT_UPPER_TX, msg) 

    def loop_Rx(self):
        
        global thread_running
        c = 0
        self.exp_out.print(self.Name + ": loop_Rx starting")
    
        while (thread_running == True):

            c = c + 1

            # get message from a lower layer
            # this thread is blocked here
            msg = self.Lower_TR.receive()
            
            text_out = self.Name + " Rx: message " + str(c) + ": " + str(msg)
            self.exp_out.print(text_out)
            
            # add an event for FSM, assuming that msg is a sequence of bytes
            msg_type = msg[0]
            if (msg_type == '0'):
                self.event_add(EVENT_LOWER_DAT, msg[1:])
            elif (msg_type == '1'):
                self.event_add(EVENT_LOWER_ACK, msg[1:])
            else:
                text_out = self.Name + " Rx: message type unknown " + msg_type
                self.exp_out.print(text_out)

    def receive(self):
        return self.Queue_Rx.get()
    
    def send(self, msg):
        self.Queue_Tx.put(msg)
        
    def event_add(self, ev_type, msg):
        
        # preparing an event
        if (isinstance(msg, str)):
            msg = msg.encode()
        
        # the event is a sequence of bytes
        event = ev_type.to_bytes(1, "big")+msg
        
        # add event to queue
        self.Queue_FSM.put(event)        
        

    def loop_FSM(self):
        
        global thread_running
        self.exp_out.print(self.Name + ": loop_FSM starting")
        
        while (thread_running == True):
            
            # get the next event
            event = self.Queue_FSM.get()
            
            ev_type = event[0]
            
            text_out = self.Name + " FSM: state: " + str(self.State)+" event type: " + str(ev_type)
            self.exp_out.print(text_out)
            
            # process the event
            msg = event[1:].decode('utf-8') # message becomes a string
            self.Procedure[ev_type][self.State](msg)
        
    def FSM_abnormal(self, msg):
        
        text_out = self.Name + " FSM: error! " + msg
        self.exp_out.print(text_out)
    
    def FSM_upper_Tx(self, msg):   
        
        text_out = self.Name + " FSM: to send: " + msg
        self.exp_out.print(text_out)

        # buffer the message (for retransmission)
        self.tx_buffer = msg
        
        # prepare to send a data message
        msg = '0' + self.tx_seq_num + msg     # inicating a new packet and its sequence number
        self.Lower_TR.send(msg)

        # waiting for ACK
        self.State = STATE_WAITING_ACK
        
        # start timer
        with self.cv_Timer:
            self.timer_active  = True
            self.timer_counter = 10
            self.cv_Timer.notify()    
    
    def FSM_lower_Rx(self, msg):

        # get the sequence number
        seq = msg[0]
        msg = msg[1:]
        
        # received a new data packet        
        text_out = self.Name + " FSM: received: " + msg
        self.exp_out.print(text_out)

        if (seq == self.tx_ack_num):
            
            # put the message in a receiving queue
            self.Queue_Rx.put(msg)
            
            self.tx_ack_num = chr(ord(self.tx_ack_num) + 1)
            if (self.tx_ack_num == chr(ord('9') + 1)):
                self.tx_ack_num = '0'
        
        else:
            text_out  = self.Name + " FSM: received received frame " + seq
            text_out += " but expected " + self.tx_ack_num
            self.exp_out.print(text_out)
            

        # to send an ACK
        self.Lower_TR.send('1'+seq)

                
    def FSM_lower_Rx_ack(self, msg):
        
        ack = msg[0] # get the ack number
        if (ack != self.tx_seq_num):
            
            # the received ack does not match the seq
            text_out = "ACK # " + ack + " does not match local seq # " + self.tx_seq_num
            self.exp_out.print(text_out)
            return

        # stop timer
        self.timer_active = False
        
        # inc the seq
        self.tx_seq_num = chr(ord(self.tx_seq_num) + 1)
        if (self.tx_seq_num == chr(ord('9') + 1)):
                self.tx_seq_num = '0'
        
        # ready to send the next upper layer packet
        with self.cv_TxOp:
            self.State = STATE_READY_TO_SEND
            self.TxOp  = True
            self.cv_TxOp.notify()
            
    def FSM_timeout(self, msg):
        
        text_out = self.Name + " FSM: to resend frame " + self.tx_seq_num + " " + self.tx_buffer
        self.exp_out.print(text_out)
        
        # prepare to send a data message
        msg = '0' + self.tx_seq_num + self.tx_buffer     # inicating a new packet and its sequence number
        self.Lower_TR.send(msg)
        
        # start timer
        with self.cv_Timer:
            self.timer_active  = True
            self.timer_counter = 10
            self.cv_Timer.notify()

    def loop_timer(self):
        
        global thread_running
        self.exp_out.print(self.Name + ": loop_Timer starting")
        
        while (thread_running == True):
            
            with self.cv_Timer: 
                while (self.timer_active == False): 
                    self.cv_Timer.wait() 
            
                time.sleep(0.5)

                if (self.timer_counter == 0):
                    # add an event for timeout
                    self.event_add(EVENT_TIMEOUT, 'x')
                    self.timer_active = False

                else:
                    self.timer_counter = self.timer_counter - 1

# %%
class PLE_TR:

    def __init__(self, name, Socket, AP_Tx, AP_Rx, exp_out):
        
        self.Name      = name
        self.Socket    = Socket
        self.AP_Tx     = AP_Tx
        self.AP_Rx     = AP_Rx
        self.Queue_Tx  = Queue()
        self.Queue_Rx  = Queue()
        self.exp_out   = exp_out
        
    def loop_Tx(self):
        
        global thread_running
        self.exp_out.print(self.Name + ": loop_Tx starting")
    
        while (thread_running == True):
        
            # get a message from queue
            msg = self.Queue_Tx.get()
            
            text_out = self.Name + " Tx: message: " + str(msg)
            self.exp_out.print(text_out)
            
            # sending the message using socket
            msg_bytes = str.encode(msg)
            if (random.random() < 0.1):
                self.exp_out.print("packet loss")

            elif (random.random() < 0.05):
                self.Socket.sendto(msg_bytes, self.AP_Tx)
                self.Socket.sendto(msg_bytes, self.AP_Tx)
                self.exp_out.print("Transmission Duplicated")
            else:
                # sending the message using socket
                self.Socket.sendto(msg_bytes, self.AP_Tx)

    def loop_Rx(self):
        
        global thread_running
        global bufferSize
        self.exp_out.print(self.Name + ": loop_Rx starting")
    
        # binding the socket with the IP and port
        self.Socket.bind(self.AP_Rx)
        
        while (thread_running == True):
        
            # get a message from socket, this thread is blocked here
            msg_addr = self.Socket.recvfrom(bufferSize)

            # Random delay ranging from 0 - 2 seconds.
            delay = random.uniform(0, 2)
            time.sleep(delay)
    
            msg  = msg_addr[0].decode('utf-8')
            addr = msg_addr[1]
            
            text_out = self.Name + " Rx: from " + str(addr) + ": " + str(msg)
            self.exp_out.print(text_out)
            
            self.Queue_Rx.put(msg)
            
    def send(self, msg):
        self.Queue_Tx.put(msg)
        
    def receive(self):
        return self.Queue_Rx.get()

# %%
thread_running = False
bufferSize = 1024

# (0) creating an output object
exp_out = EXP_Output()

# (1) create physical layer entities
AP_local_1  = ("127.0.0.1", 30000)
AP_remote_1 = ("127.0.0.1", 31111)
Socket_1    = socket.socket(family=socket.AF_INET, type=socket.SOCK_DGRAM)
PLE_1       = PLE_TR("PLE_Alice", Socket_1, AP_remote_1, AP_local_1, exp_out)

# (2) create date link layer entities
DLE_1 = DLE_TR_FSM("DLE_Alice", PLE_1, exp_out)

# (3) create application layer entities
ALE_0 = ALE_TextInput(exp_out)
ALE_1 = ALE_TR("ALE_Alice", ALE_0, DLE_1, exp_out)
# Out:
# Text(value='', description='To send:', placeholder='Type something and press enter')
# Button(description='Submit', style=ButtonStyle(), tooltip='Click me to submit a string')
# 19:03:59> ALE_Alice: loop_Tx starting
# 19:03:59> ALE_Alice: loop_Rx starting
# 19:03:59> DLE_Alice: loop_Tx starting
# 19:03:59> DLE_Alice: loop_Rx starting
# 19:03:59> PLE_Alice: loop_Tx starting
# 19:03:59> PLE_Alice: loop_Rx starting
# 19:03:59> ALE_Bob: loop_Tx starting
# 19:03:59> ALE_Bob: loop_Rx starting
# 19:03:59> DLE_Bob: loop_Tx starting
# 19:03:59> DLE_Bob: loop_Rx starting
# 19:03:59> PLE_Bob: loop_Tx starting
# 19:03:59> PLE_Bob: loop_Rx starting
# 19:03:59> DLE_Alice: loop_FSM starting
# 19:03:59> DLE_Bob: loop_FSM starting
# 19:03:59> DLE_Alice: loop_Timer starting
# 19:03:59> DLE_Bob: loop_Timer starting
# 19:06:44> ALE_Alice Tx: message 1: Alice to Bob0
# 19:06:44> ALE_Alice Tx: message 2: Alice to Bob1
# 19:06:44> ALE_Alice Tx: message 3: Alice to Bob2
# 19:06:44> ALE_Alice Tx: message 4: Alice to Bob3
# 19:06:44> ALE_Alice Tx: message 5: Alice to Bob4
# 19:06:44> ALE_Alice Tx: message 6: Alice to Bob5
# 19:06:44> ALE_Alice Tx: message 7: Alice to Bob6
# 19:06:44> ALE_Alice Tx: message 8: Alice to Bob7
# 19:06:44> ALE_Alice Tx: message 9: Alice to Bob8
# 19:06:44> ALE_Alice Tx: message 10: Alice to Bob9
# 19:06:44> ALE_Alice Tx: message 11: Alice to Bob10
# 19:06:44> ALE_Alice Tx: message 12: Alice to Bob11
# 19:06:44> ALE_Alice Tx: message 13: Alice to Bob12
# 19:06:44> ALE_Alice Tx: message 14: Alice to Bob13
# 19:06:44> ALE_Alice Tx: message 15: Alice to Bob14
# 19:06:44> ALE_Alice Tx: message 16: Alice to Bob15
# 19:06:44> ALE_Alice Tx: message 17: Alice to Bob16
# 19:06:44> ALE_Alice Tx: message 18: Alice to Bob17
# 19:06:44> ALE_Alice Tx: message 19: Alice to Bob18
# 19:06:44> ALE_Alice Tx: message 20: Alice to Bob19
# 19:06:44> DLE_Alice Tx: message 1: Alice to Bob0
# 19:06:44> DLE_Alice FSM: state: 0 event type: 0
# 19:06:44> DLE_Alice FSM: to send: Alice to Bob0
# 19:06:44> PLE_Alice Tx: message: 00Alice to Bob0
# 19:06:44> PLE_Bob Rx: from ('127.0.0.1', 30000): 00Alice to Bob0
# 19:06:44> DLE_Bob Rx: message 1: 00Alice to Bob0
# 19:06:44> DLE_Bob FSM: state: 0 event type: 1
# 19:06:44> DLE_Bob FSM: received: Alice to Bob0
# 19:06:44> ALE_Bob Rx: message 1: Alice to Bob0
# 19:06:44> PLE_Bob Tx: message: 10
# 19:06:45> PLE_Alice Rx: from ('127.0.0.1', 31111): 10
# 19:06:45> DLE_Alice Rx: message 1: 10
# 19:06:45> DLE_Alice FSM: state: 1 event type: 2
# 19:06:45> DLE_Alice Tx: message 2: Alice to Bob1
# 19:06:45> DLE_Alice FSM: state: 0 event type: 0
# 19:06:45> DLE_Alice FSM: to send: Alice to Bob1
# 19:06:45> PLE_Alice Tx: message: 01Alice to Bob1
# 19:06:46> PLE_Bob Rx: from ('127.0.0.1', 30000): 01Alice to Bob1
# 19:06:46> DLE_Bob Rx: message 2: 01Alice to Bob1
# 19:06:46> DLE_Bob FSM: state: 0 event type: 1
# 19:06:46> DLE_Bob FSM: received: Alice to Bob1
# 19:06:46> PLE_Bob Tx: message: 11
# 19:06:46> ALE_Bob Rx: message 2: Alice to Bob1
# 19:06:46> PLE_Alice Rx: from ('127.0.0.1', 31111): 11
# 19:06:46> DLE_Alice Rx: message 2: 11
# 19:06:46> DLE_Alice FSM: state: 1 event type: 2
# 19:06:46> DLE_Alice Tx: message 3: Alice to Bob2
# 19:06:46> DLE_Alice FSM: state: 0 event type: 0
# 19:06:46> DLE_Alice FSM: to send: Alice to Bob2
# 19:06:46> PLE_Alice Tx: message: 02Alice to Bob2
# 19:06:48> PLE_Bob Rx: from ('127.0.0.1', 30000): 02Alice to Bob2
# 19:06:48> DLE_Bob Rx: message 3: 02Alice to Bob2
# 19:06:48> DLE_Bob FSM: state: 0 event type: 1
# 19:06:48> DLE_Bob FSM: received: Alice to Bob2
# 19:06:48> ALE_Bob Rx: message 3: Alice to Bob2
# 19:06:48> PLE_Bob Tx: message: 12
# 19:06:50> PLE_Alice Rx: from ('127.0.0.1', 31111): 12
# 19:06:50> DLE_Alice Rx: message 3: 12
# 19:06:50> DLE_Alice FSM: state: 1 event type: 2
# 19:06:50> DLE_Alice Tx: message 4: Alice to Bob3
# 19:06:50> DLE_Alice FSM: state: 0 event type: 0
# 19:06:50> DLE_Alice FSM: to send: Alice to Bob3
# 19:06:50> PLE_Alice Tx: message: 03Alice to Bob3
# 19:06:50> PLE_Bob Rx: from ('127.0.0.1', 30000): 03Alice to Bob3
# 19:06:50> DLE_Bob Rx: message 4: 03Alice to Bob3
# 19:06:50> DLE_Bob FSM: state: 0 event type: 1
# 19:06:50> DLE_Bob FSM: received: Alice to Bob3
# 19:06:50> ALE_Bob Rx: message 4: Alice to Bob3
# 19:06:50> PLE_Bob Tx: message: 13
# 19:06:51> PLE_Alice Rx: from ('127.0.0.1', 31111): 13
# 19:06:51> DLE_Alice Rx: message 4: 13
# 19:06:51> DLE_Alice FSM: state: 1 event type: 2
# 19:06:51> DLE_Alice Tx: message 5: Alice to Bob4
# 19:06:51> DLE_Alice FSM: state: 0 event type: 0
# 19:06:51> DLE_Alice FSM: to send: Alice to Bob4
# 19:06:51> PLE_Alice Tx: message: 04Alice to Bob4
# 19:06:52> PLE_Bob Rx: from ('127.0.0.1', 30000): 04Alice to Bob4
# 19:06:52> DLE_Bob Rx: message 5: 04Alice to Bob4
# 19:06:52> DLE_Bob FSM: state: 0 event type: 1
# 19:06:52> DLE_Bob FSM: received: Alice to Bob4
# 19:06:52> PLE_Bob Tx: message: 14
# 19:06:52> ALE_Bob Rx: message 5: Alice to Bob4
# 19:06:52> PLE_Alice Rx: from ('127.0.0.1', 31111): 14
# 19:06:52> DLE_Alice Rx: message 5: 14
# 19:06:52> DLE_Alice FSM: state: 1 event type: 2
# 19:06:52> DLE_Alice Tx: message 6: Alice to Bob5
# 19:06:52> DLE_Alice FSM: state: 0 event type: 0
# 19:06:52> DLE_Alice FSM: to send: Alice to Bob5
# 19:06:52> PLE_Alice Tx: message: 05Alice to Bob5
# 19:06:53> ALE_Bob Tx: message 1: Bob to Alice0
# 19:06:53> ALE_Bob Tx: message 2: Bob to Alice1
# 19:06:53> ALE_Bob Tx: message 3: Bob to Alice2
# 19:06:53> ALE_Bob Tx: message 4: Bob to Alice3
# 19:06:53> ALE_Bob Tx: message 5: Bob to Alice4
# 19:06:53> ALE_Bob Tx: message 6: Bob to Alice5
# 19:06:53> ALE_Bob Tx: message 7: Bob to Alice6
# 19:06:53> ALE_Bob Tx: message 8: Bob to Alice7
# 19:06:53> ALE_Bob Tx: message 9: Bob to Alice8
# 19:06:53> ALE_Bob Tx: message 10: Bob to Alice9
# 19:06:53> ALE_Bob Tx: message 11: Bob to Alice10
# 19:06:53> ALE_Bob Tx: message 12: Bob to Alice11
# 19:06:53> ALE_Bob Tx: message 13: Bob to Alice12
# 19:06:53> ALE_Bob Tx: message 14: Bob to Alice13
# 19:06:53> ALE_Bob Tx: message 15: Bob to Alice14
# 19:06:53> ALE_Bob Tx: message 16: Bob to Alice15
# 19:06:53> ALE_Bob Tx: message 17: Bob to Alice16
# 19:06:53> ALE_Bob Tx: message 18: Bob to Alice17
# 19:06:53> ALE_Bob Tx: message 19: Bob to Alice18
# 19:06:53> ALE_Bob Tx: message 20: Bob to Alice19
# 19:06:53> DLE_Bob Tx: message 1: Bob to Alice0
# 19:06:53> DLE_Bob FSM: state: 0 event type: 0
# 19:06:53> DLE_Bob FSM: to send: Bob to Alice0
# 19:06:53> PLE_Bob Tx: message: 00Bob to Alice0
# 19:06:54> PLE_Bob Rx: from ('127.0.0.1', 30000): 05Alice to Bob5
# 19:06:54> DLE_Bob Rx: message 6: 05Alice to Bob5
# 19:06:54> DLE_Bob FSM: state: 1 event type: 1
# 19:06:54> DLE_Bob FSM: received: Alice to Bob5
# 19:06:54> PLE_Bob Tx: message: 15
# 19:06:54> ALE_Bob Rx: message 6: Alice to Bob5
# 19:06:54> PLE_Alice Rx: from ('127.0.0.1', 31111): 00Bob to Alice0
# 19:06:54> DLE_Alice Rx: message 6: 00Bob to Alice0
# 19:06:54> DLE_Alice FSM: state: 1 event type: 1
# 19:06:54> DLE_Alice FSM: received: Bob to Alice0
# 19:06:54> ALE_Alice Rx: message 1: Bob to Alice0
# 19:06:54> PLE_Alice Tx: message: 10
# 19:06:55> PLE_Bob Rx: from ('127.0.0.1', 30000): 10
# 19:06:55> DLE_Bob Rx: message 7: 10
# 19:06:55> DLE_Bob FSM: state: 1 event type: 2
# 19:06:55> DLE_Bob Tx: message 2: Bob to Alice1
# 19:06:55> DLE_Bob FSM: state: 0 event type: 0
# 19:06:55> DLE_Bob FSM: to send: Bob to Alice1
# 19:06:55> PLE_Bob Tx: message: 01Bob to Alice1
# 19:06:55> PLE_Alice Rx: from ('127.0.0.1', 31111): 15
# 19:06:55> DLE_Alice Rx: message 7: 15
# 19:06:55> DLE_Alice FSM: state: 1 event type: 2
# 19:06:55> DLE_Alice Tx: message 7: Alice to Bob6
# 19:06:55> DLE_Alice FSM: state: 0 event type: 0
# 19:06:55> DLE_Alice FSM: to send: Alice to Bob6
# 19:06:55> PLE_Alice Tx: message: 06Alice to Bob6
# 19:06:55> PLE_Alice Rx: from ('127.0.0.1', 31111): 01Bob to Alice1
# 19:06:55> DLE_Alice Rx: message 8: 01Bob to Alice1
# 19:06:56> PLE_Bob Rx: from ('127.0.0.1', 30000): 06Alice to Bob6
# 19:06:56> DLE_Bob Rx: message 8: 06Alice to Bob6
# 19:06:56> DLE_Bob FSM: state: 1 event type: 1
# 19:06:56> DLE_Bob FSM: received: Alice to Bob6
# 19:06:56> PLE_Bob Tx: message: 16
# 19:06:56> ALE_Bob Rx: message 7: Alice to Bob6
# 19:06:56> DLE_Alice FSM: state: 1 event type: 1
# 19:06:56> DLE_Alice FSM: received: Bob to Alice1
# 19:06:56> PLE_Alice Tx: message: 11
# 19:06:56> ALE_Alice Rx: message 2: Bob to Alice1
# 19:06:57> PLE_Alice Rx: from ('127.0.0.1', 31111): 16
# 19:06:57> DLE_Alice Rx: message 9: 16
# 19:06:57> DLE_Alice FSM: state: 1 event type: 2
# 19:06:57> DLE_Alice Tx: message 8: Alice to Bob7
# 19:06:57> DLE_Alice FSM: state: 0 event type: 0
# 19:06:57> DLE_Alice FSM: to send: Alice to Bob7
# 19:06:57> PLE_Alice Tx: message: 07Alice to Bob7
# 19:06:58> PLE_Bob Rx: from ('127.0.0.1', 30000): 11
# 19:06:58> DLE_Bob Rx: message 9: 11
# 19:06:58> DLE_Bob FSM: state: 1 event type: 2
# 19:06:58> DLE_Bob Tx: message 3: Bob to Alice2
# 19:06:58> DLE_Bob FSM: state: 0 event type: 0
# 19:06:58> DLE_Bob FSM: to send: Bob to Alice2
# 19:06:58> PLE_Bob Tx: message: 02Bob to Alice2
# 19:06:59> PLE_Alice Rx: from ('127.0.0.1', 31111): 02Bob to Alice2
# 19:06:59> DLE_Alice Rx: message 10: 02Bob to Alice2
# 19:06:59> DLE_Alice FSM: state: 1 event type: 1
# 19:06:59> DLE_Alice FSM: received: Bob to Alice2
# 19:06:59> PLE_Alice Tx: message: 12
# 19:06:59> ALE_Alice Rx: message 3: Bob to Alice2
# 19:06:59> PLE_Bob Rx: from ('127.0.0.1', 30000): 07Alice to Bob7
# 19:06:59> DLE_Bob Rx: message 10: 07Alice to Bob7
# 19:06:59> DLE_Bob FSM: state: 1 event type: 1
# 19:06:59> DLE_Bob FSM: received: Alice to Bob7
# 19:06:59> PLE_Bob Tx: message: 17
# 19:06:59> ALE_Bob Rx: message 8: Alice to Bob7
# 19:07:00> PLE_Bob Rx: from ('127.0.0.1', 30000): 12
# 19:07:00> DLE_Bob Rx: message 11: 12
# 19:07:00> DLE_Bob FSM: state: 1 event type: 2
# 19:07:00> DLE_Bob Tx: message 4: Bob to Alice3
# 19:07:00> DLE_Bob FSM: state: 0 event type: 0
# 19:07:00> DLE_Bob FSM: to send: Bob to Alice3
# 19:07:00> PLE_Bob Tx: message: 03Bob to Alice3
# 19:07:01> PLE_Alice Rx: from ('127.0.0.1', 31111): 17
# 19:07:01> DLE_Alice Rx: message 11: 17
# 19:07:01> DLE_Alice FSM: state: 1 event type: 2
# 19:07:01> DLE_Alice Tx: message 9: Alice to Bob8
# 19:07:01> DLE_Alice FSM: state: 0 event type: 0
# 19:07:01> DLE_Alice FSM: to send: Alice to Bob8
# 19:07:01> PLE_Alice Tx: message: 08Alice to Bob8
# 19:07:02> PLE_Alice Rx: from ('127.0.0.1', 31111): 03Bob to Alice3
# 19:07:02> DLE_Alice Rx: message 12: 03Bob to Alice3
# 19:07:02> DLE_Alice FSM: state: 1 event type: 1
# 19:07:02> DLE_Alice FSM: received: Bob to Alice3
# 19:07:02> ALE_Alice Rx: message 4: Bob to Alice3
# 19:07:02> PLE_Alice Tx: message: 13
# 19:07:02> PLE_Bob Rx: from ('127.0.0.1', 30000): 08Alice to Bob8
# 19:07:02> DLE_Bob Rx: message 12: 08Alice to Bob8
# 19:07:02> DLE_Bob FSM: state: 1 event type: 1
# 19:07:02> DLE_Bob FSM: received: Alice to Bob8
# 19:07:02> PLE_Bob Tx: message: 18
# 19:07:02> ALE_Bob Rx: message 9: Alice to Bob8
# 19:07:03> PLE_Bob Rx: from ('127.0.0.1', 30000): 13
# 19:07:03> DLE_Bob Rx: message 13: 13
# 19:07:03> DLE_Bob FSM: state: 1 event type: 2
# 19:07:03> DLE_Bob Tx: message 5: Bob to Alice4
# 19:07:03> DLE_Bob FSM: state: 0 event type: 0
# 19:07:03> DLE_Bob FSM: to send: Bob to Alice4
# 19:07:03> PLE_Bob Tx: message: 04Bob to Alice4
# 19:07:04> PLE_Alice Rx: from ('127.0.0.1', 31111): 18
# 19:07:04> DLE_Alice Rx: message 13: 18
# 19:07:04> DLE_Alice FSM: state: 1 event type: 2
# 19:07:04> DLE_Alice Tx: message 10: Alice to Bob9
# 19:07:04> DLE_Alice FSM: state: 0 event type: 0
# 19:07:04> DLE_Alice FSM: to send: Alice to Bob9
# 19:07:04> PLE_Alice Tx: message: 09Alice to Bob9
# 19:07:05> PLE_Bob Rx: from ('127.0.0.1', 30000): 09Alice to Bob9
# 19:07:05> DLE_Bob Rx: message 14: 09Alice to Bob9
# 19:07:05> DLE_Bob FSM: state: 1 event type: 1
# 19:07:05> DLE_Bob FSM: received: Alice to Bob9
# 19:07:05> PLE_Bob Tx: message: 19
# 19:07:05> ALE_Bob Rx: message 10: Alice to Bob9
# 19:07:05> PLE_Alice Rx: from ('127.0.0.1', 31111): 04Bob to Alice4
# 19:07:05> DLE_Alice Rx: message 14: 04Bob to Alice4
# 19:07:05> DLE_Alice FSM: state: 1 event type: 1
# 19:07:05> DLE_Alice FSM: received: Bob to Alice4
# 19:07:05> PLE_Alice Tx: message: 14
# 19:07:05> ALE_Alice Rx: message 5: Bob to Alice4
# 19:07:06> PLE_Alice Rx: from ('127.0.0.1', 31111): 19
# 19:07:06> DLE_Alice Rx: message 15: 19
# 19:07:06> DLE_Alice FSM: state: 1 event type: 2
# 19:07:06> DLE_Alice Tx: message 11: Alice to Bob10
# 19:07:06> DLE_Alice FSM: state: 0 event type: 0
# 19:07:06> DLE_Alice FSM: to send: Alice to Bob10
# 19:07:06> PLE_Alice Tx: message: 00Alice to Bob10
# 19:07:07> PLE_Bob Rx: from ('127.0.0.1', 30000): 14
# 19:07:07> DLE_Bob Rx: message 15: 14
# 19:07:07> DLE_Bob FSM: state: 1 event type: 2
# 19:07:07> DLE_Bob Tx: message 6: Bob to Alice5
# 19:07:07> DLE_Bob FSM: state: 0 event type: 0
# 19:07:07> DLE_Bob FSM: to send: Bob to Alice5
# 19:07:07> PLE_Bob Tx: message: 05Bob to Alice5
# 19:07:07> Transmission Duplicated
# 19:07:08> PLE_Alice Rx: from ('127.0.0.1', 31111): 05Bob to Alice5
# 19:07:08> DLE_Alice Rx: message 16: 05Bob to Alice5
# 19:07:08> DLE_Alice FSM: state: 1 event type: 1
# 19:07:08> DLE_Alice FSM: received: Bob to Alice5
# 19:07:08> ALE_Alice Rx: message 6: Bob to Alice5
# 19:07:08> PLE_Alice Tx: message: 15
# 19:07:08> PLE_Bob Rx: from ('127.0.0.1', 30000): 00Alice to Bob10
# 19:07:08> DLE_Bob Rx: message 16: 00Alice to Bob10
# 19:07:08> DLE_Bob FSM: state: 1 event type: 1
# 19:07:08> DLE_Bob FSM: received: Alice to Bob10
# 19:07:08> ALE_Bob Rx: message 11: Alice to Bob10
# 19:07:08> PLE_Bob Tx: message: 10
# 19:07:09> PLE_Alice Rx: from ('127.0.0.1', 31111): 05Bob to Alice5
# 19:07:09> DLE_Alice Rx: message 17: 05Bob to Alice5
# 19:07:09> DLE_Alice FSM: state: 1 event type: 1
# 19:07:09> DLE_Alice FSM: received: Bob to Alice5
# 19:07:09> DLE_Alice FSM: received received frame 5 but expected 6
# 19:07:09> PLE_Alice Tx: message: 15
# 19:07:09> PLE_Bob Rx: from ('127.0.0.1', 30000): 15
# 19:07:09> DLE_Bob Rx: message 17: 15
# 19:07:09> DLE_Bob FSM: state: 1 event type: 2
# 19:07:09> DLE_Bob Tx: message 7: Bob to Alice6
# 19:07:09> DLE_Bob FSM: state: 0 event type: 0
# 19:07:09> DLE_Bob FSM: to send: Bob to Alice6
# 19:07:09> PLE_Bob Tx: message: 06Bob to Alice6
# 19:07:09> PLE_Bob Rx: from ('127.0.0.1', 30000): 15
# 19:07:09> DLE_Bob Rx: message 18: 15
# 19:07:10> PLE_Alice Rx: from ('127.0.0.1', 31111): 10
# 19:07:10> DLE_Alice Rx: message 18: 10
# 19:07:10> DLE_Alice FSM: state: 1 event type: 2
# 19:07:10> DLE_Alice Tx: message 12: Alice to Bob11
# 19:07:10> DLE_Alice FSM: state: 0 event type: 0
# 19:07:10> DLE_Alice FSM: to send: Alice to Bob11
# 19:07:10> PLE_Alice Tx: message: 01Alice to Bob11
# 19:07:10> DLE_Bob FSM: state: 1 event type: 2
# 19:07:10> ACK # 5 does not match local seq # 6
# 19:07:11> PLE_Bob Rx: from ('127.0.0.1', 30000): 01Alice to Bob11
# 19:07:11> DLE_Bob Rx: message 19: 01Alice to Bob11
# 19:07:11> DLE_Bob FSM: state: 1 event type: 1
# 19:07:11> DLE_Bob FSM: received: Alice to Bob11
# 19:07:11> PLE_Bob Tx: message: 11
# 19:07:11> ALE_Bob Rx: message 12: Alice to Bob11
# 19:07:11> PLE_Alice Rx: from ('127.0.0.1', 31111): 06Bob to Alice6
# 19:07:11> DLE_Alice Rx: message 19: 06Bob to Alice6
# 19:07:11> DLE_Alice FSM: state: 1 event type: 1
# 19:07:11> DLE_Alice FSM: received: Bob to Alice6
# 19:07:11> ALE_Alice Rx: message 7: Bob to Alice6
# 19:07:11> PLE_Alice Tx: message: 16
# 19:07:11> PLE_Alice Rx: from ('127.0.0.1', 31111): 11
# 19:07:11> DLE_Alice Rx: message 20: 11
# 19:07:11> DLE_Alice FSM: state: 1 event type: 2
# 19:07:11> DLE_Alice Tx: message 13: Alice to Bob12
# 19:07:11> DLE_Alice FSM: state: 0 event type: 0
# 19:07:11> DLE_Alice FSM: to send: Alice to Bob12
# 19:07:11> PLE_Alice Tx: message: 02Alice to Bob12
# 19:07:12> PLE_Bob Rx: from ('127.0.0.1', 30000): 16
# 19:07:12> DLE_Bob Rx: message 20: 16
# 19:07:12> DLE_Bob FSM: state: 1 event type: 2
# 19:07:12> DLE_Bob Tx: message 8: Bob to Alice7
# 19:07:12> DLE_Bob FSM: state: 0 event type: 0
# 19:07:12> DLE_Bob FSM: to send: Bob to Alice7
# 19:07:12> PLE_Bob Tx: message: 07Bob to Alice7
# 19:07:12> PLE_Bob Rx: from ('127.0.0.1', 30000): 02Alice to Bob12
# 19:07:12> DLE_Bob Rx: message 21: 02Alice to Bob12
# 19:07:12> DLE_Bob FSM: state: 1 event type: 1
# 19:07:12> DLE_Bob FSM: received: Alice to Bob12
# 19:07:12> PLE_Bob Tx: message: 12
# 19:07:12> ALE_Bob Rx: message 13: Alice to Bob12
# 19:07:13> PLE_Alice Rx: from ('127.0.0.1', 31111): 07Bob to Alice7
# 19:07:13> DLE_Alice Rx: message 21: 07Bob to Alice7
# 19:07:13> DLE_Alice FSM: state: 1 event type: 1
# 19:07:13> DLE_Alice FSM: received: Bob to Alice7
# 19:07:13> ALE_Alice Rx: message 8: Bob to Alice7
# 19:07:13> PLE_Alice Tx: message: 17
# 19:07:14> PLE_Alice Rx: from ('127.0.0.1', 31111): 12
# 19:07:14> DLE_Alice Rx: message 22: 12
# 19:07:14> DLE_Alice FSM: state: 1 event type: 2
# 19:07:14> DLE_Alice Tx: message 14: Alice to Bob13
# 19:07:14> DLE_Alice FSM: state: 0 event type: 0
# 19:07:14> DLE_Alice FSM: to send: Alice to Bob13
# 19:07:14> PLE_Alice Tx: message: 03Alice to Bob13
# 19:07:14> PLE_Bob Rx: from ('127.0.0.1', 30000): 17
# 19:07:14> DLE_Bob Rx: message 22: 17
# 19:07:14> DLE_Bob FSM: state: 1 event type: 2
# 19:07:14> DLE_Bob Tx: message 9: Bob to Alice8
# 19:07:14> DLE_Bob FSM: state: 0 event type: 0
# 19:07:14> DLE_Bob FSM: to send: Bob to Alice8
# 19:07:14> PLE_Bob Tx: message: 08Bob to Alice8
# 19:07:15> PLE_Bob Rx: from ('127.0.0.1', 30000): 03Alice to Bob13
# 19:07:15> DLE_Bob Rx: message 23: 03Alice to Bob13
# 19:07:15> DLE_Bob FSM: state: 1 event type: 1
# 19:07:15> DLE_Bob FSM: received: Alice to Bob13
# 19:07:15> ALE_Bob Rx: message 14: Alice to Bob13
# 19:07:15> PLE_Bob Tx: message: 13
# 19:07:15> PLE_Alice Rx: from ('127.0.0.1', 31111): 08Bob to Alice8
# 19:07:15> DLE_Alice Rx: message 23: 08Bob to Alice8
# 19:07:15> DLE_Alice FSM: state: 1 event type: 1
# 19:07:15> DLE_Alice FSM: received: Bob to Alice8
# 19:07:15> PLE_Alice Tx: message: 18
# 19:07:15> ALE_Alice Rx: message 9: Bob to Alice8
# 19:07:16> PLE_Bob Rx: from ('127.0.0.1', 30000): 18
# 19:07:16> DLE_Bob Rx: message 24: 18
# 19:07:16> DLE_Bob FSM: state: 1 event type: 2
# 19:07:16> DLE_Bob Tx: message 10: Bob to Alice9
# 19:07:16> DLE_Bob FSM: state: 0 event type: 0
# 19:07:16> DLE_Bob FSM: to send: Bob to Alice9
# 19:07:16> PLE_Bob Tx: message: 09Bob to Alice9
# 19:07:16> Transmission Duplicated
# 19:07:17> PLE_Alice Rx: from ('127.0.0.1', 31111): 13
# 19:07:17> DLE_Alice Rx: message 24: 13
# 19:07:17> DLE_Alice FSM: state: 1 event type: 2
# 19:07:17> DLE_Alice Tx: message 15: Alice to Bob14
# 19:07:17> DLE_Alice FSM: state: 0 event type: 0
# 19:07:17> DLE_Alice FSM: to send: Alice to Bob14
# 19:07:17> PLE_Alice Tx: message: 04Alice to Bob14
# 19:07:17> PLE_Alice Rx: from ('127.0.0.1', 31111): 09Bob to Alice9
# 19:07:17> DLE_Alice Rx: message 25: 09Bob to Alice9
# 19:07:17> DLE_Alice FSM: state: 1 event type: 1
# 19:07:17> DLE_Alice FSM: received: Bob to Alice9
# 19:07:17> ALE_Alice Rx: message 10: Bob to Alice9
# 19:07:17> PLE_Alice Tx: message: 19
# 19:07:18> PLE_Alice Rx: from ('127.0.0.1', 31111): 09Bob to Alice9
# 19:07:18> DLE_Alice Rx: message 26: 09Bob to Alice9
# 19:07:18> DLE_Alice FSM: state: 1 event type: 1
# 19:07:18> DLE_Alice FSM: received: Bob to Alice9
# 19:07:18> DLE_Alice FSM: received received frame 9 but expected 0
# 19:07:18> PLE_Alice Tx: message: 19
# 19:07:18> PLE_Bob Rx: from ('127.0.0.1', 30000): 04Alice to Bob14
# 19:07:18> DLE_Bob Rx: message 25: 04Alice to Bob14
# 19:07:18> DLE_Bob FSM: state: 1 event type: 1
# 19:07:18> DLE_Bob FSM: received: Alice to Bob14
# 19:07:18> ALE_Bob Rx: message 15: Alice to Bob14
# 19:07:18> PLE_Bob Tx: message: 14
# 19:07:18> PLE_Bob Rx: from ('127.0.0.1', 30000): 19
# 19:07:18> DLE_Bob Rx: message 26: 19
# 19:07:18> DLE_Bob FSM: state: 1 event type: 2
# 19:07:18> DLE_Bob Tx: message 11: Bob to Alice10
# 19:07:18> DLE_Bob FSM: state: 0 event type: 0
# 19:07:18> DLE_Bob FSM: to send: Bob to Alice10
# 19:07:18> PLE_Bob Tx: message: 00Bob to Alice10
# 19:07:19> PLE_Alice Rx: from ('127.0.0.1', 31111): 14
# 19:07:19> DLE_Alice Rx: message 27: 14
# 19:07:19> DLE_Alice FSM: state: 1 event type: 2
# 19:07:19> DLE_Alice Tx: message 16: Alice to Bob15
# 19:07:19> DLE_Alice FSM: state: 0 event type: 0
# 19:07:19> DLE_Alice FSM: to send: Alice to Bob15
# 19:07:19> PLE_Alice Tx: message: 05Alice to Bob15
# 19:07:19> PLE_Bob Rx: from ('127.0.0.1', 30000): 19
# 19:07:19> DLE_Bob Rx: message 27: 19
# 19:07:19> DLE_Bob FSM: state: 1 event type: 2
# 19:07:19> ACK # 9 does not match local seq # 0
# 19:07:21> PLE_Alice Rx: from ('127.0.0.1', 31111): 00Bob to Alice10
# 19:07:21> DLE_Alice Rx: message 28: 00Bob to Alice10
# 19:07:21> DLE_Alice FSM: state: 1 event type: 1
# 19:07:21> DLE_Alice FSM: received: Bob to Alice10
# 19:07:21> PLE_Alice Tx: message: 10
# 19:07:21> ALE_Alice Rx: message 11: Bob to Alice10
# 19:07:21> PLE_Bob Rx: from ('127.0.0.1', 30000): 05Alice to Bob15
# 19:07:21> DLE_Bob Rx: message 28: 05Alice to Bob15
# 19:07:21> DLE_Bob FSM: state: 1 event type: 1
# 19:07:21> DLE_Bob FSM: received: Alice to Bob15
# 19:07:21> ALE_Bob Rx: message 16: Alice to Bob15
# 19:07:21> PLE_Bob Tx: message: 15
# 19:07:21> PLE_Alice Rx: from ('127.0.0.1', 31111): 15
# 19:07:21> DLE_Alice Rx: message 29: 15
# 19:07:21> DLE_Alice FSM: state: 1 event type: 2
# 19:07:21> DLE_Alice Tx: message 17: Alice to Bob16
# 19:07:21> DLE_Alice FSM: state: 0 event type: 0
# 19:07:21> DLE_Alice FSM: to send: Alice to Bob16
# 19:07:21> PLE_Alice Tx: message: 06Alice to Bob16
# 19:07:21> packet loss
# 19:07:21> PLE_Bob Rx: from ('127.0.0.1', 30000): 10
# 19:07:21> DLE_Bob Rx: message 29: 10
# 19:07:21> DLE_Bob FSM: state: 1 event type: 2
# 19:07:21> DLE_Bob Tx: message 12: Bob to Alice11
# 19:07:21> DLE_Bob FSM: state: 0 event type: 0
# 19:07:21> DLE_Bob FSM: to send: Bob to Alice11
# 19:07:21> PLE_Bob Tx: message: 01Bob to Alice11
# 19:07:22> PLE_Alice Rx: from ('127.0.0.1', 31111): 01Bob to Alice11
# 19:07:22> DLE_Alice Rx: message 30: 01Bob to Alice11
# 19:07:22> DLE_Alice FSM: state: 1 event type: 1
# 19:07:22> DLE_Alice FSM: received: Bob to Alice11
# 19:07:22> PLE_Alice Tx: message: 11
# 19:07:22> ALE_Alice Rx: message 12: Bob to Alice11
# 19:07:23> PLE_Bob Rx: from ('127.0.0.1', 30000): 11
# 19:07:23> DLE_Bob Rx: message 30: 11
# 19:07:23> DLE_Bob FSM: state: 1 event type: 2
# 19:07:23> DLE_Bob Tx: message 13: Bob to Alice12
# 19:07:23> DLE_Bob FSM: state: 0 event type: 0
# 19:07:23> DLE_Bob FSM: to send: Bob to Alice12
# 19:07:23> PLE_Bob Tx: message: 02Bob to Alice12
# 19:07:23> PLE_Alice Rx: from ('127.0.0.1', 31111): 02Bob to Alice12
# 19:07:23> DLE_Alice Rx: message 31: 02Bob to Alice12
# 19:07:23> DLE_Alice FSM: state: 1 event type: 1
# 19:07:23> DLE_Alice FSM: received: Bob to Alice12
# 19:07:23> ALE_Alice Rx: message 13: Bob to Alice12
# 19:07:23> PLE_Alice Tx: message: 12
# 19:07:25> PLE_Bob Rx: from ('127.0.0.1', 30000): 12
# 19:07:25> DLE_Bob Rx: message 31: 12
# 19:07:25> DLE_Bob FSM: state: 1 event type: 2
# 19:07:25> DLE_Bob Tx: message 14: Bob to Alice13
# 19:07:25> DLE_Bob FSM: state: 0 event type: 0
# 19:07:25> DLE_Bob FSM: to send: Bob to Alice13
# 19:07:25> PLE_Bob Tx: message: 03Bob to Alice13
# 19:07:26> PLE_Alice Rx: from ('127.0.0.1', 31111): 03Bob to Alice13
# 19:07:26> DLE_Alice Rx: message 32: 03Bob to Alice13
# 19:07:26> DLE_Alice FSM: state: 1 event type: 1
# 19:07:26> DLE_Alice FSM: received: Bob to Alice13
# 19:07:26> PLE_Alice Tx: message: 13
# 19:07:26> ALE_Alice Rx: message 14: Bob to Alice13
# 19:07:27> DLE_Alice FSM: state: 1 event type: 3
# 19:07:27> DLE_Alice FSM: to resend frame 6 Alice to Bob16
# 19:07:27> PLE_Alice Tx: message: 06Alice to Bob16
# 19:07:27> PLE_Bob Rx: from ('127.0.0.1', 30000): 13
# 19:07:27> DLE_Bob Rx: message 32: 13
# 19:07:27> DLE_Bob FSM: state: 1 event type: 2
# 19:07:27> DLE_Bob Tx: message 15: Bob to Alice14
# 19:07:27> DLE_Bob FSM: state: 0 event type: 0
# 19:07:27> DLE_Bob FSM: to send: Bob to Alice14
# 19:07:27> PLE_Bob Tx: message: 04Bob to Alice14
# 19:07:28> PLE_Alice Rx: from ('127.0.0.1', 31111): 04Bob to Alice14
# 19:07:28> DLE_Alice Rx: message 33: 04Bob to Alice14
# 19:07:28> DLE_Alice FSM: state: 1 event type: 1
# 19:07:28> DLE_Alice FSM: received: Bob to Alice14
# 19:07:28> ALE_Alice Rx: message 15: Bob to Alice14
# 19:07:28> PLE_Alice Tx: message: 14
# 19:07:29> PLE_Bob Rx: from ('127.0.0.1', 30000): 06Alice to Bob16
# 19:07:29> DLE_Bob Rx: message 33: 06Alice to Bob16
# 19:07:29> DLE_Bob FSM: state: 1 event type: 1
# 19:07:29> DLE_Bob FSM: received: Alice to Bob16
# 19:07:29> PLE_Bob Tx: message: 16
# 19:07:29> ALE_Bob Rx: message 17: Alice to Bob16
# 19:07:29> Transmission Duplicated
# 19:07:30> PLE_Alice Rx: from ('127.0.0.1', 31111): 16
# 19:07:30> DLE_Alice Rx: message 34: 16
# 19:07:30> DLE_Alice FSM: state: 1 event type: 2
# 19:07:30> DLE_Alice Tx: message 18: Alice to Bob17
# 19:07:30> DLE_Alice FSM: state: 0 event type: 0
# 19:07:30> DLE_Alice FSM: to send: Alice to Bob17
# 19:07:30> PLE_Alice Tx: message: 07Alice to Bob17
# 19:07:31> PLE_Bob Rx: from ('127.0.0.1', 30000): 14
# 19:07:31> DLE_Bob Rx: message 34: 14
# 19:07:31> DLE_Bob FSM: state: 1 event type: 2
# 19:07:31> DLE_Bob Tx: message 16: Bob to Alice15
# 19:07:31> DLE_Bob FSM: state: 0 event type: 0
# 19:07:31> DLE_Bob FSM: to send: Bob to Alice15
# 19:07:31> PLE_Bob Tx: message: 05Bob to Alice15
# 19:07:31> PLE_Bob Rx: from ('127.0.0.1', 30000): 07Alice to Bob17
# 19:07:31> DLE_Bob Rx: message 35: 07Alice to Bob17
# 19:07:31> DLE_Bob FSM: state: 1 event type: 1
# 19:07:31> DLE_Bob FSM: received: Alice to Bob17
# 19:07:31> ALE_Bob Rx: message 18: Alice to Bob17
# 19:07:31> PLE_Bob Tx: message: 17
# 19:07:32> PLE_Alice Rx: from ('127.0.0.1', 31111): 16
# 19:07:32> DLE_Alice Rx: message 35: 16
# 19:07:32> DLE_Alice FSM: state: 1 event type: 2
# 19:07:32> ACK # 6 does not match local seq # 7
# 19:07:33> PLE_Alice Rx: from ('127.0.0.1', 31111): 05Bob to Alice15
# 19:07:33> DLE_Alice Rx: message 36: 05Bob to Alice15
# 19:07:33> DLE_Alice FSM: state: 1 event type: 1
# 19:07:33> DLE_Alice FSM: received: Bob to Alice15
# 19:07:33> PLE_Alice Tx: message: 15
# 19:07:33> ALE_Alice Rx: message 16: Bob to Alice15
# 19:07:34> PLE_Alice Rx: from ('127.0.0.1', 31111): 17
# 19:07:34> DLE_Alice Rx: message 37: 17
# 19:07:34> DLE_Alice FSM: state: 1 event type: 2
# 19:07:34> DLE_Alice Tx: message 19: Alice to Bob18
# 19:07:34> DLE_Alice FSM: state: 0 event type: 0
# 19:07:34> DLE_Alice FSM: to send: Alice to Bob18
# 19:07:34> PLE_Alice Tx: message: 08Alice to Bob18
# 19:07:34> packet loss
# 19:07:34> PLE_Bob Rx: from ('127.0.0.1', 30000): 15
# 19:07:34> DLE_Bob Rx: message 36: 15
# 19:07:34> DLE_Bob FSM: state: 1 event type: 2
# 19:07:34> DLE_Bob Tx: message 17: Bob to Alice16
# 19:07:34> DLE_Bob FSM: state: 0 event type: 0
# 19:07:34> DLE_Bob FSM: to send: Bob to Alice16
# 19:07:34> PLE_Bob Tx: message: 06Bob to Alice16
# 19:07:35> PLE_Alice Rx: from ('127.0.0.1', 31111): 06Bob to Alice16
# 19:07:35> DLE_Alice Rx: message 38: 06Bob to Alice16
# 19:07:35> DLE_Alice FSM: state: 1 event type: 1
# 19:07:35> DLE_Alice FSM: received: Bob to Alice16
# 19:07:35> PLE_Alice Tx: message: 16
# 19:07:35> ALE_Alice Rx: message 17: Bob to Alice16
# 19:07:37> PLE_Bob Rx: from ('127.0.0.1', 30000): 16
# 19:07:37> DLE_Bob Rx: message 37: 16
# 19:07:37> DLE_Bob FSM: state: 1 event type: 2
# 19:07:37> DLE_Bob Tx: message 18: Bob to Alice17
# 19:07:37> DLE_Bob FSM: state: 0 event type: 0
# 19:07:37> DLE_Bob FSM: to send: Bob to Alice17
# 19:07:37> PLE_Bob Tx: message: 07Bob to Alice17
# 19:07:38> PLE_Alice Rx: from ('127.0.0.1', 31111): 07Bob to Alice17
# 19:07:38> DLE_Alice Rx: message 39: 07Bob to Alice17
# 19:07:38> DLE_Alice FSM: state: 1 event type: 1
# 19:07:38> DLE_Alice FSM: received: Bob to Alice17
# 19:07:38> PLE_Alice Tx: message: 17
# 19:07:38> ALE_Alice Rx: message 18: Bob to Alice17
# 19:07:38> PLE_Bob Rx: from ('127.0.0.1', 30000): 17
# 19:07:38> DLE_Bob Rx: message 38: 17
# 19:07:38> DLE_Bob FSM: state: 1 event type: 2
# 19:07:38> DLE_Bob Tx: message 19: Bob to Alice18
# 19:07:38> DLE_Bob FSM: state: 0 event type: 0
# 19:07:38> DLE_Bob FSM: to send: Bob to Alice18
# 19:07:38> PLE_Bob Tx: message: 08Bob to Alice18
# 19:07:38> packet loss
# 19:07:39> DLE_Alice FSM: state: 1 event type: 3
# 19:07:39> DLE_Alice FSM: to resend frame 8 Alice to Bob18
# 19:07:39> PLE_Alice Tx: message: 08Alice to Bob18
# 19:07:40> PLE_Bob Rx: from ('127.0.0.1', 30000): 08Alice to Bob18
# 19:07:40> DLE_Bob Rx: message 39: 08Alice to Bob18
# 19:07:40> DLE_Bob FSM: state: 1 event type: 1
# 19:07:40> DLE_Bob FSM: received: Alice to Bob18
# 19:07:40> ALE_Bob Rx: message 19: Alice to Bob18
# 19:07:40> PLE_Bob Tx: message: 18
# 19:07:41> PLE_Alice Rx: from ('127.0.0.1', 31111): 18
# 19:07:41> DLE_Alice Rx: message 40: 18
# 19:07:41> DLE_Alice FSM: state: 1 event type: 2
# 19:07:41> DLE_Alice Tx: message 20: Alice to Bob19
# 19:07:41> DLE_Alice FSM: state: 0 event type: 0
# 19:07:41> DLE_Alice FSM: to send: Alice to Bob19
# 19:07:41> PLE_Alice Tx: message: 09Alice to Bob19
# 19:07:43> PLE_Bob Rx: from ('127.0.0.1', 30000): 09Alice to Bob19
# 19:07:43> DLE_Bob Rx: message 40: 09Alice to Bob19
# 19:07:43> DLE_Bob FSM: state: 1 event type: 1
# 19:07:43> DLE_Bob FSM: received: Alice to Bob19
# 19:07:43> PLE_Bob Tx: message: 19
# 19:07:43> ALE_Bob Rx: message 20: Alice to Bob19
# 19:07:44> DLE_Bob FSM: state: 1 event type: 3
# 19:07:44> DLE_Bob FSM: to resend frame 8 Bob to Alice18
# 19:07:44> PLE_Bob Tx: message: 08Bob to Alice18
# 19:07:44> PLE_Alice Rx: from ('127.0.0.1', 31111): 19
# 19:07:44> DLE_Alice Rx: message 41: 19
# 19:07:44> DLE_Alice FSM: state: 1 event type: 2
# 19:07:45> PLE_Alice Rx: from ('127.0.0.1', 31111): 08Bob to Alice18
# 19:07:45> DLE_Alice Rx: message 42: 08Bob to Alice18
# 19:07:45> DLE_Alice FSM: state: 0 event type: 1
# 19:07:45> DLE_Alice FSM: received: Bob to Alice18
# 19:07:45> ALE_Alice Rx: message 19: Bob to Alice18
# 19:07:45> PLE_Alice Tx: message: 18
# 19:07:46> PLE_Bob Rx: from ('127.0.0.1', 30000): 18
# 19:07:46> DLE_Bob Rx: message 41: 18
# 19:07:46> DLE_Bob FSM: state: 1 event type: 2
# 19:07:46> DLE_Bob Tx: message 20: Bob to Alice19
# 19:07:46> DLE_Bob FSM: state: 0 event type: 0
# 19:07:46> DLE_Bob FSM: to send: Bob to Alice19
# 19:07:46> PLE_Bob Tx: message: 09Bob to Alice19
# 19:07:47> PLE_Alice Rx: from ('127.0.0.1', 31111): 09Bob to Alice19
# 19:07:47> DLE_Alice Rx: message 43: 09Bob to Alice19
# 19:07:47> DLE_Alice FSM: state: 0 event type: 1
# 19:07:47> DLE_Alice FSM: received: Bob to Alice19
# 19:07:47> PLE_Alice Tx: message: 19
# 19:07:47> ALE_Alice Rx: message 20: Bob to Alice19
# 19:07:47> PLE_Bob Rx: from ('127.0.0.1', 30000): 19
# 19:07:47> DLE_Bob Rx: message 42: 19
# 19:07:47> DLE_Bob FSM: state: 1 event type: 2

# %%
# (4) create physical layer entities
AP_local_2  = ("127.0.0.1", 31111)
AP_remote_2 = ("127.0.0.1", 30000)
Socket_2    = socket.socket(family=socket.AF_INET, type=socket.SOCK_DGRAM)
PLE_2       = PLE_TR("PLE_Bob", Socket_2, AP_remote_2, AP_local_2, exp_out)

# (5) create date link layer entities
DLE_2 = DLE_TR_FSM("DLE_Bob", PLE_2, exp_out)

# (6) create application layer entities
ALE_3 = ALE_TextInput(exp_out)
ALE_2 = ALE_TR("ALE_Bob", ALE_3, DLE_2, exp_out)
# Out:
# Text(value='', description='To send:', placeholder='Type something and press enter')
# Button(description='Submit', style=ButtonStyle(), tooltip='Click me to submit a string')

# %%
# start the loops of all entities
# all loops must be blocked at a certain position

t1_1 = Thread(target = ALE_1.loop_Tx, args = ()) 
t2_1 = Thread(target = ALE_1.loop_Rx, args = ()) 
t3_1 = Thread(target = DLE_1.loop_Tx, args = ())
t4_1 = Thread(target = DLE_1.loop_Rx, args = ())
t5_1 = Thread(target = PLE_1.loop_Tx, args = ()) 
t6_1 = Thread(target = PLE_1.loop_Rx, args = ())
f1_1 = Thread(target = DLE_1.loop_FSM, args = ())
f2_1 = Thread(target = DLE_1.loop_timer, args = ())


t1_2 = Thread(target = ALE_2.loop_Tx, args = ()) 
t2_2 = Thread(target = ALE_2.loop_Rx, args = ()) 
t3_2 = Thread(target = DLE_2.loop_Tx, args = ())
t4_2 = Thread(target = DLE_2.loop_Rx, args = ())
t5_2 = Thread(target = PLE_2.loop_Tx, args = ()) 
t6_2 = Thread(target = PLE_2.loop_Rx, args = ()) 
f1_2 = Thread(target = DLE_2.loop_FSM, args = ())
f2_2 = Thread(target = DLE_2.loop_timer, args = ())

thread_running = True

t1_1.start()
t2_1.start()
t3_1.start()
t4_1.start()
t5_1.start()
t6_1.start()
t1_2.start()
t2_2.start()
t3_2.start()
t4_2.start()
t5_2.start()
t6_2.start()
f1_1.start()
f1_2.start()
f2_1.start()
f2_2.start()

# %%
class MLE_TR(PLE_TR):
    def __init__(self, name, Socket, AP_Tx, AP_Rx, exp_out, experiment_id = 1):
        super().__init__(name, Socket, AP_Tx, AP_Rx, exp_out)
        self.experiment_id = experiment_id
        self.received_packets = []
        self.received_counts = {}
        
        self.button = widgets.Button(description=f'Run {name}')
        self.button.on_click(self.send_messages_callback)
        display(self.button)

    def send_messages_callback(self, b):

        for msg_id in range(1, 101):
            timestamp = time.time_ns()
            packet = f"{self.experiment_id}|{msg_id}|{timestamp}"
            self.send(packet)            
            
        self.exp_out.print(f"Button Pressed")

    def display_computations(self):

        total_expected = 100
        delays = [(received_time - sent_time) / 1e6 for (_, _, sent_time, received_time) in self.received_packets]
        avg_delay = sum(delays) / len(delays) if delays else 0
        
        unique_received = len(self.received_counts)
        loss_rate = (total_expected - unique_received) / total_expected
        
        duplicate_count = sum(1 for count in self.received_counts.values() if count > 1)
        duplicate_rate = duplicate_count / total_expected
        
        self.exp_out.print(f"--- Measurement Results for {self.Name} ---")
        self.exp_out.print(f"Average Delay: {avg_delay:.2f} ms")
        self.exp_out.print(f"Loss Rate: {loss_rate * 100:.2f}%")
        self.exp_out.print(f"Duplicate Rate: {duplicate_rate * 100:.2f}%")

    def loop_Rx(self):

        global thread_running
        global bufferSize
    
        self.Socket.bind(self.AP_Rx)
        
        while (thread_running == True):

            message_address = self.Socket.recvfrom(bufferSize)

            message = message_address[0]
            address = message_address[1]

            try:
                experiment_id, message_id, sent_time = message.decode().split('|')
                message_id = int(message_id)
                sent_time = int(sent_time)
                print(time.strftime("%H:%M:%S", time.localtime()), end=' ')
                print("%s Rx from %s: %s"%(self.Name, address, message))
                self.Queue_Rx.put(message)
            except Exception as e:
                self.exp_out.print(f"Error - {e} - parsing packet: {message}")
                continue

            key = message_id
            if key in self.received_counts:
                self.received_counts[key]+= 1
            else:
                self.received_counts[key] = 1
                self.received_packets.append((experiment_id, message_id, sent_time, time.time_ns()))
            
            self.display_computations()


exp_out = EXP_Output()

AP_local_MLE_Alice = ("localhost", 32000)
AP_Local_MLE_Bob = ("localhost", 32222)
AP_Remote_MLE_Bob = ("localhost", 32000)
AP_remote_MLE_Alice = ("localhost", 32222)

alice_MLE_socket = socket.socket(family=socket.AF_INET, type=socket.SOCK_DGRAM)
bob_MLE_socket = socket.socket(family=socket.AF_INET, type=socket.SOCK_DGRAM)

# Call class MLE_TR
alice_MLE = MLE_TR("MLE_Alice", alice_MLE_socket, AP_remote_MLE_Alice, AP_local_MLE_Alice, exp_out)
bob_MLE = MLE_TR("MLE_Bob", bob_MLE_socket, AP_Remote_MLE_Bob, AP_Local_MLE_Bob, exp_out)


alice_thread_tx = Thread(target=alice_MLE.loop_Tx)
alice_thread_rx = Thread(target=alice_MLE.loop_Rx)
bob_thread_tx = Thread(target=bob_MLE.loop_Tx)
bob_thread_rx = Thread(target=bob_MLE.loop_Rx)

# Start threads for MLE_Alice and MLE_Bob
thread_running = True

alice_thread_tx.start()
alice_thread_rx.start()
bob_thread_tx.start()
bob_thread_rx.start()
# Out:
# Button(description='Run MLE_Alice', style=ButtonStyle())
# Button(description='Run MLE_Bob', style=ButtonStyle())
# 19:03:59> MLE_Alice: loop_Tx starting
# 19:03:59> MLE_Bob: loop_Tx starting
# 19:04:01> Button Pressed
# 19:04:01> MLE_Alice Tx: message: 1|1|1743116641120193000
# 19:04:0119:04:01> MLE_Alice Tx: message: 1|2|1743116641120211000
#  MLE_Bob Rx from ('127.0.0.1', 32000): b'1|1|1743116641120193000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 5.17 ms
# 19:04:01> Loss Rate: 99.00%
# 19:04:01> Duplicate Rate: 0.00%
# 19:04:01> MLE_Alice Tx: message: 1|3|1743116641120213000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|2|1743116641120211000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 5.51 ms
# 19:04:01> Loss Rate: 98.00%
# 19:04:01> Duplicate Rate: 0.00%
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|3|1743116641120213000'
# 19:04:01> MLE_Alice Tx: message: 1|4|1743116641120214000
# 19:04:01> packet loss
# 19:04:01> MLE_Alice Tx: message: 1|5|1743116641120215000
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 5.69 ms
# 19:04:01> Loss Rate: 97.00%
# 19:04:01> Duplicate Rate: 0.00%
# 19:04:01> MLE_Alice Tx: message: 1|6|1743116641120216000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|5|1743116641120215000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 5.82 ms
# 19:04:01> Loss Rate: 96.00%
# 19:04:01> Duplicate Rate: 0.00%
# 19:04:01> MLE_Alice Tx: message: 1|7|1743116641120216000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|6|1743116641120216000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 5.93 ms
# 19:04:01> Loss Rate: 95.00%
# 19:04:01> Duplicate Rate: 0.00%
# 19:04:01> MLE_Alice Tx: message: 1|8|1743116641120217000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|7|1743116641120216000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 6.03 ms
# 19:04:01> Loss Rate: 94.00%
# 19:04:01> Duplicate Rate: 0.00%
# 19:04:01> MLE_Alice Tx: message: 1|9|1743116641120218000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|8|1743116641120217000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 6.14 ms
# 19:04:01> Loss Rate: 93.00%
# 19:04:01> Duplicate Rate: 0.00%
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|9|1743116641120218000'
# 19:04:01> MLE_Alice Tx: message: 1|10|1743116641120218000
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 6.26 ms
# 19:04:01> Loss Rate: 92.00%
# 19:04:01> Duplicate Rate: 0.00%
# 19:04:01> MLE_Alice Tx: message: 1|11|1743116641120219000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|10|1743116641120218000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 6.38 ms
# 19:04:01> Loss Rate: 91.00%
# 19:04:01> Duplicate Rate: 0.00%
# 19:04:01> MLE_Alice Tx: message: 1|12|1743116641120220000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|11|1743116641120219000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 6.50 ms
# 19:04:01> Loss Rate: 90.00%
# 19:04:01> Duplicate Rate: 0.00%
# 19:04:01> MLE_Alice Tx: message: 1|13|1743116641120221000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|12|1743116641120220000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 6.61 ms
# 19:04:01> Loss Rate: 89.00%
# 19:04:01> Duplicate Rate: 0.00%
# 19:04:01> MLE_Alice Tx: message: 1|14|1743116641120222000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|13|1743116641120221000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 6.71 ms
# 19:04:01> Loss Rate: 88.00%
# 19:04:01> Duplicate Rate: 0.00%
# 19:04:01> MLE_Alice Tx: message: 1|15|1743116641120222000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|14|1743116641120222000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 6.81 ms
# 19:04:01> Loss Rate: 87.00%
# 19:04:01> Duplicate Rate: 0.00%
# 19:04:01> MLE_Alice Tx: message: 1|16|1743116641120223000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|15|1743116641120222000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 6.91 ms
# 19:04:01> Loss Rate: 86.00%
# 19:04:01> Duplicate Rate: 0.00%
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|16|1743116641120223000'
# 19:04:01> MLE_Alice Tx: message: 1|17|1743116641120224000
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 7.00 ms
# 19:04:01> Loss Rate: 85.00%
# 19:04:01> Duplicate Rate: 0.00%
# 19:04:01> MLE_Alice Tx: message: 1|18|1743116641120224000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|17|1743116641120224000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 7.10 ms
# 19:04:01> Loss Rate: 84.00%
# 19:04:01> Duplicate Rate: 0.00%
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|18|1743116641120224000'
# 19:04:01> MLE_Alice Tx: message: 1|19|1743116641120225000
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 7.19 ms
# 19:04:01> Loss Rate: 83.00%
# 19:04:01> Duplicate Rate: 0.00%
# 19:04:01> MLE_Alice Tx: message: 1|20|1743116641120226000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|19|1743116641120225000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 7.30 ms
# 19:04:01> Loss Rate: 82.00%
# 19:04:01> Duplicate Rate: 0.00%
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|20|1743116641120226000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 7.41 ms
# 19:04:01> Loss Rate: 81.00%
# 19:04:01> Duplicate Rate: 0.00%
# 19:04:01> Transmission Duplicated
# 19:04:01> MLE_Alice Tx: message: 1|21|1743116641120227000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|20|1743116641120226000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 7.41 ms
# 19:04:01> Loss Rate: 81.00%
# 19:04:01> Duplicate Rate: 1.00%
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|21|1743116641120227000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 7.54 ms
# 19:04:01> Loss Rate: 80.00%
# 19:04:01> Duplicate Rate: 1.00%
# 19:04:01> MLE_Alice Tx: message: 1|22|1743116641120227000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|22|1743116641120227000'
# 19:04:01> MLE_Alice Tx: message: 1|23|1743116641120228000
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 7.66 ms
# 19:04:01> Loss Rate: 79.00%
# 19:04:01> Duplicate Rate: 1.00%
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|23|1743116641120228000'
# 19:04:01> MLE_Alice Tx: message: 1|24|1743116641120229000
# 19:04:01> packet loss
# 19:04:01> MLE_Alice Tx: message: 1|25|1743116641120229000
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 7.79 ms
# 19:04:01> Loss Rate: 78.00%
# 19:04:01> Duplicate Rate: 1.00%
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|25|1743116641120229000'
# 19:04:01> MLE_Alice Tx: message: 1|26|1743116641120230000
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 7.91 ms
# 19:04:01> Loss Rate: 77.00%
# 19:04:01> Duplicate Rate: 1.00%
# 19:04:01> MLE_Alice Tx: message: 1|27|1743116641120231000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|26|1743116641120230000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 8.03 ms
# 19:04:01> Loss Rate: 76.00%
# 19:04:01> Duplicate Rate: 1.00%
# 19:04:01> MLE_Alice Tx: message: 1|28|1743116641120231000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|27|1743116641120231000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 8.15 ms
# 19:04:01> Loss Rate: 75.00%
# 19:04:01> Duplicate Rate: 1.00%
# 19:04:01> MLE_Alice Tx: message: 1|29|1743116641120232000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|28|1743116641120231000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 8.27 ms
# 19:04:01> Loss Rate: 74.00%
# 19:04:01> Duplicate Rate: 1.00%
# 19:04:01> MLE_Alice Tx: message: 1|30|1743116641120233000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|29|1743116641120232000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 8.38 ms
# 19:04:01> Loss Rate: 73.00%
# 19:04:01> Duplicate Rate: 1.00%
# 19:04:01> MLE_Alice Tx: message: 1|31|1743116641120234000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|30|1743116641120233000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 8.50 ms
# 19:04:01> Loss Rate: 72.00%
# 19:04:01> Duplicate Rate: 1.00%
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|31|1743116641120234000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 8.62 ms
# 19:04:01> Loss Rate: 71.00%
# 19:04:01> Duplicate Rate: 1.00%
# 19:04:01> Transmission Duplicated
# 19:04:01> MLE_Alice Tx: message: 1|32|1743116641120234000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|31|1743116641120234000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 8.62 ms
# 19:04:01> Loss Rate: 71.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|33|1743116641120235000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|32|1743116641120234000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 8.74 ms
# 19:04:01> Loss Rate: 70.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|34|1743116641120237000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|33|1743116641120235000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 8.86 ms
# 19:04:01> Loss Rate: 69.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|35|1743116641120238000
# 19:04:01> packet loss
# 19:04:01> MLE_Alice Tx: message: 1|36|1743116641120238000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|34|1743116641120237000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 8.97 ms
# 19:04:01> Loss Rate: 68.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|37|1743116641120239000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|36|1743116641120238000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 9.08 ms
# 19:04:01> Loss Rate: 67.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|38|1743116641120240000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|37|1743116641120239000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 9.19 ms
# 19:04:01> Loss Rate: 66.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|38|1743116641120240000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 9.29 ms
# 19:04:01> Loss Rate: 65.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|39|1743116641120240000
# 19:04:01> MLE_Alice Tx: message: 1|40|1743116641120241000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|39|1743116641120240000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 9.40 ms
# 19:04:01> Loss Rate: 64.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|41|1743116641120242000
# 19:04:01> packet loss
# 19:04:01> MLE_Alice Tx: message: 1|42|1743116641120242000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|40|1743116641120241000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 9.50 ms
# 19:04:01> Loss Rate: 63.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|43|1743116641120243000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|42|1743116641120242000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 9.60 ms
# 19:04:01> Loss Rate: 62.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|44|1743116641120244000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|43|1743116641120243000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 9.69 ms
# 19:04:01> Loss Rate: 61.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|45|1743116641120245000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|44|1743116641120244000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 9.79 ms
# 19:04:01> Loss Rate: 60.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|46|1743116641120245000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|45|1743116641120245000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 9.88 ms
# 19:04:01> Loss Rate: 59.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|47|1743116641120246000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|46|1743116641120245000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 9.97 ms
# 19:04:01> Loss Rate: 58.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|48|1743116641120247000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|47|1743116641120246000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 10.06 ms
# 19:04:01> Loss Rate: 57.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|49|1743116641120248000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|48|1743116641120247000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 10.15 ms
# 19:04:01> Loss Rate: 56.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|50|1743116641120248000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|49|1743116641120248000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 10.24 ms
# 19:04:01> Loss Rate: 55.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|51|1743116641120249000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|50|1743116641120248000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 10.32 ms
# 19:04:01> Loss Rate: 54.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|52|1743116641120250000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|51|1743116641120249000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 10.41 ms
# 19:04:01> Loss Rate: 53.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|53|1743116641120250000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|52|1743116641120250000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 10.49 ms
# 19:04:01> Loss Rate: 52.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|54|1743116641120251000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|53|1743116641120250000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 10.57 ms
# 19:04:01> Loss Rate: 51.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|55|1743116641120252000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|54|1743116641120251000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 10.65 ms
# 19:04:01> Loss Rate: 50.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|56|1743116641120253000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|55|1743116641120252000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 10.73 ms
# 19:04:01> Loss Rate: 49.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|57|1743116641120254000
# 19:04:01> packet loss
# 19:04:01> MLE_Alice Tx: message: 1|58|1743116641120254000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|56|1743116641120253000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 10.81 ms
# 19:04:01> Loss Rate: 48.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|59|1743116641120255000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|58|1743116641120254000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 10.89 ms
# 19:04:01> Loss Rate: 47.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|60|1743116641120256000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|59|1743116641120255000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 10.97 ms
# 19:04:01> Loss Rate: 46.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|60|1743116641120256000'
# 19:04:01> MLE_Alice Tx: message: 1|61|1743116641120256000
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 11.06 ms
# 19:04:01> Loss Rate: 45.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|62|1743116641120257000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|61|1743116641120256000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 11.14 ms
# 19:04:01> Loss Rate: 44.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|63|1743116641120258000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|62|1743116641120257000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 11.23 ms
# 19:04:01> Loss Rate: 43.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|64|1743116641120258000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|63|1743116641120258000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 11.32 ms
# 19:04:01> Loss Rate: 42.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|65|1743116641120259000
# 19:04:01> packet loss
# 19:04:01> MLE_Alice Tx: message: 1|66|1743116641120260000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|64|1743116641120258000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 11.41 ms
# 19:04:01> Loss Rate: 41.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|67|1743116641120260000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|66|1743116641120260000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 11.50 ms
# 19:04:01> Loss Rate: 40.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|68|1743116641120261000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|67|1743116641120260000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 11.59 ms
# 19:04:01> Loss Rate: 39.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|69|1743116641120262000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|68|1743116641120261000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 11.68 ms
# 19:04:01> Loss Rate: 38.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|70|1743116641120263000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|69|1743116641120262000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 11.77 ms
# 19:04:01> Loss Rate: 37.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|71|1743116641120263000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|70|1743116641120263000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 11.86 ms
# 19:04:01> Loss Rate: 36.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|72|1743116641120264000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|71|1743116641120263000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 11.94 ms
# 19:04:01> Loss Rate: 35.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|73|1743116641120265000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|72|1743116641120264000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 12.03 ms
# 19:04:01> Loss Rate: 34.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|74|1743116641120265000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|73|1743116641120265000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 12.11 ms
# 19:04:01> Loss Rate: 33.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|75|1743116641120266000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|74|1743116641120265000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 12.20 ms
# 19:04:01> Loss Rate: 32.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|76|1743116641120267000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|75|1743116641120266000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 12.28 ms
# 19:04:01> Loss Rate: 31.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|76|1743116641120267000'
# 19:04:01> MLE_Alice Tx: message: 1|77|1743116641120267000
# 19:04:01> packet loss
# 19:04:01> MLE_Alice Tx: message: 1|78|1743116641120268000
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 12.36 ms
# 19:04:01> Loss Rate: 30.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|79|1743116641120269000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|78|1743116641120268000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 12.44 ms
# 19:04:01> Loss Rate: 29.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|80|1743116641120270000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|79|1743116641120269000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 12.52 ms
# 19:04:01> Loss Rate: 28.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|80|1743116641120270000'
# 19:04:01> MLE_Alice Tx: message: 1|81|1743116641120270000
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 12.60 ms
# 19:04:01> Loss Rate: 27.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|82|1743116641120271000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|81|1743116641120270000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 12.68 ms
# 19:04:01> Loss Rate: 26.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|83|1743116641120272000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|82|1743116641120271000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 12.76 ms
# 19:04:01> Loss Rate: 25.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|84|1743116641120272000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|83|1743116641120272000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 12.84 ms
# 19:04:01> Loss Rate: 24.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|85|1743116641120273000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|84|1743116641120272000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 12.92 ms
# 19:04:01> Loss Rate: 23.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|86|1743116641120274000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|85|1743116641120273000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 13.00 ms
# 19:04:01> Loss Rate: 22.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|87|1743116641120274000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|86|1743116641120274000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 13.08 ms
# 19:04:01> Loss Rate: 21.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|87|1743116641120274000'
# 19:04:01> MLE_Alice Tx: message: 1|88|1743116641120275000
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 13.16 ms
# 19:04:01> Loss Rate: 20.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|89|1743116641120276000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|88|1743116641120275000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 13.23 ms
# 19:04:01> Loss Rate: 19.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|90|1743116641120277000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|89|1743116641120276000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 13.31 ms
# 19:04:01> Loss Rate: 18.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|91|1743116641120277000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|90|1743116641120277000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 13.39 ms
# 19:04:01> Loss Rate: 17.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|92|1743116641120278000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|91|1743116641120277000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 13.47 ms
# 19:04:01> Loss Rate: 16.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|93|1743116641120279000
# 19:04:01> packet loss
# 19:04:01> MLE_Alice Tx: message: 1|94|1743116641120279000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|92|1743116641120278000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 13.56 ms
# 19:04:01> Loss Rate: 15.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|95|1743116641120280000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|94|1743116641120279000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 13.65 ms
# 19:04:01> Loss Rate: 14.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|96|1743116641120281000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|95|1743116641120280000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 13.75 ms
# 19:04:01> Loss Rate: 13.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|97|1743116641120281000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|96|1743116641120281000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 13.86 ms
# 19:04:01> Loss Rate: 12.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|98|1743116641120282000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|97|1743116641120281000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 13.96 ms
# 19:04:01> Loss Rate: 11.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|99|1743116641120283000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|98|1743116641120282000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 14.06 ms
# 19:04:01> Loss Rate: 10.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01> MLE_Alice Tx: message: 1|100|1743116641120284000
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|99|1743116641120283000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 14.16 ms
# 19:04:01> Loss Rate: 9.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:01 MLE_Bob Rx from ('127.0.0.1', 32000): b'1|100|1743116641120284000'
# 19:04:01> --- Measurement Results for MLE_Bob ---
# 19:04:01> Average Delay: 14.26 ms
# 19:04:01> Loss Rate: 8.00%
# 19:04:01> Duplicate Rate: 2.00%
# 19:04:11> Button Pressed
# 19:04:11> MLE_Bob Tx: message: 1|1|1743116651302660000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|1|1743116651302660000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 1.45 ms
# 19:04:11> Loss Rate: 99.00%
# 19:04:11> Duplicate Rate: 0.00%
# 19:04:11> MLE_Bob Tx: message: 1|2|1743116651302710000
# 19:04:11> packet loss
# 19:04:11> MLE_Bob Tx: message: 1|3|1743116651302714000
# 19:04:11> MLE_Bob Tx: message: 1|4|1743116651302716000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|3|1743116651302714000'
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|4|1743116651302716000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 2.04 ms
# 19:04:11> Loss Rate: 98.00%
# 19:04:11> Duplicate Rate: 0.00%
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 2.39 ms
# 19:04:11> Loss Rate: 97.00%
# 19:04:11> Duplicate Rate: 0.00%
# 19:04:11> MLE_Bob Tx: message: 1|5|1743116651302718000
# 19:04:11> packet loss
# 19:04:11> MLE_Bob Tx: message: 1|6|1743116651302720000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|6|1743116651302720000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 3.14 ms
# 19:04:11> Loss Rate: 96.00%
# 19:04:11> Duplicate Rate: 0.00%
# 19:04:11> MLE_Bob Tx: message: 1|7|1743116651302722000
# 19:04:11> MLE_Bob Tx: message: 1|8|1743116651302724000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|7|1743116651302722000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 3.81 ms
# 19:04:11> Loss Rate: 95.00%
# 19:04:11> Duplicate Rate: 0.00%
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|8|1743116651302724000'
# 19:04:11> MLE_Bob Tx: message: 1|9|1743116651302726000
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 4.36 ms
# 19:04:11> Loss Rate: 94.00%
# 19:04:11> Duplicate Rate: 0.00%
# 19:04:11> MLE_Bob Tx: message: 1|10|1743116651302729000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|9|1743116651302726000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 6.31 ms
# 19:04:11> Loss Rate: 93.00%
# 19:04:11> Duplicate Rate: 0.00%
# 19:04:11> MLE_Bob Tx: message: 1|11|1743116651302731000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|10|1743116651302729000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 7.80 ms
# 19:04:11> Loss Rate: 92.00%
# 19:04:11> Duplicate Rate: 0.00%
# 19:04:11> MLE_Bob Tx: message: 1|12|1743116651302733000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|11|1743116651302731000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 8.98 ms
# 19:04:11> Loss Rate: 91.00%
# 19:04:11> Duplicate Rate: 0.00%
# 19:04:11> MLE_Bob Tx: message: 1|13|1743116651302735000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|12|1743116651302733000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 9.94 ms
# 19:04:11> Loss Rate: 90.00%
# 19:04:11> Duplicate Rate: 0.00%
# 19:04:11> MLE_Bob Tx: message: 1|14|1743116651302737000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|13|1743116651302735000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 10.74 ms
# 19:04:11> Loss Rate: 89.00%
# 19:04:11> Duplicate Rate: 0.00%
# 19:04:11> MLE_Bob Tx: message: 1|15|1743116651302739000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|14|1743116651302737000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 11.42 ms
# 19:04:11> Loss Rate: 88.00%
# 19:04:11> Duplicate Rate: 0.00%
# 19:04:11> MLE_Bob Tx: message: 1|16|1743116651302742000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|15|1743116651302739000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 12.03 ms
# 19:04:11> Loss Rate: 87.00%
# 19:04:11> Duplicate Rate: 0.00%
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|16|1743116651302742000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 12.55 ms
# 19:04:11> Loss Rate: 86.00%
# 19:04:11> Duplicate Rate: 0.00%
# 19:04:11> MLE_Bob Tx: message: 1|17|1743116651302744000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|17|1743116651302744000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 13.03 ms
# 19:04:11> Loss Rate: 85.00%
# 19:04:11> Duplicate Rate: 0.00%
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|17|1743116651302744000'
# 19:04:11> Transmission Duplicated
# 19:04:11> MLE_Bob Tx: message: 1|18|1743116651302746000
# 19:04:11> packet loss
# 19:04:11> MLE_Bob Tx: message: 1|19|1743116651302748000
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 13.03 ms
# 19:04:11> Loss Rate: 85.00%
# 19:04:11> Duplicate Rate: 1.00%
# 19:04:11> MLE_Bob Tx: message: 1|20|1743116651302750000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|19|1743116651302748000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 13.48 ms
# 19:04:11> Loss Rate: 84.00%
# 19:04:11> Duplicate Rate: 1.00%
# 19:04:11> MLE_Bob Tx: message: 1|21|1743116651302752000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|20|1743116651302750000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 13.88 ms
# 19:04:11> Loss Rate: 83.00%
# 19:04:11> Duplicate Rate: 1.00%
# 19:04:11> MLE_Bob Tx: message: 1|22|1743116651302754000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|21|1743116651302752000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 14.25 ms
# 19:04:11> Loss Rate: 82.00%
# 19:04:11> Duplicate Rate: 1.00%
# 19:04:11> MLE_Bob Tx: message: 1|23|1743116651302755000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|22|1743116651302754000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 14.59 ms
# 19:04:11> Loss Rate: 81.00%
# 19:04:11> Duplicate Rate: 1.00%
# 19:04:11> MLE_Bob Tx: message: 1|24|1743116651302757000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|23|1743116651302755000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 14.90 ms
# 19:04:11> Loss Rate: 80.00%
# 19:04:11> Duplicate Rate: 1.00%
# 19:04:11> MLE_Bob Tx: message: 1|25|1743116651302759000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|24|1743116651302757000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 15.19 ms
# 19:04:11> Loss Rate: 79.00%
# 19:04:11> Duplicate Rate: 1.00%
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|25|1743116651302759000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 15.46 ms
# 19:04:11> Loss Rate: 78.00%
# 19:04:11> Duplicate Rate: 1.00%
# 19:04:11> Transmission Duplicated
# 19:04:11> MLE_Bob Tx: message: 1|26|1743116651302761000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|25|1743116651302759000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 15.46 ms
# 19:04:11> Loss Rate: 78.00%
# 19:04:11> Duplicate Rate: 2.00%
# 19:04:11> MLE_Bob Tx: message: 1|27|1743116651302763000
# 19:04:11> packet loss
# 19:04:11> MLE_Bob Tx: message: 1|28|1743116651302765000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|26|1743116651302761000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 15.72 ms
# 19:04:11> Loss Rate: 77.00%
# 19:04:11> Duplicate Rate: 2.00%
# 19:04:11> MLE_Bob Tx: message: 1|29|1743116651302767000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|28|1743116651302765000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 15.97 ms
# 19:04:11> Loss Rate: 76.00%
# 19:04:11> Duplicate Rate: 2.00%
# 19:04:11> MLE_Bob Tx: message: 1|30|1743116651302769000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|29|1743116651302767000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 16.20 ms
# 19:04:11> Loss Rate: 75.00%
# 19:04:11> Duplicate Rate: 2.00%
# 19:04:11> MLE_Bob Tx: message: 1|31|1743116651302771000
# 19:04:11> packet loss
# 19:04:11> MLE_Bob Tx: message: 1|32|1743116651302773000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|30|1743116651302769000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 16.41 ms
# 19:04:11> Loss Rate: 74.00%
# 19:04:11> Duplicate Rate: 2.00%
# 19:04:11> MLE_Bob Tx: message: 1|33|1743116651302775000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|32|1743116651302773000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 16.62 ms
# 19:04:11> Loss Rate: 73.00%
# 19:04:11> Duplicate Rate: 2.00%
# 19:04:11> MLE_Bob Tx: message: 1|34|1743116651302809000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|33|1743116651302775000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 16.82 ms
# 19:04:11> Loss Rate: 72.00%
# 19:04:11> Duplicate Rate: 2.00%
# 19:04:11> MLE_Bob Tx: message: 1|35|1743116651302811000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|34|1743116651302809000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 17.00 ms
# 19:04:11> Loss Rate: 71.00%
# 19:04:11> Duplicate Rate: 2.00%
# 19:04:11> MLE_Bob Tx: message: 1|36|1743116651302813000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|35|1743116651302811000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 17.18 ms
# 19:04:11> Loss Rate: 70.00%
# 19:04:11> Duplicate Rate: 2.00%
# 19:04:11> MLE_Bob Tx: message: 1|37|1743116651302815000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|36|1743116651302813000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 17.35 ms
# 19:04:11> Loss Rate: 69.00%
# 19:04:11> Duplicate Rate: 2.00%
# 19:04:11> MLE_Bob Tx: message: 1|38|1743116651302817000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|37|1743116651302815000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 17.51 ms
# 19:04:11> Loss Rate: 68.00%
# 19:04:11> Duplicate Rate: 2.00%
# 19:04:11> MLE_Bob Tx: message: 1|39|1743116651302819000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|38|1743116651302817000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 17.67 ms
# 19:04:11> Loss Rate: 67.00%
# 19:04:11> Duplicate Rate: 2.00%
# 19:04:11> MLE_Bob Tx: message: 1|40|1743116651302820000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|39|1743116651302819000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 17.83 ms
# 19:04:11> Loss Rate: 66.00%
# 19:04:11> Duplicate Rate: 2.00%
# 19:04:11> MLE_Bob Tx: message: 1|41|1743116651302822000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|40|1743116651302820000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 17.98 ms
# 19:04:11> Loss Rate: 65.00%
# 19:04:11> Duplicate Rate: 2.00%
# 19:04:11> MLE_Bob Tx: message: 1|42|1743116651302824000
# 19:04:11> packet loss
# 19:04:11> MLE_Bob Tx: message: 1|43|1743116651302826000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|41|1743116651302822000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 18.14 ms
# 19:04:11> Loss Rate: 64.00%
# 19:04:11> Duplicate Rate: 2.00%
# 19:04:11> MLE_Bob Tx: message: 1|44|1743116651302829000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|43|1743116651302826000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 18.29 ms
# 19:04:11> Loss Rate: 63.00%
# 19:04:11> Duplicate Rate: 2.00%
# 19:04:11> MLE_Bob Tx: message: 1|45|1743116651302831000
# 19:04:11> packet loss
# 19:04:11> MLE_Bob Tx: message: 1|46|1743116651302833000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|44|1743116651302829000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 18.44 ms
# 19:04:11> Loss Rate: 62.00%
# 19:04:11> Duplicate Rate: 2.00%
# 19:04:11> MLE_Bob Tx: message: 1|47|1743116651302835000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|46|1743116651302833000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 18.58 ms
# 19:04:11> Loss Rate: 61.00%
# 19:04:11> Duplicate Rate: 2.00%
# 19:04:11> MLE_Bob Tx: message: 1|48|1743116651302837000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|47|1743116651302835000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 18.73 ms
# 19:04:11> Loss Rate: 60.00%
# 19:04:11> Duplicate Rate: 2.00%
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|48|1743116651302837000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 18.86 ms
# 19:04:11> Loss Rate: 59.00%
# 19:04:11> Duplicate Rate: 2.00%
# 19:04:11> Transmission Duplicated
# 19:04:11> MLE_Bob Tx: message: 1|49|1743116651302839000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|48|1743116651302837000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 18.86 ms
# 19:04:11> Loss Rate: 59.00%
# 19:04:11> Duplicate Rate: 3.00%
# 19:04:11> MLE_Bob Tx: message: 1|50|1743116651302841000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|49|1743116651302839000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 19.01 ms
# 19:04:11> Loss Rate: 58.00%
# 19:04:11> Duplicate Rate: 3.00%
# 19:04:11> MLE_Bob Tx: message: 1|51|1743116651302843000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|50|1743116651302841000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 19.14 ms
# 19:04:11> Loss Rate: 57.00%
# 19:04:11> Duplicate Rate: 3.00%
# 19:04:11> MLE_Bob Tx: message: 1|52|1743116651302845000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|51|1743116651302843000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 19.28 ms
# 19:04:11> Loss Rate: 56.00%
# 19:04:11> Duplicate Rate: 3.00%
# 19:04:11> MLE_Bob Tx: message: 1|53|1743116651302847000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|52|1743116651302845000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 19.41 ms
# 19:04:11> Loss Rate: 55.00%
# 19:04:11> Duplicate Rate: 3.00%
# 19:04:11> MLE_Bob Tx: message: 1|54|1743116651302849000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|53|1743116651302847000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 19.54 ms
# 19:04:11> Loss Rate: 54.00%
# 19:04:11> Duplicate Rate: 3.00%
# 19:04:11> MLE_Bob Tx: message: 1|55|1743116651302851000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|54|1743116651302849000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 19.69 ms
# 19:04:11> Loss Rate: 53.00%
# 19:04:11> Duplicate Rate: 3.00%
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|55|1743116651302851000'
# 19:04:11> MLE_Bob Tx: message: 1|56|1743116651302853000
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 19.83 ms
# 19:04:11> Loss Rate: 52.00%
# 19:04:11> Duplicate Rate: 3.00%
# 19:04:11> MLE_Bob Tx: message: 1|57|1743116651302855000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|56|1743116651302853000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 19.98 ms
# 19:04:11> Loss Rate: 51.00%
# 19:04:11> Duplicate Rate: 3.00%
# 19:04:11> MLE_Bob Tx: message: 1|58|1743116651302857000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|57|1743116651302855000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 20.13 ms
# 19:04:11> Loss Rate: 50.00%
# 19:04:11> Duplicate Rate: 3.00%
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|58|1743116651302857000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 20.28 ms
# 19:04:11> Loss Rate: 49.00%
# 19:04:11> Duplicate Rate: 3.00%
# 19:04:11> MLE_Bob Tx: message: 1|59|1743116651302859000
# 19:04:11> MLE_Bob Tx: message: 1|60|1743116651302861000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|59|1743116651302859000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 20.42 ms
# 19:04:11> Loss Rate: 48.00%
# 19:04:11> Duplicate Rate: 3.00%
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|60|1743116651302861000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 20.56 ms
# 19:04:11> Loss Rate: 47.00%
# 19:04:11> Duplicate Rate: 3.00%
# 19:04:11> MLE_Bob Tx: message: 1|61|1743116651302862000
# 19:04:11> MLE_Bob Tx: message: 1|62|1743116651302864000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|61|1743116651302862000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 20.70 ms
# 19:04:11> Loss Rate: 46.00%
# 19:04:11> Duplicate Rate: 3.00%
# 19:04:11> MLE_Bob Tx: message: 1|63|1743116651302866000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|62|1743116651302864000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 20.84 ms
# 19:04:11> Loss Rate: 45.00%
# 19:04:11> Duplicate Rate: 3.00%
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|63|1743116651302866000'
# 19:04:11> MLE_Bob Tx: message: 1|64|1743116651302868000
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 20.97 ms
# 19:04:11> Loss Rate: 44.00%
# 19:04:11> Duplicate Rate: 3.00%
# 19:04:11> MLE_Bob Tx: message: 1|65|1743116651302870000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|64|1743116651302868000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 21.11 ms
# 19:04:11> Loss Rate: 43.00%
# 19:04:11> Duplicate Rate: 3.00%
# 19:04:11> MLE_Bob Tx: message: 1|66|1743116651302872000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|65|1743116651302870000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 21.24 ms
# 19:04:11> Loss Rate: 42.00%
# 19:04:11> Duplicate Rate: 3.00%
# 19:04:11> MLE_Bob Tx: message: 1|67|1743116651302874000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|66|1743116651302872000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 21.38 ms
# 19:04:11> Loss Rate: 41.00%
# 19:04:11> Duplicate Rate: 3.00%
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|67|1743116651302874000'
# 19:04:11> MLE_Bob Tx: message: 1|68|1743116651302876000
# 19:04:11> packet loss
# 19:04:11> MLE_Bob Tx: message: 1|69|1743116651302878000
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 21.51 ms
# 19:04:11> Loss Rate: 40.00%
# 19:04:11> Duplicate Rate: 3.00%
# 19:04:11> MLE_Bob Tx: message: 1|70|1743116651302880000
# 19:04:11> packet loss
# 19:04:11> MLE_Bob Tx: message: 1|71|1743116651302882000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|69|1743116651302878000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 21.64 ms
# 19:04:11> Loss Rate: 39.00%
# 19:04:11> Duplicate Rate: 3.00%
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|71|1743116651302882000'
# 19:04:11> MLE_Bob Tx: message: 1|72|1743116651302884000
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 21.77 ms
# 19:04:11> Loss Rate: 38.00%
# 19:04:11> Duplicate Rate: 3.00%
# 19:04:11> MLE_Bob Tx: message: 1|73|1743116651302886000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|72|1743116651302884000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 21.89 ms
# 19:04:11> Loss Rate: 37.00%
# 19:04:11> Duplicate Rate: 3.00%
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|73|1743116651302886000'
# 19:04:11> MLE_Bob Tx: message: 1|74|1743116651302888000
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 22.02 ms
# 19:04:11> Loss Rate: 36.00%
# 19:04:11> Duplicate Rate: 3.00%
# 19:04:11> MLE_Bob Tx: message: 1|75|1743116651302890000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|74|1743116651302888000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 22.15 ms
# 19:04:11> Loss Rate: 35.00%
# 19:04:11> Duplicate Rate: 3.00%
# 19:04:11> MLE_Bob Tx: message: 1|76|1743116651302892000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|75|1743116651302890000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 22.27 ms
# 19:04:11> Loss Rate: 34.00%
# 19:04:11> Duplicate Rate: 3.00%
# 19:04:11> MLE_Bob Tx: message: 1|77|1743116651302894000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|76|1743116651302892000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 22.39 ms
# 19:04:11> Loss Rate: 33.00%
# 19:04:11> Duplicate Rate: 3.00%
# 19:04:11> MLE_Bob Tx: message: 1|78|1743116651302896000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|77|1743116651302894000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 22.51 ms
# 19:04:11> Loss Rate: 32.00%
# 19:04:11> Duplicate Rate: 3.00%
# 19:04:11> MLE_Bob Tx: message: 1|79|1743116651302898000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|78|1743116651302896000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 22.63 ms
# 19:04:11> Loss Rate: 31.00%
# 19:04:11> Duplicate Rate: 3.00%
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|79|1743116651302898000'
# 19:04:11> MLE_Bob Tx: message: 1|80|1743116651302900000
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 22.75 ms
# 19:04:11> Loss Rate: 30.00%
# 19:04:11> Duplicate Rate: 3.00%
# 19:04:11> MLE_Bob Tx: message: 1|81|1743116651302902000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|80|1743116651302900000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 22.87 ms
# 19:04:11> Loss Rate: 29.00%
# 19:04:11> Duplicate Rate: 3.00%
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|81|1743116651302902000'
# 19:04:11> MLE_Bob Tx: message: 1|82|1743116651302904000
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 22.98 ms
# 19:04:11> Loss Rate: 28.00%
# 19:04:11> Duplicate Rate: 3.00%
# 19:04:11> MLE_Bob Tx: message: 1|83|1743116651302922000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|82|1743116651302904000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 23.10 ms
# 19:04:11> Loss Rate: 27.00%
# 19:04:11> Duplicate Rate: 3.00%
# 19:04:11> MLE_Bob Tx: message: 1|84|1743116651302924000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|83|1743116651302922000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 23.22 ms
# 19:04:11> Loss Rate: 26.00%
# 19:04:11> Duplicate Rate: 3.00%
# 19:04:11> MLE_Bob Tx: message: 1|85|1743116651302926000
# 19:04:11> packet loss
# 19:04:11> MLE_Bob Tx: message: 1|86|1743116651302928000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|84|1743116651302924000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 23.33 ms
# 19:04:11> Loss Rate: 25.00%
# 19:04:11> Duplicate Rate: 3.00%
# 19:04:11> MLE_Bob Tx: message: 1|87|1743116651302930000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|86|1743116651302928000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 23.45 ms
# 19:04:11> Loss Rate: 24.00%
# 19:04:11> Duplicate Rate: 3.00%
# 19:04:11> MLE_Bob Tx: message: 1|88|1743116651302932000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|87|1743116651302930000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 23.56 ms
# 19:04:11> Loss Rate: 23.00%
# 19:04:11> Duplicate Rate: 3.00%
# 19:04:11> MLE_Bob Tx: message: 1|89|1743116651302934000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|88|1743116651302932000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 23.67 ms
# 19:04:11> Loss Rate: 22.00%
# 19:04:11> Duplicate Rate: 3.00%
# 19:04:11> MLE_Bob Tx: message: 1|90|1743116651302936000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|89|1743116651302934000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 23.78 ms
# 19:04:11> Loss Rate: 21.00%
# 19:04:11> Duplicate Rate: 3.00%
# 19:04:11> MLE_Bob Tx: message: 1|91|1743116651302938000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|90|1743116651302936000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 23.89 ms
# 19:04:11> Loss Rate: 20.00%
# 19:04:11> Duplicate Rate: 3.00%
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|91|1743116651302938000'
# 19:04:11> MLE_Bob Tx: message: 1|92|1743116651302940000
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 24.00 ms
# 19:04:11> Loss Rate: 19.00%
# 19:04:11> Duplicate Rate: 3.00%
# 19:04:11> MLE_Bob Tx: message: 1|93|1743116651302942000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|92|1743116651302940000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 24.11 ms
# 19:04:11> Loss Rate: 18.00%
# 19:04:11> Duplicate Rate: 3.00%
# 19:04:11> MLE_Bob Tx: message: 1|94|1743116651302944000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|93|1743116651302942000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 24.22 ms
# 19:04:11> Loss Rate: 17.00%
# 19:04:11> Duplicate Rate: 3.00%
# 19:04:11> MLE_Bob Tx: message: 1|95|1743116651302945000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|94|1743116651302944000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 24.33 ms
# 19:04:11> Loss Rate: 16.00%
# 19:04:11> Duplicate Rate: 3.00%
# 19:04:11> MLE_Bob Tx: message: 1|96|1743116651302947000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|95|1743116651302945000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 24.44 ms
# 19:04:11> Loss Rate: 15.00%
# 19:04:11> Duplicate Rate: 3.00%
# 19:04:11> MLE_Bob Tx: message: 1|97|1743116651302949000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|96|1743116651302947000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 24.54 ms
# 19:04:11> Loss Rate: 14.00%
# 19:04:11> Duplicate Rate: 3.00%
# 19:04:11> MLE_Bob Tx: message: 1|98|1743116651302961000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|97|1743116651302949000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 24.65 ms
# 19:04:11> Loss Rate: 13.00%
# 19:04:11> Duplicate Rate: 3.00%
# 19:04:11> MLE_Bob Tx: message: 1|99|1743116651302963000
# 19:04:11> packet loss
# 19:04:11> MLE_Bob Tx: message: 1|100|1743116651302965000
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|98|1743116651302961000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 24.76 ms
# 19:04:11> Loss Rate: 12.00%
# 19:04:11> Duplicate Rate: 3.00%
# 19:04:11 MLE_Alice Rx from ('127.0.0.1', 32222): b'1|100|1743116651302965000'
# 19:04:11> --- Measurement Results for MLE_Alice ---
# 19:04:11> Average Delay: 24.87 ms
# 19:04:11> Loss Rate: 11.00%
# 19:04:11> Duplicate Rate: 3.00%
